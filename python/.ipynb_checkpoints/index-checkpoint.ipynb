# %% [markdown]
# # Topicando (AlPHA)
# Topicando es un proyecto que busca ayudar a obtener los tópicos más comentados por un grupo de personas, obteniendo palabras clave en forma de ranking y grafos, para poder analizar necesidades, reclamos, comentarios, tendencias e ideas de la comunidad de forma masiva.
#
# En base a un array de frases como input se procesarán y analizarán los datos recolectados para poder tener un contexto de un tema de debate o discusión, siendo asi que:
# - Presenta en una lista ordenada de mayor a menor las palabras más utilizadas diferenciadas con stemming o lemmatizing
# - En base a las x palabras más usadas escogidas por estadistica o por número fijo, se crean clusters con KNN, KMeans, etc o solo con que contengan a esta palabra y se muestran grafos por cada palabra elegida como centroide
# - De cada cluster o agrupación se debe mostrar las palabras más usadas

# %%
pip install spacy
pip install pandas
# Out:
#   Input In [4]
#     pip install spacy
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Imports

# %%
import spacy
from collections import Counter
from spacy.matcher import Matcher
import pandas as pd
import numpy as np

# %%
class TopicandoV1:
    nlp = None
    phrases = []
    entities = []
    relations = []
    dictWords = {}
    
    def __init__(self, spacyLang, phrases):
        self.nlp = spacy.load(spacyLang)
        self.phrases = phrases
        self.entities = []
        self.relations = []
        self.dictWords = {}
    
    def getVectorizedPhrases(self):
        values = []
        for phrase in self.phrases:
            vector = np.zeros(300)
            doc = self.nlp(phrase)
            for token in doc:
                if not token.is_stop and not token.is_punct:
                    #print(token.text, token.pos_, token.dep_) #eliminar det
                    vector = vector + np.array(token.vector_norm)
            values.append(vector / len(doc))
        return np.array(values)

    def getMostUsedWordsInCorpus(self, useLemma = True):
        fullText = ""
        for phrase in self.phrases:
            fullText += (phrase + " ")
        doc = self.nlp(fullText)

        words = [(token.lemma_ if useLemma else token.text)
            for token in doc
            if not token.is_stop and not token.is_punct]

        word_freq = Counter(words)
        common_words = word_freq.most_common()
        return common_words
    
    def getWordCountOfEntitiesAndRelations(self):
        dictWords = {}
        for entitiesPair in self.entities:
            for word in entitiesPair:
                if word not in dictWords.keys():
                    dictWords[word] = 1
                else:
                    dictWords[word] += 1
        for relations in self.relations:
            for word in relations:
                if word not in dictWords.keys():
                    dictWords[word] = 1
                else:
                    dictWords[word] += 1

        self.dictWords = dictWords
        return dictWords

    def getMostUsedWordsOfEntitiesAndRelations(self, useLemma = True):
        self.getWordCountOfEntitiesAndRelations()
        return dict(sorted(self.dictWords.items(), key=lambda item: item[1], reverse=True))
    
    def searchEntitiesAndRelations(self):
        self.entities = []
        for phrase in self.phrases:
            self.entities.append(self.__getEntities(phrase))
        
        self.relations = []
        for phrase in self.phrases:
            self.relations.append(self.__getRelations(phrase))
    
    def getSourceEdgeTargetDataFrame(self,sourcesToSearch=[], edgesToSearch=[], targetsToSearch=[]):
        phraseLength = len(self.entities)
        sources = []
        targets = []
        edges = []
        
        for index in range(0, phraseLength):
            for relation in self.relations[index]:
                source = self.entities[index][0]
                target = self.entities[index][1]

                if (len(sourcesToSearch) + len(targetsToSearch) + len(edgesToSearch)) == 0 or (relation in edgesToSearch or source in sourcesToSearch or target in targetsToSearch):
                    sources.append(self.entities[index][0])
                    targets.append(self.entities[index][1])
                    edges.append(relation)

        sourceEdgeTargetDataframe = pd.DataFrame({'source':sources, 'target':targets, 'edge':edges})
        return sourceEdgeTargetDataframe
    
    def getSourcesEdgesTargetsEdgesArray(self, sourcesToSearch=[], edgesToSearch=[], targetsToSearch=[]):
        phraseLength = len(self.entities)
        data = []
        
        for index in range(0, phraseLength):
            for relation in self.relations[index]:
                source = self.entities[index][0]
                target = self.entities[index][1]

                if (len(sourcesToSearch) + len(targetsToSearch) + len(edgesToSearch)) == 0 or (relation in edgesToSearch or source in sourcesToSearch or target in targetsToSearch):
                    if source != '':
                        data.append([source, relation])
                    if target != '':
                        data.append([target, relation])

        return data
    
    def getSourcesTargetsArray(self, sourcesToSearch=[], edgesToSearch=[], targetsToSearch=[]):
        phraseLength = len(self.entities)
        data = []
        
        for index in range(0, phraseLength):
            for relation in self.relations[index]:
                source = self.entities[index][0]
                target = self.entities[index][1]

                if (len(sourcesToSearch) + len(targetsToSearch) + len(edgesToSearch)) == 0 or (relation in edgesToSearch or source in sourcesToSearch or target in targetsToSearch):
                    if source != '' and target != '':
                        data.append([source, target])

        return data

    def getSourceEdgeTargetEdgeDataFrame(self, sourcesToSearch=[], edgesToSearch=[], targetsToSearch=[]):
        phraseLength = len(self.entities)
        sources = []
        targets = []
        edges = []
        
        for index in range(0, phraseLength):
            for relation in self.relations[index]:
                source = self.entities[index][0]
                target = self.entities[index][1]

                if (len(sourcesToSearch) + len(targetsToSearch) + len(edgesToSearch)) == 0 or (relation in edgesToSearch or source in sourcesToSearch or target in targetsToSearch):
                    if source != '':
                        sources.append(self.entities[index][0])
                        targets.append(relation)
                        edges.append(relation)
                    if target != '':
                        sources.append(self.entities[index][1])
                        targets.append(relation)
                        edges.append(relation)

        sourceEdgeTargetDataframe = pd.DataFrame({'source':sources, 'target':targets, 'edge':edges})
        return sourceEdgeTargetDataframe

    def __getRelations(self, phrase):
        doc = self.nlp(phrase)

        matcher = Matcher(self.nlp.vocab)
        pattern = [
            {'POS':'VERB','OP':"?"},
            {'POS':'AUX','OP':"?"},
        ]

        matcher.add("matching_1", [pattern]) 
        matches = matcher(doc)

        if len(matches) == 0:
            return ["haber"]

        return [doc[match[1]:match[2]].lemma_ for match in matches]

    def __getEntities(self, phrase):
        ent1 = ""
        ent2 = ""

        prv_tok_dep = ""    
        prv_tok_text = ""   

        prefix = ""
        modifier = ""

        prv_token = None

        tokens = []

        for tok in self.nlp(phrase):
            if tok.dep_ != "punct":
                if tok.dep_ == "compound":
                    prefix = tok.text
                if prv_tok_dep == "compound":
                    prefix = prv_tok_text + " "+ tok.text
                if tok.dep_.endswith("mod") == True:
                    modifier = tok.text
                if prv_tok_dep == "compound":
                    modifier = prv_tok_text + " "+ tok.text
                if (tok.dep_.find("subj") == True or tok.dep_ == "subj") and tok.pos_ != "PRON":
                    ent1 = modifier + " " + prefix + " "+ tok.lemma_
                    prefix = ""
                    modifier = ""
                    prv_tok_dep = ""
                    prv_tok_text = ""
                    tokens.append(ent1)
                if tok.dep_.find("obj") == True:
                    ent2 = modifier + " " + prefix + " " + tok.lemma_
                    tokens.append(ent2)
                if tok.dep_ == "obj":
                    ent2 = tok.lemma_
                    tokens.append(ent2)
                if ent1.strip() == "" and ent2.find(tok.lemma_) == -1:
                    if tok.dep_.find("mod") == True and tok.pos_ == "ADJ":
                        ent1 = tok.lemma_
                        tokens.append(ent1)
                    if tok.pos_ == "NOUN":
                        ent1 = tok.lemma_
                        tokens.append(ent1)
                if ent2.strip() == "" and ent1.find(tok.lemma_) == -1:
                    if tok.dep_.find("mod") == True and tok.pos_ == "ADJ":
                        ent2 = tok.lemma_
                        tokens.append(ent2)
                    if tok.pos_ == "ADJ":
                        ent2 = tok.lemma_
                        tokens.append(ent2)
                    if tok.pos_ == "NOUN":
                        ent2 = tok.lemma_
                        tokens.append(ent2)
                    if (prv_token != None and prv_token.pos_ == "AUX") and (tok.pos_ == "VERB" or tok.pos_ == "ADJ"):
                        ent2 = tok.lemma_
                        tokens.append(ent2)
                prv_tok_dep = tok.dep_
                prv_tok_text = tok.text
                prv_token = tok

        #return [token.strip() for  token in tokens]
        return [ent1.strip(), ent2.strip()]

# %% [markdown]
# ## Data

# %%
phrases = [
    "No hay baños limpios",
    "los baños no se limpian",
    "los baños están sucios",
    "los vecinos hacen mucho ruido",
    "la vecina todo el día grita",
    "la vecina grita todo el día",
    "el vecino prende la radio todo el día",
    "ya no hay respeto a los mayores",
    "me acosan en la calle del barrio",
    "los viejos miran mucho mi cuerpo",
    "morbosean a mis familiares",
    "los viejos son pervertidos",
    "las calles están sucias",
    "ya no hay calles limpias",
    "los perros dañan la basura",
    "hay muchos perros que dejan sus desechos en la calle",
    "mucha mierda de perro en la acera",
]

# %%
data = pd.read_csv('./sugerencias-y-quejas-de-los-ciudadanos (1).csv',delimiter=';')
data = data.dropna()
data[data['Referencia'].apply(lambda x: isinstance(x, (str, bytes)))]
phrases = [ phrase.lower() for phrase in data.iloc[:,6].values]

# %% [markdown]
# ## Functions

# %%
topicando = TopicandoV1("es_core_news_lg",phrases)

# %%
topicando.getMostUsedWordsInCorpus(useLemma = True)
# Out:
# [('calle', 4),
#  ('baño', 3),
#  ('vecino', 3),
#  ('perro', 3),
#  ('limpio', 2),
#  ('sucio', 2),
#  ('gritar', 2),
#  ('viejo', 2),
#  ('limpiar', 1),
#  ('ruido', 1),
#  ('vecina', 1),
#  ('prender', 1),
#  ('radio', 1),
#  ('respeto', 1),
#  ('mayor', 1),
#  ('acosar', 1),
#  ('barrio', 1),
#  ('mirar', 1),
#  ('cuerpo', 1),
#  ('morbosean', 1),
#  ('familiar', 1),
#  ('pervertido', 1),
#  ('dañar', 1),
#  ('basura', 1),
#  ('dejar', 1),
#  ('desecho', 1),
#  ('mierda', 1),
#  ('acera', 1)]

# %%
topicando.searchEntitiesAndRelations()

# %%
topicando.getWordCountOfEntitiesAndRelations()
# Out:
# {'limpio': 2,
#  'baño': 3,
#  '': 3,
#  'sucio': 2,
#  'vecino': 3,
#  'ruido': 1,
#  'día': 2,
#  'vecina': 1,
#  'radio': 1,
#  'respeto': 1,
#  'calle': 4,
#  'yo': 1,
#  'viejo': 2,
#  'cuerpo': 1,
#  'familiar': 1,
#  'pervertir': 2,
#  'perro': 1,
#  'basura': 1,
#  'desecho': 1,
#  'mierda': 1,
#  'acera': 1,
#  'haber': 5,
#  'limpiar': 1,
#  'estar': 2,
#  'hacer': 1,
#  'gritar': 2,
#  'prender': 1,
#  'acosar': 1,
#  'mirar': 1,
#  'morbosear': 1,
#  'ser': 1,
#  'dañar': 1,
#  'dejar': 1}

# %%
topicando.getMostUsedWordsOfEntitiesAndRelations()
# Out:
# {'haber': 5,
#  'calle': 4,
#  'baño': 3,
#  '': 3,
#  'vecino': 3,
#  'limpio': 2,
#  'sucio': 2,
#  'día': 2,
#  'viejo': 2,
#  'pervertir': 2,
#  'estar': 2,
#  'gritar': 2,
#  'ruido': 1,
#  'vecina': 1,
#  'radio': 1,
#  'respeto': 1,
#  'yo': 1,
#  'cuerpo': 1,
#  'familiar': 1,
#  'perro': 1,
#  'basura': 1,
#  'desecho': 1,
#  'mierda': 1,
#  'acera': 1,
#  'limpiar': 1,
#  'hacer': 1,
#  'prender': 1,
#  'acosar': 1,
#  'mirar': 1,
#  'morbosear': 1,
#  'ser': 1,
#  'dañar': 1,
#  'dejar': 1}

# %%
kg_df = topicando.getSourceEdgeTargetEdgeDataFrame()
kg_df2 = topicando.getSourceEdgeTargetEdgeDataFrame(sourcesToSearch=["limpio","baño"])
print(kg_df[0:5])
print(kg_df2[0:5])
# Out:
#    source   target     edge
# 0  limpio    haber    haber
# 1    baño    haber    haber
# 2    baño  limpiar  limpiar
# 3    baño    estar    estar
# 4   sucio    estar    estar
#    source   target     edge
# 0  limpio    haber    haber
# 1    baño    haber    haber
# 2    baño  limpiar  limpiar
# 3    baño    estar    estar
# 4   sucio    estar    estar

# %% [markdown]
# ## Html Output

# %%
from IPython.display import Javascript
import json

# %%
# %%javascript
# require.config({
#     packages: [{
#         name: 'highcharts',
#         main: 'highcharts'
#     }],
#     paths: {
#         'highcharts': 'https://code.highcharts.com',
#         'networkgraph': 'https://code.highcharts.com/modules/networkgraph.js'
#     }
# });

# %%
topicando.getSourcesTargetsArray()
# Out:
# [['falta', 'respuesta'],
#  ['notificación', 'que'],
#  ['altura', 'revisión'],
#  ['modificacion  ambito', 'comision'],
#  ['buzón', 'notificación'],
#  ['no  máquina', 'bono'],
#  ['incidencia', 'carretera'],
#  ['incidencia', 'carretera'],
#  ['incidencia', 'carretera'],
#  ['exigencia', 'uso'],
#  ['transporte', 'demanda'],
#  ['lugar', 'mascarilla'],
#  ['señalización', 'entrada'],
#  ['alta', 'sistema'],
#  ['notificación', 'electrónico'],
#  ['medio', 'ambiente'],
#  ['medio', 'ambiente'],
#  ['medio', 'ambiente'],
#  ['queja', 'presentado'],
#  ['falta', 'aviso'],
#  ['paso', 'peatonal'],
#  ['horizontal', 'mejora'],
#  ['interesar', 'precio'],
#  ['interesar', 'precio'],
#  ['interesar', 'precio'],
#  ['reacondicionamiento', 'camino'],
#  ['contestación', 'satisfecho'],
#  ['modificación', 'normativa'],
#  ['alegación', 'plantilla'],
#  ['interesado', 'eliminación'],
#  ['interesado', 'real'],
#  ['interesado', 'real'],
#  ['desacuerdo', 'asignación'],
#  ['rechazado', 'servicio'],
#  ['rechazado', 'servicio'],
#  ['interesado', 'retraso'],
#  ['cl-501', 'entrada'],
#  ['pasal', 'madera'],
#  ['interesado', 'riesgo'],
#  ['documento', 'solicitar'],
#  ['documento', 'solicitar'],
#  ['incumplimiento', 'normativo'],
#  ['interesado', 'denuncia'],
#  ['mal', 'funcionamiento'],
#  ['deasignación', 'permiso'],
#  ['electrónico', 'tramitación'],
#  ['mal', 'funcionamiento'],
#  ['petición', 'mejor'],
#  ['colocación', 'badén'],
#  ['cl@ve', 'sistema'],
#  ['limpieza', 'cañado'],
#  ['solicitud', 'servicio'],
#  ['camino', 'vecinal'],
#  ['falta', 'información'],
#  ['notificación', 'electrónico'],
#  ['retraso', 'santerva'],
#  ['unificación', 'criterio'],
#  ['contaminación', 'actividad'],
#  ['cierre', '112'],
#  ['cierre', '112'],
#  ['cierre', '112'],
#  ['falta', 'vigilancia'],
#  ['mal', 'estado'],
#  ['mal', 'estado'],
#  ['mejora', 'tecnológico'],
#  ['imposibilidad', 'contacto'],
#  ['señal', 'carretera'],
#  ['iteresado', 'solución'],
#  ['iteresado', 'solución'],
#  ['malestar', 'falta'],
#  ['mal', 'funcionamiento'],
#  ['supervisión', 'calidad'],
#  ['crítica', 'exigencia'],
#  ['mal  agujero', 'asfaltar'],
#  ['mal  agujero', 'asfaltar'],
#  ['mal  agujero', 'asfaltar'],
#  ['camino', 'público'],
#  ['forma', 'presencial'],
#  ['forma', 'presencial'],
#  ['demora', 'violencia'],
#  ['registro', 'puerta'],
#  ['registro', 'puerta'],
#  ['interesado', 'ubiación'],
#  ['deficiente', 'territorial'],
#  ['reiteración', 'estado'],
#  ['cartel', 'playa'],
#  ['desafectacion  parcela', 'desafectacion'],
#  ['atención', 'telefónico'],
#  ['estado', 'señalización'],
#  ['interesado', 'certificado'],
#  ['interesado', 'certificado'],
#  ['señal', 'luminoso'],
#  ['paso', 'camión'],
#  ['limpieza', 'cuneta'],
#  ['instalacion', 'carretera'],
#  ['vehículo', 'paso'],
#  ['vehículo', 'paso'],
#  ['estado', 'salido'],
#  ['falta', 'atención'],
#  ['problema', 'conexión'],
#  ['alto', 'localidad'],
#  ['interesado', 'segovia'],
#  ['error', 'declaración'],
#  ['falta', 'cuidado'],
#  ['falta', 'luz'],
#  ['imposiblidad', 'internet'],
#  ['imposiblidad', 'internet'],
#  ['notificación', 'electrónico'],
#  ['desacuerdo', 'asignación'],
#  ['malo', 'conservación'],
#  ['electrónico', 'gnu-linux'],
#  ['electrónico', 'gnu-linux'],
#  ['electrónico', 'gnu-linux'],
#  ['reclamación', 'malo'],
#  ['limpieza', 'solar'],
#  ['notificación', 'buzón'],
#  ['tercero', 'solicitante'],
#  ['tercero', 'solicitante'],
#  ['tercero', 'solicitante'],
#  ['tercero', 'solicitante'],
#  ['sanción', 'tráfico'],
#  ['no ambiente en subir', 'personal'],
#  ['no ambiente en subir', 'personal'],
#  ['no ambiente en subir', 'personal'],
#  ['pesca', 'oficina'],
#  ['servicio', 'precario'],
#  ['falta', 'atención'],
#  ['falta', 'junta'],
#  ['aclaración', 'legislación'],
#  ['sistema', 'informatico'],
#  ['queja', 'medio'],
#  ['pino', 'existente'],
#  ['protección', 'incendio'],
#  ['disconformidad', 'contestación'],
#  ['internet', 'telefonía'],
#  ['incumplmiiento', 'normativa'],
#  ['coto', 'pesco'],
#  ['localidad', 'cambio'],
#  ['trato', 'inadecuado'],
#  ['licencia', 'ambiental'],
#  ['construcción', 'velatorio'],
#  ['sistema', 'operativo'],
#  ['interesado', 'obra'],
#  ['deficiencia', 'carril'],
#  ['trato', 'recibido'],
#  ['barrera', 'protección'],
#  ['teletramitación', 'documento'],
#  ['teletramitación', 'documento'],
#  ['vertido', 'parcela'],
#  ['estado', 'carretera'],
#  ['prtoblema', 'sede'],
#  ['atención', 'inadecuado'],
#  ['estado', 'carretera'],
#  ['contestación', 'escrito'],
#  ['señalización', 'comienzo'],
#  ['interesado', 'estado'],
#  ['peligrosidad', 'carretera'],
#  ['certificadi', 'competencia'],
#  ['interesado', 'estado'],
#  ['inadecuado  agente', 'inadecuado'],
#  ['lal', 'estado'],
#  ['administración', 'trámite'],
#  ['administración', 'trámite'],
#  ['administración', 'trámite'],
#  ['administración', 'trámite'],
#  ['adopción', 'estrategia'],
#  ['interesado', 'retraso'],
#  ['cuestioón', 'relativo'],
#  ['terraza', 'verja'],
#  ['requisito', 'ite'],
#  ['estado', 'márgén'],
#  ['atención', 'mesa'],
#  ['atención', 'mesa'],
#  ['información', 'insuficiente'],
#  ['devolución', 'importe'],
#  ['interesado', 'aglomeración'],
#  ['imposibilidad', 'trámite'],
#  ['interesado', 'práctica'],
#  ['interesado', 'práctica'],
#  ['interesado', 'práctica'],
#  ['interesado', 'práctica'],
#  ['falta', 'contestación'],
#  ['horario', 'clase'],
#  ['propiedad', 'actuación'],
#  ['falta', 'señalización'],
#  ['fomento', 'atender'],
#  ['fomento', 'atender'],
#  ['fomento', 'atender'],
#  ['dificultad', '60'],
#  ['derecho', 'trámite'],
#  ['nuevo', 'sistema'],
#  ['cebo', 'utilizado'],
#  ['mal', 'funcionamiento'],
#  ['reserva', 'fecha'],
#  ['importe', 'devolución'],
#  ['interesado', 'prestación'],
#  ['autobús', 'día'],
#  ['autobús', 'día'],
#  ['limpieza', 'carretera'],
#  ['normalidad', 'post-covid'],
#  ['diámetro', 'escaso'],
#  ['contestación', 'urgente']]

# %%
chart_data = []
nodes_filtered = []
for i in topicando.getSourcesTargetsArray():
    if i[0] not in nodes_filtered:
        nodes_filtered.append(i[0])
    if i[1] not in nodes_filtered:
        nodes_filtered.append(i[1])
    chart_data.append([i[0],i[1]])

Javascript("window.chartData={};".format(json.dumps(chart_data)))

# %%
topicando.getWordCountOfEntitiesAndRelations()
# Out:
# {'falta': 12,
#  'respuesta': 1,
#  'notificación': 6,
#  'que': 1,
#  'altura': 1,
#  'revisión': 1,
#  'modificacion  ambito': 1,
#  'comision': 1,
#  'buzón': 2,
#  'no  máquina': 1,
#  'bono': 1,
#  'cita': 1,
#  '': 3,
#  'incidencia': 1,
#  'carretera': 7,
#  'exigencia': 2,
#  'uso': 1,
#  'transporte': 1,
#  'demanda': 1,
#  'lugar': 1,
#  'mascarilla': 1,
#  'señalización': 4,
#  'entrada': 2,
#  'alta': 1,
#  'sistema': 5,
#  'electrónico': 5,
#  'medio': 2,
#  'ambiente': 1,
#  'queja': 2,
#  'presentado': 1,
#  'aviso': 1,
#  'paso': 3,
#  'peatonal': 1,
#  'horizontal': 1,
#  'mejora': 2,
#  'interesar': 2,
#  'precio': 1,
#  'reacondicionamiento': 1,
#  'camino': 3,
#  'contestación': 5,
#  'satisfecho': 1,
#  'modificación': 1,
#  'normativa': 2,
#  'alegación': 1,
#  'plantilla': 1,
#  'interesado': 16,
#  'eliminación': 1,
#  'real': 2,
#  'desacuerdo': 2,
#  'asignación': 2,
#  'rechazado': 1,
#  'servicio': 3,
#  'retraso': 3,
#  'cl-501': 1,
#  'pasal': 1,
#  'madera': 1,
#  'riesgo': 1,
#  'documento': 2,
#  'solicitar': 9,
#  'incumplimiento': 1,
#  'normativo': 1,
#  'denuncia': 1,
#  'mal': 5,
#  'funcionamiento': 4,
#  'deasignación': 1,
#  'permiso': 1,
#  'tramitación': 1,
#  'petición': 1,
#  'mejor': 1,
#  'colocación': 1,
#  'badén': 1,
#  'cl@ve': 1,
#  'limpieza': 4,
#  'cañado': 1,
#  'solicitud': 2,
#  'vecinal': 1,
#  'información': 2,
#  'santerva': 1,
#  'unificación': 1,
#  'criterio': 1,
#  'contaminación': 1,
#  'actividad': 1,
#  'cierre': 3,
#  '112': 1,
#  'vigilancia': 1,
#  'estado': 10,
#  'tecnológico': 1,
#  'imposibilidad': 2,
#  'contacto': 1,
#  'señal': 2,
#  'iteresado': 1,
#  'solución': 1,
#  'malestar': 1,
#  'supervisión': 1,
#  'calidad': 1,
#  'crítica': 1,
#  'mal  agujero': 1,
#  'asfaltar': 2,
#  'público': 1,
#  'forma': 1,
#  'presencial': 1,
#  'demora': 1,
#  'violencia': 1,
#  'registro': 1,
#  'puerta': 1,
#  'ubiación': 1,
#  'deficiente': 1,
#  'territorial': 1,
#  'reiteración': 1,
#  'cartel': 1,
#  'playa': 1,
#  'desafectacion  parcela': 1,
#  'desafectacion': 1,
#  'atención': 5,
#  'telefónico': 1,
#  'certificado': 1,
#  'luminoso': 1,
#  'camión': 1,
#  'cuneta': 1,
#  'instalacion': 1,
#  'vehículo': 1,
#  'salido': 1,
#  'problema': 1,
#  'conexión': 1,
#  'alto': 1,
#  'localidad': 2,
#  'segovia': 1,
#  'error': 1,
#  'declaración': 1,
#  'cuidado': 1,
#  'luz': 1,
#  'imposiblidad': 1,
#  'internet': 2,
#  'malo': 2,
#  'conservación': 1,
#  'gnu-linux': 1,
#  'reclamación': 1,
#  'solar': 1,
#  'tercero': 1,
#  'solicitante': 1,
#  'sanción': 1,
#  'tráfico': 1,
#  'no ambiente en subir': 1,
#  'personal': 1,
#  'pesca': 1,
#  'oficina': 1,
#  'precario': 1,
#  'junta': 1,
#  'aclaración': 1,
#  'legislación': 1,
#  'informatico': 1,
#  'pino': 1,
#  'existente': 1,
#  'protección': 2,
#  'incendio': 1,
#  'disconformidad': 1,
#  'telefonía': 1,
#  'incumplmiiento': 1,
#  'coto': 1,
#  'pesco': 1,
#  'cambio': 1,
#  'trato': 2,
#  'inadecuado': 3,
#  'licencia': 1,
#  'ambiental': 1,
#  'construcción': 1,
#  'velatorio': 1,
#  'operativo': 1,
#  'obra': 1,
#  'deficiencia': 1,
#  'carril': 1,
#  'recibido': 1,
#  'barrera': 1,
#  'teletramitación': 1,
#  'vertido': 1,
#  'parcela': 1,
#  'prtoblema': 1,
#  'sede': 1,
#  'escrito': 1,
#  'comienzo': 1,
#  'peligrosidad': 1,
#  'certificadi': 1,
#  'competencia': 1,
#  'inadecuado  agente': 1,
#  'lal': 1,
#  'administración': 1,
#  'trámite': 3,
#  'adopción': 1,
#  'estrategia': 1,
#  'cuestioón': 1,
#  'relativo': 1,
#  'terraza': 1,
#  'verja': 1,
#  'requisito': 1,
#  'ite': 1,
#  'márgén': 1,
#  'mesa': 1,
#  'insuficiente': 1,
#  'devolución': 2,
#  'importe': 2,
#  'aglomeración': 1,
#  'práctica': 1,
#  'horario': 1,
#  'clase': 1,
#  'propiedad': 1,
#  'actuación': 1,
#  'fomento': 1,
#  'atender': 4,
#  'dificultad': 1,
#  '60': 1,
#  'derecho': 1,
#  'nuevo': 1,
#  'cebo': 1,
#  'utilizado': 1,
#  'reserva': 1,
#  'fecha': 1,
#  'prestación': 1,
#  'autobús': 1,
#  'día': 1,
#  'normalidad': 1,
#  'post-covid': 1,
#  'diámetro': 1,
#  'escaso': 1,
#  'urgente': 1,
#  'haber': 100,
#  'ir': 1,
#  'desarrolir': 1,
#  'funcionar': 3,
#  'ser': 4,
#  'rehabilitar': 1,
#  'usar': 1,
#  'dar él': 1,
#  'sugerir': 4,
#  'abaratar': 1,
#  'quejar': 15,
#  'derivar': 1,
#  'encontrar': 1,
#  'temer': 1,
#  'obligacion': 1,
#  'relacionar él': 1,
#  'requerir': 1,
#  'mejorar': 1,
#  'presentar': 3,
#  'incorporar': 1,
#  'alertar': 1,
#  'contactar': 1,
#  'llamar': 1,
#  'tordil él': 1,
#  'sg-322': 1,
#  'expresar': 1,
#  'pedir': 1,
#  'otorgar': 1,
#  'estar': 3,
#  'abrir': 1,
#  'proponer': 1,
#  'carbanar': 1,
#  'querer': 1,
#  'envien': 1,
#  'za-925': 2,
#  'aparcar': 1,
#  'obstruir': 1,
#  'atravesar': 1,
#  'conectar él': 1,
#  'poder': 3,
#  'hacer': 2,
#  'debiar': 1,
#  'habilitar': 1,
#  'subir': 2,
#  'realizar': 2,
#  'faltar': 3,
#  'preguntar': 1,
#  'aumentar': 1,
#  'espinar': 1,
#  'solicitar poder': 1,
#  'reanude': 1,
#  'catalogar': 1,
#  'proteger él': 1,
#  'evitar': 1,
#  'alcantarillar': 1,
#  'llegar': 1}

# %%
valMin = min([topicando.dictWords[word] for word in topicando.dictWords.keys() if word != '' and word in nodes_filtered])
valMax = max([topicando.dictWords[word] for word in topicando.dictWords.keys() if word != '' and word in nodes_filtered])

valMinNormalized = 5
valMaxNormalized = 50

# %%
nodes = []
for word in topicando.dictWords.keys():
    if word != '' and word in nodes_filtered:
        nodes.append({
            "id": word,
            "marker": {
                "count": topicando.dictWords[word],
                "radius": np.interp(topicando.dictWords[word],[valMin,valMax],[valMinNormalized,valMaxNormalized])
            }
        })

Javascript("window.nodes={};".format(json.dumps(nodes)))

# %%
# %%javascript
# // Since I append the div later, sometimes there are multiple divs.
# $("#container").remove();
#
# // Make the cdiv to contain the chart.
# element.append('<div id="container" style="min-width: 310px; min-height: 600px; margin: 0 auto"></div>');
#
# console.log("init");
# console.log(window.chartData);
# console.log(window.nodes);
#
# // Require highcarts and make the chart.
# require([
#     'highcharts',
#     'highcharts/modules/exporting',
#     'highcharts/modules/accessibility',
#     'highcharts/modules/networkgraph'
# ], function (Highcharts) {
#
#     console.log("WORKING");
#     $('#container').highcharts({
#         chart: {
#         type: 'networkgraph',
#         height: '100%'
#       },
#       title: {
#         text: ''
#       },
#       subtitle: {
#         text: ''
#       },
#         tooltip: {
#     formatter: function () {
#         console.log(this)
#       return "<b>" + this.key + "</b>: " + this.point.count;
#     }
#   },
#       plotOptions: {
#         networkgraph: {
#           keys: ['from', 'to'],
#           layoutAlgorithm: {
#             enableSimulation: false,//true
#             friction: -0.9
#           }
#         }
#       },
#       series: [{
#           colorByPoint: true,
#         accessibility: {
#           enabled: false
#         },
#         dataLabels: {
#           enabled: true,
#           linkFormat: '',
#         },
#         id: 'lang-tree',
#         data: window.chartData,
#         nodes: window.nodes
#       }]
#     });
# });
