# %% [markdown]
# # Topicando (AlPHA)
# Topicando es un proyecto que busca ayudar a obtener los tópicos más comentados por un grupo de personas, obteniendo palabras clave en forma de ranking y grafos, para poder analizar necesidades, reclamos, comentarios, tendencias e ideas de la comunidad de forma masiva.
#
# En base a un array de frases como input se procesarán y analizarán los datos recolectados para poder tener un contexto de un tema de debate o discusión, siendo asi que:
# - Presenta en una lista ordenada de mayor a menor las palabras más utilizadas diferenciadas con stemming o lemmatizing
# - En base a las x palabras más usadas escogidas por estadistica o por número fijo, se crean clusters con KNN, KMeans, etc o solo con que contengan a esta palabra y se muestran grafos por cada palabra elegida como centroide
# - De cada cluster o agrupación se debe mostrar las palabras más usadas

# %%
import IPython.display
import ipywidgets
import io
import pandas as pd
from topicando import TopicandoV1
import numpy as np

# %% [markdown]
# ## Elije un archivo csv

# %%
fileUploader = ipywidgets.FileUpload( accept = '.csv', multiple = False )
display(fileUploader)
# Out:
# FileUpload(value=(), accept='.csv', description='Upload')

# %%
data = pd.read_csv(io.BytesIO(fileUploader.value[0].content), delimiter=';')
data = data.dropna()
data.head()
# Out:
#     Tipo      Estado F.Solicitud Origen                   Unidad  \
# 0  Queja  Contestado  2021-12-17    WEB  CONSEJERIA DE EDUCACION
# 1  Queja  Contestado  2021-12-16    WEB  CONSEJERIA DE EDUCACION
# 2  Queja  Contestado  2021-12-15    WEB  CONSEJERIA DE EDUCACION
# 3  Queja  Contestado  2021-12-14   OAMR  CONSEJERIA DE EDUCACION
# 4  Queja  Contestado  2021-12-05    WEB  CONSEJERIA DE EDUCACION
#
#              Provincia                                         Referencia
# 0  SERVICIOS CENTRALES  Ayudas becas comedor centros docentes concertados
# 1  SERVICIOS CENTRALES  Rechazado por ser cuestión de la Consejería de...
# 2               BURGOS  No está de acuerdo con cantar villancicos en l...
# 3            SALAMANCA       solicitud de tablets por medios electronicos
# 4            SALAMANCA  falta vacuna covid de tres trabajadores ies pe...

# %% [markdown]
# ## Elija una columna del dataframe

# %%
columnSelector = ipywidgets.Dropdown(
    options=data.columns.values,
    value=data.columns.values[0],
    description='CSV Column:',
    disabled=False,
)
display(columnSelector)
# Out:
# Dropdown(description='CSV Column:', options=('Tipo', 'Estado', 'F.Solicitud', 'Origen', 'Unidad', 'Provincia',…

# %%
phrases = data[columnSelector.value].values

# %% [markdown]
# ## Functions

# %%
topicando = topicando.TopicandoV1("es_core_news_lg", phrases)

# %%
topicando.getMostUsedWordsInCorpus(useLemma = True)
# Out:
# [('escolar', 7),
#  ('ESCOLAR', 6),
#  ('CEIP', 6),
#  ('infantil', 6),
#  ('centro', 5),
#  ('programa', 5),
#  ('Cierre', 5),
#  ('Santa', 5),
#  ('María', 5),
#  ('comedor', 4),
#  ('solicitud', 4),
#  ('IES', 4),
#  ('escuela', 4),
#  ('colegio', 3),
#  ('interesado', 3),
#  ('quejar', 3),
#  ('clase', 3),
#  ('TRANSPORTE', 3),
#  ('tratar', 3),
#  ('RELEO', 3),
#  ('PLUS', 3),
#  ('atencion', 3),
#  ('información', 3),
#  ('problema', 3),
#  ('Ayudas', 2),
#  ('beca', 2),
#  ('Educación', 2),
#  ('vacuna', 2),
#  ('covid', 2),
#  ('inadecuado', 2),
#  ('meteorológico', 2),
#  ('solicitar', 2),
#  ('suspensión', 2),
#  ('Profesor', 2),
#  ('inclemencia', 2),
#  ('RUTA', 2),
#  ('AUTOBUS', 2),
#  ('servicio', 2),
#  ('DISTANCIA', 2),
#  ('transporte', 2),
#  ('COVID', 2),
#  ('19', 2),
#  ('administración', 2),
#  ('texto', 2),
#  ('recibido', 2),
#  ('menor', 2),
#  ('PCR', 2),
#  ('CENTRO', 2),
#  ('BILINGÜISMO', 2),
#  ('ingl', 2),
#  ('hijo', 2),
#  ('docente', 1),
#  ('concertado', 1),
#  ('rechazado', 1),
#  ('cuestión', 1),
#  ('Consejería', 1),
#  ('Becas', 1),
#  ('cantar', 1),
#  ('villancico', 1),
#  ('fiesta', 1),
#  ('Navidad', 1),
#  ('tablet', 1),
#  ('medio', 1),
#  ('electronico', 1),
#  ('faltar', 1),
#  ('trabajador', 1),
#  ('ies', 1),
#  ('peñaranda', 1),
#  ('trato', 1),
#  ('Problemas', 1),
#  ('conciliacoón', 1),
#  ('cerrar', 1),
#  ('inclmencias', 1),
#  ('11', 1),
#  ('enero', 1),
#  ('intersado', 1),
#  ('temporal', 1),
#  ('presncial', 1),
#  ('DEFICIENCIAS', 1),
#  ('DIEGO', 1),
#  ('PRAVES', 1),
#  ('Fibra', 1),
#  ('óptico', 1),
#  ('Palomera', 1),
#  ('italiano', 1),
#  ('EOI', 1),
#  ('Burgos', 1),
#  ('Programas', 1),
#  ('informático', 1),
#  ('obsoleto', 1),
#  ('extracurricular', 1),
#  ('alto', 1),
#  ('capacidad', 1),
#  ('cierre', 1),
#  ('educativo', 1),
#  ('situación', 1),
#  ('climatológtico', 1),
#  ('funcionamiento', 1),
#  ('Colegio', 1),
#  ('motivo', 1),
#  ('meterorológica', 1),
#  ('queja', 1),
#  ('meteorología', 1),
#  ('MODIFICACION', 1),
#  ('Parque', 1),
#  ('Alameda', 1),
#  ('-ceip', 1),
#  ('Peral-Pinar', 1),
#  ('Jalón', 1),
#  ('LLAMADA', 1),
#  ('PASIVAS', 1),
#  ('jubilacion', 1),
#  ('intersada', 1),
#  ('cambio', 1),
#  ('ALZADOR', 1),
#  ('irrespetuoso', 1),
#  ('teléfono', 1),
#  ('exposición', 1),
#  ('Formación', 1),
#  ('Profesional', 1),
#  ('conservatorio', 1),
#  ('Aranda', 1),
#  ('Duero', 1),
#  ('cumplir', 1),
#  ('obligación', 1),
#  ('Servicio', 1),
#  ('desacuerdo', 1),
#  ('prestar', 1),
#  ('continuador', 1),
#  ('error', 1),
#  ('citacion', 1),
#  ('VACUNACION', 1),
#  ('COVID-19', 1),
#  ('PROBLEMAS', 1),
#  ('curso', 1),
#  ('bachillerato', 1),
#  ('MODELO', 1),
#  ('BECA', 1),
#  ('F.P.', 1),
#  ('Irregularidades', 1),
#  ('Merindades', 1),
#  ('Castilla', 1),
#  ('Comerdor', 1),
#  ('Pablo', 1),
#  ('Picasso', 1),
#  ('Carbajosa', 1),
#  ('Sagrada', 1),
#  ('TRATO', 1),
#  ('RECIBIDO', 1),
#  ('ORDENANZA', 1),
#  ('INSTITUTO', 1),
#  ('Incidente', 1),
#  ('Guardería', 1),
#  ('Grijota', 1),
#  ('ORDOÑO', 1),
#  ('II', 1),
#  ('grado', 1),
#  ('SUPERIOR', 1),
#  ('ALONSO', 1),
#  ('MADRIGAL', 1),
#  ('c.g.s.', 1),
#  ('finanzas', 1),
#  ('semipresencial', 1),
#  ('religión', 1),
#  ('listado', 1),
#  ('provisional', 1),
#  ('adminiso', 1),
#  ('e.e.i.', 1),
#  ('gratuidad', 1),
#  ('libro', 1),
#  ('trabajadora', 1),
#  ('Teresa', 1),
#  ('León', 1),
#  ('Ibeas', 1),
#  ('Juarros', 1),
#  ('Asitencia', 1),
#  ('acto', 1),
#  ('graduación', 1),
#  ('PESIMA', 1),
#  ('TELEFONICA', 1),
#  ('Acoso', 1),
#  ('3', 1),
#  ('año', 1),
#  ('permitir', 1),
#  ('acceso', 1),
#  ('bus', 1),
#  ('parada', 1),
#  ('distinto', 1),
#  ('habitual', 1),
#  ('Convalidación', 1),
#  ('módulo', 1),
#  ('electrónico', 1),
#  ('denegación', 1),
#  ('REGISTRO', 1),
#  ('escrito', 1),
#  ('conversión', 1),
#  ('CONVERSION', 1),
#  ('relativo', 1),
#  ('criterior', 1),
#  ('desdoble', 1),
#  ('aula', 1),
#  ('revision', 1),
#  ('caso', 1),
#  ('hija', 1),
#  ('AYUDA', 1),
#  ('COMPETENCIAS', 1),
#  ('DIGITALES', 1),
#  ('Discriminación', 1),
#  ('sufrido', 1),
#  ('vacunación', 1),
#  ('compromisir', 1),
#  ('garantizar', 1),
#  ('alzador', 1),
#  ('autobús', 1),
#  ('empresa', 1),
#  ('estructura', 1),
#  ('pasivo', 1),
#  ('LIBROS', 1),
#  ('Solcitudes', 1),
#  ('ciclo', 1),
#  ('FP', 1),
#  ('CEO', 1),
#  ('ATENEA', 1),
#  ('BILINGÜE', 1),
#  ('reducción', 1),
#  ('jornada', 1),
#  ('junio', 1),
#  ('septiembre', 1),
#  ('Recogida', 1),
#  ('titulo', 1),
#  ('universitario', 1),
#  ('UEMC', 1),
#  ('accidente', 1),
#  ('Instituto', 1),
#  ('contestación', 1),
#  ('malo', 1),
#  ('educación', 1),
#  ('Trato', 1),
#  ('Dirección', 1),
#  ('Provincial', 1),
#  ('DEVOLUCION', 1),
#  ('TASA', 1),
#  ('MATRICULA', 1),
#  ('DISCAPACIDAD', 1),
#  ('Miguel', 1),
#  ('Delibes', 1),
#  ('Nava', 1),
#  ('Rey', 1),
#  ('oboe', 1),
#  (' ', 1),
#  ('ELTRANSPORTE', 1),
#  ('SCOLAR', 1),
#  ('duque', 1),
#  ('ALBA', 1),
#  ('presencial', 1),
#  ('Solicitud', 1),
#  ('participación', 1),
#  ('presentación', 1),
#  ('admisión', 1),
#  ('alumnado', 1),
#  ('TARDANZA', 1),
#  ('EMPEZAR', 1),
#  ('clás', 1),
#  ('atención', 1),
#  ('FONETICA', 1),
#  ('NIÑO', 1),
#  ('21/22', 1),
#  ('listas', 1),
#  ('DINÁMICAS', 1),
#  ('enviar', 1),
#  ('alumno', 1),
#  ('casa', 1),
#  ('obra', 1),
#  ('tejado', 1),
#  ('Reducción', 1),
#  ('hora', 1),
#  ('lectiva', 1),
#  ('3º', 1),
#  ('organización', 1),
#  ('turno', 1),
#  ('asistir', 1),
#  ('apuntar', 1),
#  ('niño', 1),
#  ('instituto', 1),
#  ('distante', 1),
#  ('contratatación', 1),
#  ('predoctoral', 1),
#  ('personal', 1),
#  ('investigador', 1),
#  ('RETRASO', 1),
#  ('Modelo', 1),
#  ('Releo', 1),
#  ('+', 1),
#  ('PROCEDIMIENTO', 1),
#  ('seguir', 1),
#  ('documento', 1),
#  ('figurar', 1),
#  ('tener', 1),
#  ('acompañado', 1),
#  ('padre', 1),
#  ('madre', 1),
#  ('tutor', 1),
#  ('incidencia', 1),
#  ('Aplicación', 1),
#  ('Comedores', 1),
#  ('Escolares', 1),
#  ('quejo', 1),
#  ('NULA', 1),
#  ('MAESTRA', 1),
#  ('INTERINA', 1),
#  ('deficiente', 1)]

# %%
topicando.searchEntitiesAndRelations()

# %%
topicando.getWordCountOfEntitiesAndRelations()
# Out:
# {'beca': 2,
#  'comedor': 2,
#  'cuestión': 1,
#  'rechazado': 1,
#  'acuerdo': 2,
#  'villancico': 1,
#  'solicitud': 4,
#  'tablet': 1,
#  'trabajadores covid de peñarandir': 1,
#  'trabajador': 1,
#  'interesado': 2,
#  'trato': 1,
#  'problema': 3,
#  'centro': 2,
#  'intersado': 1,
#  'suspensión': 2,
#  '': 41,
#  'fibra': 1,
#  'óptico': 1,
#  'italiano': 1,
#  'informático': 1,
#  'obsoleto': 1,
#  'Programa': 1,
#  'capacidad': 1,
#  'cierre': 1,
#  'funcionamiento': 1,
#  'motivo': 1,
#  'Cierre  centro': 1,
#  'inclemencia': 1,
#  'queja': 3,
#  'RUTA': 1,
#  '-ceip': 1,
#  'llamada': 1,
#  'clase': 1,
#  'cambio': 1,
#  'alzador': 2,
#  'teléfono': 1,
#  'inadecuado': 1,
#  'exposición': 1,
#  'conservatorio': 1,
#  'CEIP': 1,
#  'obligación': 1,
#  'escolar': 4,
#  'desacuerdo': 1,
#  'servicio': 2,
#  'error': 1,
#  'CURSO  bachillerato': 1,
#  'curso': 1,
#  'transporte': 1,
#  'RECIBIDO': 1,
#  'incidente': 1,
#  'grado': 1,
#  'SUPERIOR': 1,
#  'administración': 1,
#  'finanza': 1,
#  'religión': 1,
#  'listado': 1,
#  'provisional': 1,
#  'programa': 4,
#  'gratuidad': 1,
#  'colegio': 1,
#  'trabajadora': 1,
#  'Asitencia': 1,
#  'acto': 1,
#  'PESIMA': 1,
#  'acoso': 1,
#  'menor': 1,
#  'bus': 1,
#  'acceso': 1,
#  'convalidación': 1,
#  'módulo': 1,
#  'denegación': 1,
#  'REGISTRO': 1,
#  'conversión': 1,
#  'conversion': 1,
#  'relativo': 1,
#  'información': 2,
#  'caso': 1,
#  'hija': 1,
#  'sufrido': 1,
#  'vacunación': 1,
#  'autobús': 1,
#  'estructura': 1,
#  'pasivo': 1,
#  'ciclo': 1,
#  'ceo': 1,
#  'reducción': 1,
#  'jornada': 1,
#  'universitario': 1,
#  'tratar': 5,
#  'contestación': 1,
#  'malo': 1,
#  'educación': 1,
#  'recibido': 1,
#  'TASA': 1,
#  'escuela': 4,
#  'infantil': 4,
#  'GRAN  duque': 1,
#  'gran': 1,
#  'presencial': 1,
#  'participación': 1,
#  'presentación': 1,
#  'ingl': 1,
#  'atención': 1,
#  'listas': 1,
#  'casa': 1,
#  'alumno': 1,
#  'hora': 1,
#  'lectiva': 1,
#  'niño': 1,
#  'predoctoral': 1,
#  'personal': 1,
#  'RETRASO': 1,
#  'ESCOLAR': 1,
#  'Modelo': 1,
#  'tenemos': 1,
#  'PROCEDIMIENTO': 1,
#  'documento': 1,
#  'padre': 1,
#  'incidencia': 1,
#  'atencion': 1,
#  'deficiente': 1,
#  'haber': 71,
#  'ser': 1,
#  'estar': 1,
#  'cantar': 1,
#  'faltar': 1,
#  'peñarandir': 1,
#  'quejar': 2,
#  'cierrir': 1,
#  'solicitar': 2,
#  'extracurricular': 1,
#  'hacer': 1,
#  'cumplir': 1,
#  'prestar': 1,
#  'su': 1,
#  'permitir': 1,
#  'compromisir': 1,
#  'garantizar': 1,
#  'enviar': 1,
#  'asistir': 1,
#  'apuntar': 1,
#  'figurar': 1,
#  'tener': 1,
#  'ir': 1}

# %%
topicando.getMostUsedWordsOfEntitiesAndRelations()
# Out:
# {'haber': 71,
#  '': 41,
#  'tratar': 5,
#  'solicitud': 4,
#  'escolar': 4,
#  'programa': 4,
#  'escuela': 4,
#  'infantil': 4,
#  'problema': 3,
#  'queja': 3,
#  'beca': 2,
#  'comedor': 2,
#  'acuerdo': 2,
#  'interesado': 2,
#  'centro': 2,
#  'suspensión': 2,
#  'alzador': 2,
#  'servicio': 2,
#  'información': 2,
#  'quejar': 2,
#  'solicitar': 2,
#  'cuestión': 1,
#  'rechazado': 1,
#  'villancico': 1,
#  'tablet': 1,
#  'trabajadores covid de peñarandir': 1,
#  'trabajador': 1,
#  'trato': 1,
#  'intersado': 1,
#  'fibra': 1,
#  'óptico': 1,
#  'italiano': 1,
#  'informático': 1,
#  'obsoleto': 1,
#  'Programa': 1,
#  'capacidad': 1,
#  'cierre': 1,
#  'funcionamiento': 1,
#  'motivo': 1,
#  'Cierre  centro': 1,
#  'inclemencia': 1,
#  'RUTA': 1,
#  '-ceip': 1,
#  'llamada': 1,
#  'clase': 1,
#  'cambio': 1,
#  'teléfono': 1,
#  'inadecuado': 1,
#  'exposición': 1,
#  'conservatorio': 1,
#  'CEIP': 1,
#  'obligación': 1,
#  'desacuerdo': 1,
#  'error': 1,
#  'CURSO  bachillerato': 1,
#  'curso': 1,
#  'transporte': 1,
#  'RECIBIDO': 1,
#  'incidente': 1,
#  'grado': 1,
#  'SUPERIOR': 1,
#  'administración': 1,
#  'finanza': 1,
#  'religión': 1,
#  'listado': 1,
#  'provisional': 1,
#  'gratuidad': 1,
#  'colegio': 1,
#  'trabajadora': 1,
#  'Asitencia': 1,
#  'acto': 1,
#  'PESIMA': 1,
#  'acoso': 1,
#  'menor': 1,
#  'bus': 1,
#  'acceso': 1,
#  'convalidación': 1,
#  'módulo': 1,
#  'denegación': 1,
#  'REGISTRO': 1,
#  'conversión': 1,
#  'conversion': 1,
#  'relativo': 1,
#  'caso': 1,
#  'hija': 1,
#  'sufrido': 1,
#  'vacunación': 1,
#  'autobús': 1,
#  'estructura': 1,
#  'pasivo': 1,
#  'ciclo': 1,
#  'ceo': 1,
#  'reducción': 1,
#  'jornada': 1,
#  'universitario': 1,
#  'contestación': 1,
#  'malo': 1,
#  'educación': 1,
#  'recibido': 1,
#  'TASA': 1,
#  'GRAN  duque': 1,
#  'gran': 1,
#  'presencial': 1,
#  'participación': 1,
#  'presentación': 1,
#  'ingl': 1,
#  'atención': 1,
#  'listas': 1,
#  'casa': 1,
#  'alumno': 1,
#  'hora': 1,
#  'lectiva': 1,
#  'niño': 1,
#  'predoctoral': 1,
#  'personal': 1,
#  'RETRASO': 1,
#  'ESCOLAR': 1,
#  'Modelo': 1,
#  'tenemos': 1,
#  'PROCEDIMIENTO': 1,
#  'documento': 1,
#  'padre': 1,
#  'incidencia': 1,
#  'atencion': 1,
#  'deficiente': 1,
#  'ser': 1,
#  'estar': 1,
#  'cantar': 1,
#  'faltar': 1,
#  'peñarandir': 1,
#  'cierrir': 1,
#  'extracurricular': 1,
#  'hacer': 1,
#  'cumplir': 1,
#  'prestar': 1,
#  'su': 1,
#  'permitir': 1,
#  'compromisir': 1,
#  'garantizar': 1,
#  'enviar': 1,
#  'asistir': 1,
#  'apuntar': 1,
#  'figurar': 1,
#  'tener': 1,
#  'ir': 1}

# %%
kg_df = topicando.getSourceEdgeTargetEdgeDataFrame()
kg_df2 = topicando.getSourceEdgeTargetEdgeDataFrame(sourcesToSearch=["limpio","baño"])
print(kg_df[0:5])
print(kg_df2[0:5])
# Out:
#       source target   edge
# 0       beca  haber  haber
# 1    comedor  haber  haber
# 2   cuestión    ser    ser
# 3  rechazado    ser    ser
# 4    acuerdo  estar  estar
# Empty DataFrame
# Columns: [source, target, edge]
# Index: []

# %% [markdown]
# ## Html Output

# %%
from IPython.display import Javascript
import json

# %%
# %%javascript
# require.config({
#     packages: [{
#         name: 'highcharts',
#         main: 'highcharts'
#     }],
#     paths: {
#         'highcharts': 'https://code.highcharts.com',
#         'networkgraph': 'https://code.highcharts.com/modules/networkgraph.js'
#     }
# });

# %%
topicando.getSourcesTargetsArray()
# Out:
# [['beca', 'comedor'],
#  ['cuestión', 'rechazado'],
#  ['acuerdo', 'villancico'],
#  ['acuerdo', 'villancico'],
#  ['solicitud', 'tablet'],
#  ['trabajadores covid de peñarandir', 'trabajador'],
#  ['trabajadores covid de peñarandir', 'trabajador'],
#  ['interesado', 'trato'],
#  ['problema', 'centro'],
#  ['intersado', 'suspensión'],
#  ['fibra', 'óptico'],
#  ['informático', 'obsoleto'],
#  ['Programa', 'capacidad'],
#  ['cierre', 'centro'],
#  ['funcionamiento', 'motivo'],
#  ['Cierre  centro', 'inclemencia'],
#  ['queja', 'suspensión'],
#  ['RUTA', '-ceip'],
#  ['llamada', 'clase'],
#  ['teléfono', 'inadecuado'],
#  ['interesado', 'exposición'],
#  ['CEIP', 'obligación'],
#  ['comedor', 'escolar'],
#  ['desacuerdo', 'servicio'],
#  ['CURSO  bachillerato', 'curso'],
#  ['transporte', 'escolar'],
#  ['grado', 'SUPERIOR'],
#  ['administración', 'finanza'],
#  ['listado', 'provisional'],
#  ['programa', 'gratuidad'],
#  ['colegio', 'trabajadora'],
#  ['Asitencia', 'acto'],
#  ['acoso', 'escolar'],
#  ['menor', 'servicio'],
#  ['bus', 'acceso'],
#  ['convalidación', 'módulo'],
#  ['denegación', 'REGISTRO'],
#  ['relativo', 'información'],
#  ['caso', 'hija'],
#  ['sufrido', 'vacunación'],
#  ['autobús', 'alzador'],
#  ['autobús', 'alzador'],
#  ['estructura', 'pasivo'],
#  ['reducción', 'jornada'],
#  ['problema', 'tratar'],
#  ['problema', 'tratar'],
#  ['problema', 'tratar'],
#  ['acuerdo', 'contestación'],
#  ['malo', 'educación'],
#  ['escuela', 'infantil'],
#  ['GRAN  duque', 'gran'],
#  ['participación', 'programa'],
#  ['presentación', 'solicitud'],
#  ['escuela', 'infantil'],
#  ['escuela', 'infantil'],
#  ['escuela', 'infantil'],
#  ['atención', 'problema'],
#  ['casa', 'alumno'],
#  ['hora', 'lectiva'],
#  ['queja', 'niño'],
#  ['predoctoral', 'personal'],
#  ['RETRASO', 'ESCOLAR'],
#  ['Modelo', 'programa'],
#  ['tenemos', 'PROCEDIMIENTO'],
#  ['documento', 'padre'],
#  ['documento', 'padre'],
#  ['documento', 'padre'],
#  ['queja', 'información'],
#  ['atencion', 'deficiente']]

# %%
chart_data = []
nodes_filtered = []
for i in topicando.getSourcesTargetsArray():
    if i[0] not in nodes_filtered:
        nodes_filtered.append(i[0])
    if i[1] not in nodes_filtered:
        nodes_filtered.append(i[1])
    chart_data.append([i[0],i[1]])

Javascript("window.chartData={};".format(json.dumps(chart_data)))

# %%
topicando.getWordCountOfEntitiesAndRelations()
# Out:
# {'beca': 2,
#  'comedor': 2,
#  'cuestión': 1,
#  'rechazado': 1,
#  'acuerdo': 2,
#  'villancico': 1,
#  'solicitud': 4,
#  'tablet': 1,
#  'trabajadores covid de peñarandir': 1,
#  'trabajador': 1,
#  'interesado': 2,
#  'trato': 1,
#  'problema': 3,
#  'centro': 2,
#  'intersado': 1,
#  'suspensión': 2,
#  '': 41,
#  'fibra': 1,
#  'óptico': 1,
#  'italiano': 1,
#  'informático': 1,
#  'obsoleto': 1,
#  'Programa': 1,
#  'capacidad': 1,
#  'cierre': 1,
#  'funcionamiento': 1,
#  'motivo': 1,
#  'Cierre  centro': 1,
#  'inclemencia': 1,
#  'queja': 3,
#  'RUTA': 1,
#  '-ceip': 1,
#  'llamada': 1,
#  'clase': 1,
#  'cambio': 1,
#  'alzador': 2,
#  'teléfono': 1,
#  'inadecuado': 1,
#  'exposición': 1,
#  'conservatorio': 1,
#  'CEIP': 1,
#  'obligación': 1,
#  'escolar': 4,
#  'desacuerdo': 1,
#  'servicio': 2,
#  'error': 1,
#  'CURSO  bachillerato': 1,
#  'curso': 1,
#  'transporte': 1,
#  'RECIBIDO': 1,
#  'incidente': 1,
#  'grado': 1,
#  'SUPERIOR': 1,
#  'administración': 1,
#  'finanza': 1,
#  'religión': 1,
#  'listado': 1,
#  'provisional': 1,
#  'programa': 4,
#  'gratuidad': 1,
#  'colegio': 1,
#  'trabajadora': 1,
#  'Asitencia': 1,
#  'acto': 1,
#  'PESIMA': 1,
#  'acoso': 1,
#  'menor': 1,
#  'bus': 1,
#  'acceso': 1,
#  'convalidación': 1,
#  'módulo': 1,
#  'denegación': 1,
#  'REGISTRO': 1,
#  'conversión': 1,
#  'conversion': 1,
#  'relativo': 1,
#  'información': 2,
#  'caso': 1,
#  'hija': 1,
#  'sufrido': 1,
#  'vacunación': 1,
#  'autobús': 1,
#  'estructura': 1,
#  'pasivo': 1,
#  'ciclo': 1,
#  'ceo': 1,
#  'reducción': 1,
#  'jornada': 1,
#  'universitario': 1,
#  'tratar': 5,
#  'contestación': 1,
#  'malo': 1,
#  'educación': 1,
#  'recibido': 1,
#  'TASA': 1,
#  'escuela': 4,
#  'infantil': 4,
#  'GRAN  duque': 1,
#  'gran': 1,
#  'presencial': 1,
#  'participación': 1,
#  'presentación': 1,
#  'ingl': 1,
#  'atención': 1,
#  'listas': 1,
#  'casa': 1,
#  'alumno': 1,
#  'hora': 1,
#  'lectiva': 1,
#  'niño': 1,
#  'predoctoral': 1,
#  'personal': 1,
#  'RETRASO': 1,
#  'ESCOLAR': 1,
#  'Modelo': 1,
#  'tenemos': 1,
#  'PROCEDIMIENTO': 1,
#  'documento': 1,
#  'padre': 1,
#  'incidencia': 1,
#  'atencion': 1,
#  'deficiente': 1,
#  'haber': 71,
#  'ser': 1,
#  'estar': 1,
#  'cantar': 1,
#  'faltar': 1,
#  'peñarandir': 1,
#  'quejar': 2,
#  'cierrir': 1,
#  'solicitar': 2,
#  'extracurricular': 1,
#  'hacer': 1,
#  'cumplir': 1,
#  'prestar': 1,
#  'su': 1,
#  'permitir': 1,
#  'compromisir': 1,
#  'garantizar': 1,
#  'enviar': 1,
#  'asistir': 1,
#  'apuntar': 1,
#  'figurar': 1,
#  'tener': 1,
#  'ir': 1}

# %%
valMin = min([topicando.dictWords[word] for word in topicando.dictWords.keys() if word != '' and word in nodes_filtered])
valMax = max([topicando.dictWords[word] for word in topicando.dictWords.keys() if word != '' and word in nodes_filtered])

valMinNormalized = 5
valMaxNormalized = 50

# %%
nodes = []
for word in topicando.dictWords.keys():
    if word != '' and word in nodes_filtered:
        nodes.append({
            "id": word,
            "marker": {
                "count": topicando.dictWords[word],
                "radius": np.interp(topicando.dictWords[word],[valMin,valMax],[valMinNormalized,valMaxNormalized])
            }
        })

Javascript("window.nodes={};".format(json.dumps(nodes)))
Javascript("window.valMinNormalized=0;".format(json.dumps(valMinNormalized)))
Javascript("window.valMaxNormalized=0;".format(json.dumps(valMaxNormalized)))

# %%
# %%javascript
# // Since I append the div later, sometimes there are multiple divs.
# $("#container").remove();
#
# // Make the cdiv to contain the chart.
# element.append('<div id="container" style="min-width: 310px; min-height: 600px; margin: 0 auto"></div>');
#
# console.log("init");
# console.log(window.chartData);
# console.log(window.nodes);
#
# // Require highcarts and make the chart.
# require([
#     'highcharts',
#     'highcharts/modules/exporting',
#     'highcharts/modules/accessibility',
#     'highcharts/modules/networkgraph'
# ], function (Highcharts) {
#
#     console.log("WORKING");
#     $('#container').highcharts({
#         chart: {
#         type: 'networkgraph',
#         height: '100%'
#       },
#       title: {
#         text: ''
#       },
#       subtitle: {
#         text: ''
#       },
#         tooltip: {
#     formatter: function () {
#         console.log(this)
#       return "<b>" + this.key + "</b>: " + this.point.marker.count;
#     }
#   },
#       plotOptions: {
#         networkgraph: {
#           keys: ['from', 'to'],
#           layoutAlgorithm: {
#             enableSimulation: false,//true
#             friction: -0.9
#           }
#         }
#       },
#       series: [{
#           colorByPoint: true,
#         accessibility: {
#           enabled: false
#         },
#         dataLabels: {
#           enabled: true,
#           linkFormat: '',
#         },
#         id: 'lang-tree',
#         data: window.chartData,
#         nodes: window.nodes
#       }]
#     });
# });
