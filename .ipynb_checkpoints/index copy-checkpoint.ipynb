# %% [markdown]
# # Topicando (AlPHA)
# Topicando es un proyecto que busca ayudar a obtener los tópicos más comentados por un grupo de personas, obteniendo palabras clave en forma de ranking y grafos, para poder analizar necesidades, reclamos, comentarios, tendencias e ideas de la comunidad de forma masiva.
#
# En base a un array de frases como input se procesarán y analizarán los datos recolectados para poder tener un contexto de un tema de debate o discusión, siendo asi que:
# - Presenta en una lista ordenada de mayor a menor las palabras más utilizadas diferenciadas con stemming o lemmatizing
# - En base a las x palabras más usadas escogidas por estadistica o por número fijo, se crean clusters con KNN, KMeans, etc o solo con que contengan a esta palabra y se muestran grafos por cada palabra elegida como centroide
# - De cada cluster o agrupación se debe mostrar las palabras más usadas

# %% [markdown]
# ## Imports

# %%
import spacy
from unidecode import unidecode
from string import punctuation 
from nltk.corpus import stopwords
from collections import Counter
from spacy.matcher import Matcher 
from spacy.tokens import Span

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import scipy

# %%
nlp = spacy.load('es_core_news_md')

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Most Used Words

# %%
def getMostUsedWords(phrases, num):
    fullText = ""
    for phrase in phrases:
        fullText += (phrase + " ")
    doc = nlp(fullText)
    
    words = [token.text
        for token in doc
        if not token.is_stop and not token.is_punct]

    word_freq = Counter(words)
    common_words = word_freq.most_common(num)
    return common_words

def getMostUsedWordsLenma(phrases, num):
    fullText = ""
    for phrase in phrases:
        fullText += (str(phrase) + " ")
    doc = nlp(fullText)
    
    words = [token.lemma_
        for token in doc
        if not token.is_stop and not token.is_punct]

    word_freq = Counter(words)
    common_words = word_freq.most_common(num)
    return common_words

def getWordCount(words):
    dictWords = {}
    for word in words:
        if word not in dictWords.keys():
            dictWords[word] = 1
        else:
            dictWords[word] += 1
    return dictWords

# %% [markdown]
# ### Knowledge Graph

# %%
# No siempre son 2 entidades
def getEntities(phrases):
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    
  prv_tok_text = ""   

  prefix = ""
  modifier = ""

  prv_token = None

  print("TEXTO  LEMMA  POS  TAG  DEP  SHAPE")
  for tok in nlp(phrases):
    print(tok.text, tok.lemma_, tok.pos_, tok.tag_, tok.dep_, tok.shape_)
    #print(tok.text + " > " + tok.dep_ + " > " + tok.lemma_)
    if tok.dep_ != "punct":
      if tok.dep_ == "compound":
        prefix = tok.text
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      if (tok.dep_.find("subj") == True or tok.dep_ == "subj") and tok.pos_ != "PRON":
        ent1 = modifier + " " + prefix + " "+ tok.lemma_
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""   
      if tok.dep_.find("obj") == True:
        ent2 = modifier + " " + prefix + " " + tok.lemma_
      if tok.dep_ == "obj":
        ent2 = tok.lemma_
      if ent1.strip() == "" and ent2.find(tok.lemma_) == -1:
        print("ent1 que o perro >> ",tok.lemma_)
        if tok.dep_.find("mod") == True and tok.pos_ == "ADJ":
          ent1 = tok.lemma_
        if tok.pos_ == "NOUN":
          ent1 = tok.lemma_
      if ent2.strip() == "" and ent1.find(tok.lemma_) == -1:
        if tok.dep_.find("mod") == True and tok.pos_ == "ADJ":
          ent2 = tok.lemma_
        if tok.pos_ == "ADJ":
          ent2 = tok.lemma_
        if tok.pos_ == "NOUN":
          ent2 = tok.lemma_
        if (prv_token != None and prv_token.pos_ == "AUX") and (tok.pos_ == "VERB" or tok.pos_ == "ADJ"):
          ent2 = tok.lemma_
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
      prv_token = tok

  return [ent1.strip(), ent2.strip()]

# %%
# TRAER TAMBIEN UN ARRAY DE LOS DISTINTOS VERBOS Y SE USEN LOS 2
def getRelation(sent):
    doc = nlp(sent)

    # Matcher class object 
    matcher = Matcher(nlp.vocab)
 
    pattern2 = [
        {'POS':'VERB','OP':"?"},
        {'POS':'AUX','OP':"?"},
    ]

    #matcher.add("matching_1", [pattern, pattern2]) 
    matcher.add("matching_1", [pattern2]) 
    matches = matcher(doc)
    print(matches)

    if len(matches) == 0:
        return "haber"

    k = len(matches) - 1

    print(doc[matches[0][1]:matches[0][2]])
    print(doc[matches[k][1]:matches[k][2]])
    span = doc[matches[k][1]:matches[k][2]] 

    return(span.lemma_)

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('./sugerencias-y-quejas-de-los-ciudadanos (1).csv',delimiter=';')
data = data.dropna()
data[data['Referencia'].apply(lambda x: isinstance(x, (str, bytes)))]
data
# Out:
#            Tipo      Estado F.Solicitud Origen  \
# 0         Queja  Contestado  2021-12-29    WEB
# 1         Queja  Contestado  2021-12-23     12
# 2         Queja  Contestado  2021-12-22    WEB
# 3         Queja  Contestado  2021-12-20    WEB
# 4    Sugerencia  Contestado  2021-12-17     12
# ..          ...         ...         ...    ...
# 162       Queja  Contestado  2021-01-14    WEB
# 163       Queja  Contestado  2021-01-14     12
# 164       Queja  Contestado  2021-01-10  LIBRO
# 165       Queja  Contestado  2021-01-09    WEB
# 166       Queja  Contestado  2021-01-02  LIBRO
#
#                                      Unidad            Provincia  \
# 0    CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE                 LEÓN
# 1    CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE  SERVICIOS CENTRALES
# 2    CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE  SERVICIOS CENTRALES
# 3    CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE               ZAMORA
# 4    CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE  SERVICIOS CENTRALES
# ..                                      ...                  ...
# 162  CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE              SEGOVIA
# 163  CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE               BURGOS
# 164  CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE                 LEÓN
# 165  CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE  SERVICIOS CENTRALES
# 166  CONSEJERIA DE FOMENTO Y MEDIO AMBIENTE                 LEÓN
#
#                                             Referencia
# 0                       Falta de respuesta a solicitud
# 1    Notificaciones sin indicación del titular al q...
# 2    SOLICITA REVISIÓN DE ALTURA MÁXIMA DE EDIFICAC...
# 3    normas subsidiarias municikpales consistente e...
# 4                    BUZÓN NOTIFICACIONES ELECTRÓNICAS
# ..                                                 ...
# 162  El interesado se queja porque el autobús de la...
# 163                    No limpieza de carretera BU-945
# 164                              Normalidad Post-covid
# 165               Diámetro escaso tuberías agua ZA-925
# 166  Contestación urgente a solicitud formulada por...
#
# [167 rows x 7 columns]

# %%
phrases = [ phrase.lower() for phrase in data.iloc[:,6].values]
phrases
# Out:
# ['falta de respuesta a solicitud',
#  'notificaciones sin indicación del titular al que van dirigidas',
#  'solicita revisión de altura máxima de edificación en la cisterniga (vallladolid)',
#  'normas subsidiarias municikpales consistente en la modificacion el ambito desarrolo del area especial ae.ps-4 y re¡mision a la comision de urbanismo.',
#  'buzón notificaciones electrónicas',
#  'no funciona la máquina de bonos de transporte de la estación de autobuses',
#  'cita',
#  'incidencias en la carretera za-504, que ha sido recientemente rehabilitada',
#  'exigencia de uso de navegador internet explorer para trámites electrónicos',
#  'transporte a la demanda. merindades',
#  'no usar las mascarillas en el lugar de trabajo',
#  'señalización en entrada carretera a peñaranda de bracamonte',
#  'darse de alta en bec mediante sistema cl@ve',
#  'notificaciones electrónicas',
#  'que en medio ambiente no ha sido atendida.',
#  'queja relacionada con la presentada el día 8 noviembre 2021',
#  'falta de aviso en notificaciones electrónicas',
#  'paso peatonal',
#  'solicita mejora señalizacion horizontal cl 517',
#  'el interesa sugiere abaratar precios del transporte del tren de cercanías de segovia-madrid',
#  'reacondicionamiento camino navarredondilla a navatalgordo',
#  'no satisfecho con contestación envíada a queja anterior',
#  'modificación de normativa de pesca para el año 2022 para los embalses de pontón alto y puente alta (sg)',
#  'alegaciones a la plantilla de respuestas del primer ejercicio de la oposición para acceso al cuerpo de policía local',
#  'el interesado se queja de la eliminación de líneas de trasporte en santa mª la real de nieva',
#  'la interesada se queja de la supresión de líneas de transporte en santa mª la real de nieva',
#  'la interesada se queja de eliminación de líneas regulares de transporte público en santa mª la real de nieva',
#  'desacuerdo con asignación de cotos sobrantes de pesca en salamanca',
#  'rechazada y derivada a servicios centrales  por ser competencia del 112 (fomento y medio ambiente)',
#  'la interesada se queja de retrasos en la línea arévalo-nava de la asunción-segovia',
#  'mejora carretera cl-501 entrada pueblo la adrada',
#  'los pasales de madera del puente se encuentran en un estado ruinoso',
#  'el interesado teme riesgo de inundaciones por estado de puentes en madrona',
#  'obligacion relacionarse electrónicamente',
#  'se requiere contestación y aportación documentos relacionados en el "solicita" del escrito de 22 de noviembre de 2021',
#  'incumplimiento normativa de acampada',
#  'el interesado denuncia situcación de la ocupación por roturación de vias pecuarias',
#  'mal funcionamiento nuevo sistema de notificaciones electrónicas.',
#  'deasignación permiso arec',
#  'mejorar tramitación electrónica',
#  'mal funcionamiento formulario para presentar telematicamente para medioambiente valladolid',
#  'petición mejora plataformas junta cyl',
#  'colocación badenes',
#  'incorporar sistema cl@ve para trámites administrativos',
#  'limpieza cañada de ganado',
#  'solicitud de servicio de autobús a escuela capacitación agraria segovis',
#  'cierre camino vecinal',
#  'falta de información en notificaciones electrónicas',
#  'notificación electrónica. enlace al nuevo sistema de notificaciones',
#  'retraso autobus de santervas de campos',
#  'unificación criterios en sede electrónica',
#  'contaminación por actividades de combustión de pellets',
#  'cierre alerta 112 sin contactar con menor que llamó al 112',
#  'falta de vigilancia en zona de barbacoas en verano',
#  'queja por mal estado carretera tordillos',
#  'mejoras tecnológicas ámbito rural',
#  'imposibilidad contacto telefónico',
#  'señales de carretera incorrectas',
#  'el iteresado sugiere que se de una solución al estado, lamentable, de la carretera sg-322',
#  'malestar con con falta de resolución expresa de su solicitud',
#  'mal funcionamiento aplicacvión permisos pesca',
#  'supervisión e la calidad de las aguas del pantano de la cuerda del pozo',
#  'críticas a la exigencia de internet explorer en trámites administrativos',
#  'el interesado se queja porque se ha asfaltado mal un agujero en la carretera',
#  'cierre camino público',
#  'pide que atiendan de forma presencial',
#  'demora en otorgar vivienda proteccion oficial por violencia de género',
#  'registro de medio ambiente no está operativo a las 13.50 horas y no abren la puerta',
#  'la interesada propone nueva ubiación de los autobuses',
#  'atencion deficiente territorial de medio ambiente valladolid',
#  'reiteración mal estado rejilla crta. va-223',
#  'carteles aparcamiento carbanas playa pita',
#  'denuncia desafectacion parcelas ganadero  a medio ambiente.',
#  'no atención telefónica',
#  'mal estado de la señalización vertical en la bu-532',
#  'el interesado quiere que le envien el certificado de transporte por carretera',
#  'señal luminosa no funciona de noche',
#  'paso de camiones por carretera inapropiada',
#  'limpieza cunetas carretera cl-602',
#  'instalacion terraza muy cerca de la carretera za-925.',
#  'vehículo del servicio de medio ambiente que aparca en vado vecinal obstruyendo el paso',
#  'mal estado salida 36 a a-601',
#  'falta de atención en la sección de vivienda pública',
#  'problemas de conexión a internet',
#  'alta velocidad al atravesar la localidad.',
#  'la interesada se queja del retraso de la linea de nava de la asunción a segovia',
#  'errores a la hora de presentar declaración responsable de celebración de monterías y/o ganchos',
#  'falta de cuidado en puentes sobre las vías za-925 y za-921.',
#  'falta de luz en carretera autonomica',
#  'imposiblidad de conectarse a internet para renovación licencia de caza e imposibilidad de tramitación en ventanilla ya que está cerrada',
#  'notificaciones electrónicas',
#  'desacuerdo con asignación de permisos de pesca en ponferrada',
#  'mala conservación carretera fompedraza',
#  'poder hacer tramitación electrónica con certificado digital bajo sistema operativo debian (gnu-linux)',
#  'reclamación por la mala gestión de la administración en el arreglo de zona de acceso a explotación ganadera',
#  'limpieza solar',
#  'notificaciones buzón electrónico del ciudadano',
#  'solicita que se habilite la posibilidad de que un tercero pueda presentar documentación por otro solicitante en determinados trámites administrativos.',
#  'sanción de tráfico por práctica irregular de castellana de autopistas s.a.',
#  'no hay personal de medio ambiente en la planta baja y no está permitido subir',
#  'no servicio oficina caza y pesca (planta baja)',
#  'servicio precario e insuficiente transporte',
#  'falta de atención',
#  'falta de medios telemáticos para realizar junta arbitral de transportes',
#  'aclaración sobre legislación aplicable a requisitos para alquiler de vivienda',
#  'el sistema informatico no funciona',
#  'queja sobre medio ambiente y residuos',
#  'pinos existentes en el monte público lindantes con urbanización',
#  'protección contra incendios forestales. contestación a queja',
#  'disconformidad con la contestación dada a la q-14457',
#  'falta cobertura internet y telefonía móvil',
#  'incumplmiiento normativa medioambiental por la empresa kronospan',
#  'solicitud devolución pagos cotos pesca por cierre perimetral',
#  'solicita cambio localidad examen y otras cuestiones por puerperio',
#  'trato inadecuado por personal del 112',
#  'licencia ambiental',
#  'construcción velatorio en toral de los vados',
#  'sistema operativo móvil ios',
#  'el interesado pregunta por las obras de la cl-601',
#  'deficiencias en carril bici de la carretera de puente ducero',
#  'trato recibido en el 112',
#  'bu-562. falta barrera de protección',
#  'aumentar capacidad subir documentos en teletramitación',
#  'vertido de san en la parcela 79 pol 23 de almeida de sayago',
#  'mal estado de carretera',
#  'prtoblemas con mac en sede electrónica',
#  'atención inadecuada en el servicio de financiacion y ayudas a la vivienda',
#  'mal estado de la carretera autónomica cl-612 (carretera zamora villalpando) en el primer tramo desde la capital hasta aspariegos',
#  'falta contestación escrito',
#  'señalización comienzo pueblo',
#  'el interesado se quja del estado del firme de la carretera sg-723',
#  'peligrosidad en la carretera del espinar',
#  'certificadi competencias',
#  'la interesada se queja del estado de la carretera cl-607',
#  'trato inadecuado agente medioambiental',
#  'lal interesada se queja del mal estado de la cl 607',
#  'solicita poder realizar trámites con la administración pública de forma presencial',
#  'adopción de una estrategia de mantenimiento  de la carretera za-925 en periodo invernal.',
#  'la interesada se queja de retrasos en el transporte escolar',
#  'diversas cuestioones relativas a un proyecto de reparcelación',
#  'terraza con una verja perimetral atornillada a la carretera',
#  'requisito ite para ayudas rehabilitación de vivienda',
#  'mal estado márgenes río tormes',
#  'sugiere que se reanude la atención en la mesa habilitada al efecto',
#  'información insuficiente para anulación permisos pesca',
#  'devolución importe licencia de caza temporada 2020/2021',
#  'la interesada se queja de aglomeraciones en el autobús',
#  'imposibilidad de hacer el trámite electrónicamente',
#  'el interesado sugiere catalogar la zona de cosntanzana y protegerla y evitar prácticas agrícolas',
#  'falta de contestación y actuación en queja sobre reparación alcantarilla en ctra. va-223 en fompedraza',
#  'horario de clases de curso del cap en miranda de ebro',
#  'queja actuaciones cámara propiedad urbana fianza',
#  'falta de señalización de escalón en aparcamietno del parque natural laguna negra y circos glaciares de urbión',
#  'no ha sido atendido presencialmente en fomento.',
#  'dificultad en tramitación electrónica para solicitar tarjeta club de los 60',
#  'derecho a trámites electrónicos',
#  'queja sobre nuevo sistema de elección de cotos.',
#  'cebos utilizados para pesca',
#  'mal funcionamiento de aplicación de subvención iapa 3065',
#  'reserva de fecha para cotos de pesca de villafeliz (león)',
#  'solicita devolución del importe de permisos de cotos',
#  'la interesada se queja de la prestación del servicio de la ruta escolar de su hijo',
#  'el interesado se queja porque el autobús de la línea 5 del servicio metropolitano no llegó los días 2 y 4 de enero e',
#  'no limpieza de carretera bu-945',
#  'normalidad post-covid',
#  'diámetro escaso tuberías agua za-925',
#  'contestación urgente a solicitud formulada por correo electrónico el día 21 de enero de 2021']

# %%
#print(phrases)
print(getMostUsedWords(phrases,10))
print(getMostUsedWordsLenma(phrases,10))
# Out:
# [('escolar', 13), ('cierre', 7), ('ceip', 6), ('infantil', 6), ('solicitud', 5), ('ies', 5), ('queja', 5), ('trato', 5), ('transporte', 5), ('programa', 5)]
# [('escolar', 14), ('centro', 7), ('cerrar', 6), ('ceip', 6), ('programa', 6), ('infantil', 6), ('comedor', 5), ('solicitud', 5), ('ies', 5), ('quejar', 5)]

# %%
for phrase in phrases:
    print(phrase)
    print(getEntities(phrase))
    print(getRelation(phrase))
    print("\n")
# Out:
# ayudas becas comedor centros docentes concertados
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ayudas ayuda NOUN NOUN ROOT xxxx
# ent1 que o perro >>  ayuda
# becas beca ADJ ADJ amod xxxx
# comedor comedor NOUN NOUN amod xxxx
# centros centro NOUN NOUN appos xxxx
# docentes docente ADJ ADJ amod xxxx
# concertados concertado ADJ ADJ amod xxxx
# ['ayuda', 'beca']
# []
# haber
#
#
# rechazado por ser cuestión de la consejería de educación. becas
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# rechazado rechazado ADJ ADJ ROOT xxxx
# ent1 que o perro >>  rechazado
# por por ADP ADP mark xxx
# ent1 que o perro >>  por
# ser ser AUX AUX cop xxx
# ent1 que o perro >>  ser
# cuestión cuestión NOUN NOUN xcomp xxxx
# ent1 que o perro >>  cuestión
# de de ADP ADP case xx
# la el DET DET det xx
# consejería consejería NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# educación educación NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# becas beca NOUN NOUN ROOT xxxx
# ['cuestión', 'rechazado']
# [(11840699188806025751, 2, 3)]
# ser
# ser
# ser
#
#
# no está de acuerdo con cantar villancicos en las fiestas de navidad en el colegio
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# está estar AUX AUX cop xxxx
# ent1 que o perro >>  estar
# de de ADP ADP ROOT xx
# ent1 que o perro >>  de
# acuerdo acuerdo NOUN NOUN fixed xxxx
# ent1 que o perro >>  acuerdo
# con con ADP ADP mark xxx
# cantar cantar VERB VERB advcl xxxx
# villancicos villancico NOUN NOUN obj xxxx
# en en ADP ADP case xx
# las el DET DET det xxx
# fiestas fiesta NOUN NOUN obl xxxx
# de de ADP ADP case xx
# navidad navidad NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# colegio colegio NOUN NOUN obl xxxx
# ['acuerdo', 'villancico']
# [(11840699188806025751, 1, 2), (11840699188806025751, 5, 6)]
# está
# cantar
# cantar
#
#
# solicitud de tablets por medios electronicos
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicitud solicitud NOUN NOUN ROOT xxxx
# ent1 que o perro >>  solicitud
# de de ADP ADP case xx
# tablets tablet NOUN NOUN nmod xxxx
# por por ADP ADP case xxx
# medios medio NOUN NOUN nmod xxxx
# electronicos electronico ADJ ADJ amod xxxx
# ['solicitud', 'tablet']
# []
# haber
#
#
# falta vacuna covid de tres trabajadores ies peñaranda
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta faltar VERB VERB ROOT xxxx
# ent1 que o perro >>  faltar
# vacuna vacuna NOUN NOUN nsubj xxxx
# covid covid PROPN PROPN compound xxxx
# de de ADP ADP case xx
# tres tres NUM NUM nummod xxxx
# trabajadores trabajador NOUN NOUN nmod xxxx
# ies ies ADJ ADJ compound xxx
# peñaranda peñarandir VERB VERB nsubj xxxx
# ['trabajadores ies peñarandir', 'trabajador']
# [(11840699188806025751, 0, 1), (11840699188806025751, 7, 8)]
# falta
# peñaranda
# peñarandir
#
#
# la interesada se queja del trato inadecuado
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# del del ADP ADP case xxx
# trato trato NOUN NOUN obj xxxx
# inadecuado inadecuado ADJ ADJ amod xxxx
# ['interesado', 'trato']
# [(11840699188806025751, 3, 4)]
# queja
# queja
# quejar
#
#
# problemas conciliacoón cierre centros inclmencias meteorológicas 11 enero
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# problemas problema NOUN NOUN ROOT xxxx
# ent1 que o perro >>  problema
# conciliacoón conciliacoón ADJ ADJ amod xxxx
# cierre cerrar VERB VERB amod xxxx
# centros centro NOUN NOUN nmod xxxx
# inclmencias inclmencia ADJ ADJ amod xxxx
# meteorológicas meteorológico ADJ ADJ amod xxxx
# 11 11 NUM NUM nummod dd
# enero enero NOUN NOUN nmod xxxx
# ['problema', 'conciliacoón']
# [(11840699188806025751, 2, 3)]
# cierre
# cierre
# cerrar
#
#
# el intersado solicita suspensión temporal de clases presnciales
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# intersado intersado ADJ ADJ nsubj xxxx
# solicita solicitar VERB VERB ROOT xxxx
# suspensión suspensión NOUN NOUN obj xxxx
# temporal temporal ADJ ADJ amod xxxx
# de de ADP ADP case xx
# clases clase NOUN NOUN nmod xxxx
# presnciales presncial ADJ ADJ amod xxxx
# ['intersado', 'suspensión']
# [(11840699188806025751, 2, 3)]
# solicita
# solicita
# solicitar
#
#
# deficiencias transporte escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# deficiencias deficiencia NOUN NOUN ROOT xxxx
# ent1 que o perro >>  deficiencia
# transporte transporte NOUN NOUN amod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['deficiencia', 'transporte']
# []
# haber
#
#
# ies diego de praves
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ies ies PROPN PROPN ROOT xxx
# ent1 que o perro >>  ies
# diego diego PROPN PROPN flat xxxx
# ent1 que o perro >>  diego
# de de ADP ADP case xx
# ent1 que o perro >>  de
# praves prav NOUN NOUN flat xxxx
# ent1 que o perro >>  prav
# ['prav', '']
# []
# haber
#
#
# fibra óptica ceip la palomera
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# fibra fibra NOUN NOUN ROOT xxxx
# ent1 que o perro >>  fibra
# óptica óptico ADJ ADJ amod xxxx
# ceip ceip PROPN PROPN appos xxxx
# la el DET DET det xx
# palomera palomera NOUN NOUN ROOT xxxx
# ['fibra', 'óptico']
# []
# haber
#
#
# profesor italiano eoi burgos
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# profesor profesor NOUN NOUN ROOT xxxx
# ent1 que o perro >>  profesor
# italiano italiano ADJ ADJ amod xxxx
# eoi eoi PROPN PROPN appos xxx
# burgos burgo ADJ ADJ amod xxxx
# ['profesor', 'italiano']
# []
# haber
#
#
# programas informáticos obsoletos
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# programas programa NOUN NOUN ROOT xxxx
# ent1 que o perro >>  programa
# informáticos informático ADJ ADJ amod xxxx
# obsoletos obsoleto ADJ ADJ amod xxxx
# ['programa', 'informático']
# []
# haber
#
#
# programa extracurricular altas capacidades.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# programa programa NOUN NOUN ROOT xxxx
# ent1 que o perro >>  programa
# extracurricular extracurricular ADJ ADJ amod xxxx
# altas alto ADJ ADJ amod xxxx
# capacidades capacidad NOUN NOUN appos xxxx
# . . PUNCT PUNCT punct .
# ['programa', 'extracurricular']
# []
# haber
#
#
# cierre del centro educativo por situación climatológtica
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cierre cierre NOUN NOUN ROOT xxxx
# ent1 que o perro >>  cierre
# del del ADP ADP case xxx
# centro centro NOUN NOUN nmod xxxx
# educativo educativo ADJ ADJ amod xxxx
# por por ADP ADP case xxx
# situación situación NOUN NOUN nmod xxxx
# climatológtica climatológtico ADJ ADJ amod xxxx
# ['cierre', 'centro']
# []
# haber
#
#
# funcionamiento del colegio con motivo de las inclemencias meterorológicas
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# funcionamiento funcionamiento NOUN NOUN ROOT xxxx
# ent1 que o perro >>  funcionamiento
# del del ADP ADP case xxx
# colegio colegio NOUN NOUN nmod xxxx
# con con ADP ADP case xxx
# motivo motivo NOUN NOUN fixed xxxx
# de de ADP ADP fixed xx
# las el DET DET det xxx
# inclemencias inclemencia NOUN NOUN nmod xxxx
# meterorológicas meterorológica ADJ ADJ amod xxxx
# ['funcionamiento', 'colegio']
# []
# haber
#
#
# cierre centros inclemencias meteorológicas
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cierre cerrar VERB VERB amod xxxx
# ent1 que o perro >>  cerrar
# centros centro NOUN NOUN ROOT xxxx
# ent1 que o perro >>  centro
# inclemencias inclemencia ADJ ADJ amod xxxx
# meteorológicas meteorológico ADJ ADJ amod xxxx
# ['centro', 'inclemencia']
# [(11840699188806025751, 0, 1)]
# cierre
# cierre
# cerrar
#
#
# queja por suspensión de clases debido por la meteorología
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja queja NOUN NOUN ROOT xxxx
# ent1 que o perro >>  queja
# por por ADP ADP case xxx
# suspensión suspensión NOUN NOUN obl xxxx
# de de ADP ADP case xx
# clases clase NOUN NOUN nmod xxxx
# debido debido ADJ ADJ case xxxx
# por por ADP ADP fixed xxx
# la el DET DET det xx
# meteorología meteorología NOUN NOUN obl xxxx
# ['queja', 'suspensión']
# []
# haber
#
#
# modificacion ruta escolar ceip parque alameda -ceip el peral-pinar de jalón
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# modificacion modificacion PROPN PROPN ROOT xxxx
# ent1 que o perro >>  modificacion
# ruta ruta NOUN NOUN flat xxxx
# ent1 que o perro >>  ruta
# escolar escolar ADJ ADJ amod xxxx
# ceip ceip PROPN PROPN flat xxxx
# parque parque PROPN PROPN flat xxxx
# alameda alameda PROPN PROPN flat xxxx
# -ceip -ceip PROPN PROPN flat -xxxx
# el el DET DET det xx
# peral-pinar peral-pinar NOUN NOUN appos xxxx-xxxx
# de de ADP ADP case xx
# jalón jalón NOUN NOUN nmod xxxx
# ['ruta', 'escolar']
# []
# haber
#
#
# llamada de clases pasivas a la jubilacion de la intersada
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# llamada llamado ADJ ADJ ROOT xxxx
# ent1 que o perro >>  llamado
# de de ADP ADP case xx
# ent1 que o perro >>  de
# clases clase NOUN NOUN obj xxxx
# pasivas pasivo ADJ ADJ amod xxxx
# ent1 que o perro >>  pasivo
# a a ADP ADP case x
# la el DET DET det xx
# jubilacion jubilacion PROPN PROPN obj xxxx
# de de ADP ADP case xx
# la el DET DET fixed xx
# intersada intersada NOUN NOUN nmod xxxx
# ['pasivo', 'jubilacion']
# []
# haber
#
#
# cambio ruta transporte escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cambio cambio NOUN NOUN ROOT xxxx
# ent1 que o perro >>  cambio
# ruta ruta NOUN NOUN nmod xxxx
# transporte transporte NOUN NOUN amod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['cambio', 'ruta']
# []
# haber
#
#
# alzador en autobus escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# alzador alzador NOUN NOUN ROOT xxxx
# ent1 que o perro >>  alzador
# en en ADP ADP case xx
# autobus autobus NOUN NOUN nmod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['alzador', 'autobus']
# []
# haber
#
#
# trato inadecuado e irrespetuoso por teléfono.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# inadecuado inadecuado ADJ ADJ amod xxxx
# e e CCONJ CCONJ cc x
# irrespetuoso irrespetuoso ADJ ADJ conj xxxx
# por por ADP ADP case xxx
# teléfono teléfono NOUN NOUN obl xxxx
# . . PUNCT PUNCT punct .
# ['trato', 'inadecuado']
# []
# haber
#
#
# la interesada hace una exposición de la formación profesional
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ ROOT xxxx
# ent1 que o perro >>  interesado
# hace hacer VERB VERB advcl xxxx
# ent1 que o perro >>  hacer
# una uno DET DET det xxx
# ent1 que o perro >>  uno
# exposición exposición NOUN NOUN obj xxxx
# de de ADP ADP case xx
# ent1 que o perro >>  de
# la el DET DET det xx
# ent1 que o perro >>  el
# formación formación NOUN NOUN nmod xxxx
# ent1 que o perro >>  formación
# profesional profesional ADJ ADJ amod xxxx
# ['formación', 'exposición']
# [(11840699188806025751, 2, 3)]
# hace
# hace
# hacer
#
#
# solicitud beca conservatorio
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicitud solicitud NOUN NOUN ROOT xxxx
# ent1 que o perro >>  solicitud
# beca beca NOUN NOUN amod xxxx
# conservatorio conservatorio ADJ ADJ amod xxxx
# ['solicitud', 'beca']
# []
# haber
#
#
# ceip santa maría de aranda de duero no cumple con obligaciones
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ceip ceip PROPN PROPN nsubj xxxx
# santa santa PROPN PROPN flat xxxx
# maría maría PROPN PROPN flat xxxx
# de de ADP ADP case xx
# aranda aranda PROPN PROPN nmod xxxx
# de de ADP ADP case xx
# duero duero NOUN NOUN flat xxxx
# no no ADV ADV advmod xx
# cumple cumplir VERB VERB ROOT xxxx
# con con ADP ADP case xxx
# obligaciones obligación NOUN NOUN obj xxxx
# ['ceip', 'obligación']
# [(11840699188806025751, 8, 9)]
# cumple
# cumple
# cumplir
#
#
# servicio de comedor escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# servicio servicio NOUN NOUN ROOT xxxx
# ent1 que o perro >>  servicio
# de de ADP ADP case xx
# comedor comedor NOUN NOUN nmod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['servicio', 'comedor']
# []
# haber
#
#
# desacuerdo no prestar servicio continuadores
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# desacuerdo desacuerdo NOUN NOUN ROOT xxxx
# ent1 que o perro >>  desacuerdo
# no no ADV ADV advmod xx
# prestar prestar VERB VERB csubj xxxx
# servicio servicio NOUN NOUN obj xxxx
# continuadores continuador ADJ ADJ amod xxxx
# ['no  prestar', 'servicio']
# [(11840699188806025751, 2, 3)]
# prestar
# prestar
# prestar
#
#
# error en citacion vacuna covid
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# error error NOUN NOUN ROOT xxxx
# ent1 que o perro >>  error
# en en ADP ADP case xx
# citacion citacion PROPN PROPN nmod xxxx
# vacuna vacunir VERB VERB case xxxx
# covid covid PROPN PROPN nmod xxxx
# ['error', '']
# [(11840699188806025751, 3, 4)]
# vacuna
# vacuna
# vacunir
#
#
# vacunacion covid-19
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# vacunacion vacunacion PROPN PROPN ROOT xxxx
# ent1 que o perro >>  vacunacion
# covid-19 covid-19 PROPN PROPN flat xxxx-dd
# ent1 que o perro >>  covid-19
# ['', '']
# []
# haber
#
#
# problemas con curso bachillerato en su modelo a distancia
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# problemas problema NOUN NOUN ROOT xxxx
# ent1 que o perro >>  problema
# con con ADP ADP case xxx
# curso curso NOUN NOUN nmod xxxx
# bachillerato bachillerato ADJ ADJ amod xxxx
# en en ADP ADP case xx
# su su DET DET det xx
# modelo modelo NOUN NOUN nmod xxxx
# a a ADP ADP case x
# distancia distancia NOUN NOUN nmod xxxx
# ['problema', 'curso']
# []
# haber
#
#
# beca f.p.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# beca beca NOUN NOUN ROOT xxxx
# ent1 que o perro >>  beca
# f.p f.p PROPN PROPN obj x.x
# . . PUNCT PUNCT punct .
# ['beca', 'f.p']
# []
# haber
#
#
# irregularidades en el transporte escolar. ies merindades de castilla
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# irregularidades irregularidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  irregularidad
# en en ADP ADP case xx
# el el DET DET det xx
# transporte transporte NOUN NOUN nmod xxxx
# escolar escolar ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ies ies NOUN NOUN ROOT xxx
# merindades merindad NOUN NOUN flat xxxx
# de de ADP ADP case xx
# castilla castilla PROPN PROPN nmod xxxx
# ['irregularidad', 'transporte']
# []
# haber
#
#
# covid - 19
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# covid covid PROPN PROPN ROOT xxxx
# ent1 que o perro >>  covid
# - - PUNCT PUNCT punct -
# 19 19 NUM NUM nummod dd
# ent1 que o perro >>  19
# ['', '']
# []
# haber
#
#
# comerdor escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# comerdor comerdor VERB VERB ROOT xxxx
# ent1 que o perro >>  comerdor
# escolar escolar ADJ ADJ amod xxxx
# ent1 que o perro >>  escolar
# ['escolar', '']
# [(11840699188806025751, 0, 1)]
# comerdor
# comerdor
# comerdor
#
#
# ceip pablo picasso - carbajosa la sagrada
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ceip ceip PROPN PROPN ROOT xxxx
# ent1 que o perro >>  ceip
# pablo pablo PROPN PROPN flat xxxx
# ent1 que o perro >>  pablo
# picasso picasso PROPN PROPN flat xxxx
# ent1 que o perro >>  picasso
# - - PUNCT PUNCT punct -
# carbajosa carbajós ADJ ADJ amod xxxx
# ent1 que o perro >>  carbajós
# la el DET DET det xx
# sagrada sagrado ADJ ADJ amod xxxx
# ['carbajós', 'sagrado']
# []
# haber
#
#
# trato recibido por ordenanza instituto
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# recibido recibido ADJ ADJ amod xxxx
# por por ADP ADP case xxx
# ordenanza ordenanza NOUN NOUN obl xxxx
# instituto instituto NOUN NOUN punct xxxx
# ['trato', 'recibido']
# []
# haber
#
#
# incidente en guardería de grijota
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# incidente incidente NOUN NOUN ROOT xxxx
# ent1 que o perro >>  incidente
# en en ADP ADP case xx
# guardería guardería NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# grijota grijota PROPN PROPN nmod xxxx
# ['incidente', 'guardería']
# []
# haber
#
#
# ies ordoño ii - grado superior distancia
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ies ies NOUN NOUN ROOT xxx
# ent1 que o perro >>  ies
# ordoño ordoño PROPN PROPN flat xxxx
# ii ii PROPN PROPN flat xx
# - - PUNCT PUNCT punct -
# grado grado NOUN NOUN appos xxxx
# superior superior ADJ ADJ amod xxxx
# distancia distancia NOUN NOUN appos xxxx
# ['ies', 'grado']
# []
# haber
#
#
# ies alonso de madrigal c.g.s. administración y finanzas semipresencial
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ies ies PROPN PROPN ROOT xxx
# ent1 que o perro >>  ies
# alonso alonso PROPN PROPN flat xxxx
# ent1 que o perro >>  alonso
# de de ADP ADP case xx
# ent1 que o perro >>  de
# madrigal madrigal PROPN PROPN nmod xxxx
# ent1 que o perro >>  madrigal
# c.g.s c.g.s PROPN PROPN flat x.x.x
# ent1 que o perro >>  c.g.s
# . . PUNCT PUNCT punct .
# administración administración NOUN NOUN ROOT xxxx
# ent1 que o perro >>  administración
# y y CCONJ CCONJ cc x
# finanzas finanza NOUN NOUN conj xxxx
# semipresencial semipresencial ADJ ADJ amod xxxx
# ['administración', 'finanza']
# []
# haber
#
#
# religión
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# religión religión NOUN NOUN ROOT xxxx
# ent1 que o perro >>  religión
# ['religión', '']
# []
# haber
#
#
# listados provisionales adminiso e.e.i.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# listados listado NOUN NOUN ROOT xxxx
# ent1 que o perro >>  listado
# provisionales provisional ADJ ADJ amod xxxx
# adminiso adminiso ADJ ADJ amod xxxx
# e.e.i e.e.i PROPN PROPN obj x.x.x
# . . PUNCT PUNCT punct .
# ['listado', 'e.e.i']
# []
# haber
#
#
# programa de gratuidad de libros de texto releo plus.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# programa programa NOUN NOUN ROOT xxxx
# ent1 que o perro >>  programa
# de de ADP ADP case xx
# gratuidad gratuidad NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# libros libro NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# texto texto NOUN NOUN nmod xxxx
# releo releer VERB VERB appos xxxx
# plus plus PROPN PROPN flat xxxx
# . . PUNCT PUNCT punct .
# ['programa', 'gratuidad']
# [(11840699188806025751, 7, 8)]
# releo
# releo
# releer
#
#
# trato recibido por una trabajadora del colegio teresa de león de ibeas de juarros
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# recibido recibido ADJ ADJ amod xxxx
# por por ADP ADP case xxx
# una uno DET DET det xxx
# trabajadora trabajadora NOUN NOUN obj xxxx
# del del ADP ADP case xxx
# colegio colegio NOUN NOUN nmod xxxx
# teresa teresa PROPN PROPN appos xxxx
# de de ADP ADP case xx
# león león NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# ibeas ibea NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# juarros juarro NOUN NOUN nmod xxxx
# ['trato', 'trabajadora']
# []
# haber
#
#
# asitencia acto graduación infantil.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# asitencia asitencia NOUN NOUN nsubj xxxx
# acto acto VERB VERB ROOT xxxx
# graduación graduación NOUN NOUN obj xxxx
# infantil infantil ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['asitencia', 'graduación']
# [(11840699188806025751, 1, 2)]
# acto
# acto
# acto
#
#
# pesima atencion telefonica
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# pesima pesimo ADJ ADJ amod xxxx
# ent1 que o perro >>  pesimo
# atencion atencion PROPN PROPN ROOT xxxx
# telefonica telefonica PROPN PROPN flat xxxx
# ['pesimo', '']
# []
# haber
#
#
# acoso escolar menor de 3 años.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# acoso acoso NOUN NOUN ROOT xxxx
# ent1 que o perro >>  acoso
# escolar escolar ADJ ADJ amod xxxx
# menor menor ADJ ADJ amod xxxx
# de de ADP ADP case xx
# 3 3 NUM NUM nummod d
# años año NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# ['acoso', 'escolar']
# []
# haber
#
#
# información menores servicio comedor.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# información información NOUN NOUN ROOT xxxx
# ent1 que o perro >>  información
# menores menor ADJ ADJ amod xxxx
# servicio servicio NOUN NOUN nmod xxxx
# comedor comedor ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['información', 'menor']
# []
# haber
#
#
# no le permiten acceso al bus escolar en parada distinta a la habitual
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# le él PRON PRON obj xx
# permiten permitir VERB VERB ROOT xxxx
# ent1 que o perro >>  permitir
# acceso acceso NOUN NOUN obj xxxx
# al al ADP ADP case xx
# ent1 que o perro >>  al
# bus bus NOUN NOUN nmod xxx
# ent1 que o perro >>  bus
# escolar escolar ADJ ADJ amod xxxx
# en en ADP ADP case xx
# parada parada NOUN NOUN nmod xxxx
# distinta distinto ADJ ADJ amod xxxx
# a a ADP ADP case x
# la el DET DET fixed xx
# habitual habitual ADJ ADJ ROOT xxxx
# ['bus', 'acceso']
# [(11840699188806025751, 2, 3)]
# permiten
# permiten
# permitir
#
#
# pcr
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# pcr pcr PROPN PROPN ROOT xxx
# ent1 que o perro >>  pcr
# ['', '']
# []
# haber
#
#
# convalidación módulos administración electrónica.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# convalidación convalidación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  convalidación
# módulos módulo NOUN NOUN appos xxxx
# administración administración NOUN NOUN flat xxxx
# electrónica electrónico ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['convalidación', 'módulo']
# []
# haber
#
#
# denegación registro escrito
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# denegación denegación ADJ ADJ amod xxxx
# ent1 que o perro >>  denegación
# registro registro NOUN NOUN ROOT xxxx
# escrito escrito ADJ ADJ amod xxxx
# ['denegación', 'registro']
# []
# haber
#
#
# conversión centro al bilingüismo
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# conversión conversión NOUN NOUN ROOT xxxx
# ent1 que o perro >>  conversión
# centro centro NOUN NOUN nmod xxxx
# al al ADP ADP case xx
# bilingüismo bilingüismo NOUN NOUN nmod xxxx
# ['conversión', 'centro']
# []
# haber
#
#
# conversion centro al bilingüismo
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# conversion conversion PROPN PROPN ROOT xxxx
# ent1 que o perro >>  conversion
# centro centro PROPN PROPN flat xxxx
# ent1 que o perro >>  centro
# al al ADP ADP case xx
# ent1 que o perro >>  al
# bilingüismo bilingüismo NOUN NOUN nmod xxxx
# ent1 que o perro >>  bilingüismo
# ['bilingüismo', '']
# []
# haber
#
#
# solicitan información relativa a criterior para desdoble de aulas
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicitan solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# información información NOUN NOUN nsubj xxxx
# relativa relativo ADJ ADJ amod xxxx
# a a ADP ADP case x
# criterior criterior NOUN NOUN nmod xxxx
# para para ADP ADP case xxxx
# desdoble desdoble ADJ ADJ nmod xxxx
# de de ADP ADP case xx
# aulas aula NOUN NOUN nmod xxxx
# ['información', 'relativo']
# [(11840699188806025751, 0, 1)]
# solicitan
# solicitan
# solicitar
#
#
# revision caso su hija
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# revision revision NOUN NOUN ROOT xxxx
# ent1 que o perro >>  revision
# caso caso ADV ADV amod xxxx
# su su DET DET det xx
# hija hija NOUN NOUN ROOT xxxx
# ['revision', 'hija']
# []
# haber
#
#
# nadie le ayuda sobre competencias digitales
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# nadie nadie PRON PRON nsubj xxxx
# ent1 que o perro >>  nadie
# le él PRON PRON obj xx
# ayuda ayudar VERB VERB ROOT xxxx
# ent1 que o perro >>  ayudar
# sobre sobre ADP ADP case xxxx
# ent1 que o perro >>  sobre
# competencias competencia NOUN NOUN nmod xxxx
# ent1 que o perro >>  competencia
# digitales digital ADJ ADJ amod xxxx
# ['competencia', 'él']
# [(11840699188806025751, 2, 3)]
# ayuda
# ayuda
# ayudar
#
#
# discriminación sufrida en la vacunación contra la covid 19
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# discriminación discriminación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  discriminación
# sufrida sufrido ADJ ADJ amod xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# vacunación vacunación NOUN NOUN obl xxxx
# contra contra ADP ADP case xxxx
# la el DET DET det xx
# covid covid PROPN PROPN nmod xxxx
# 19 19 NUM NUM nummod dd
# ['discriminación', 'sufrido']
# []
# haber
#
#
# no compromiso en garantizar alzador en autobús empresa transporte escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# compromiso compromisir VERB VERB ROOT xxxx
# ent1 que o perro >>  compromisir
# en en ADP ADP mark xx
# ent1 que o perro >>  en
# garantizar garantizar VERB VERB xcomp xxxx
# ent1 que o perro >>  garantizar
# alzador alzador NOUN NOUN obj xxxx
# en en ADP ADP case xx
# ent1 que o perro >>  en
# autobús autobús NOUN NOUN obj xxxx
# empresa empresa NOUN NOUN nmod xxxx
# ent1 que o perro >>  empresa
# transporte transporte NOUN NOUN amod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['empresa', 'autobús']
# [(11840699188806025751, 1, 2), (11840699188806025751, 3, 4)]
# compromiso
# garantizar
# garantizar
#
#
# estructura pasiva en libros texto ingles
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# estructura estructura NOUN NOUN ROOT xxxx
# ent1 que o perro >>  estructura
# pasiva pasivo ADJ ADJ amod xxxx
# en en ADP ADP case xx
# libros libro NOUN NOUN nmod xxxx
# texto texto ADJ ADJ amod xxxx
# ingles ingl ADJ ADJ amod xxxx
# ['estructura', 'pasivo']
# []
# haber
#
#
# solcitudes ciclo fp
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solcitudes solcitud ADJ ADJ amod xxxx
# ent1 que o perro >>  solcitud
# ciclo ciclo NOUN NOUN ROOT xxxx
# fp fp PROPN PROPN appos xx
# ['solcitud', 'ciclo']
# []
# haber
#
#
# ceo atenea bilingüe
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ceo ceo PROPN PROPN nsubj xxx
# atenea atenear VERB VERB ROOT xxxx
# bilingüe bilingüe PROPN PROPN obj xxxx
# ['ceo', 'bilingüe']
# [(11840699188806025751, 1, 2)]
# atenea
# atenea
# atenear
#
#
# reducción jornada escolar junio y septiembre.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# reducción reducción NOUN NOUN ROOT xxxx
# ent1 que o perro >>  reducción
# jornada jornada NOUN NOUN amod xxxx
# escolar escolar ADJ ADJ amod xxxx
# junio junio NOUN NOUN appos xxxx
# y y CCONJ CCONJ cc x
# septiembre septiembre NOUN NOUN conj xxxx
# . . PUNCT PUNCT punct .
# ['reducción', 'jornada']
# []
# haber
#
#
# recogida titulo universitaria uemc
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# recogida recogido ADJ ADJ amod xxxx
# ent1 que o perro >>  recogido
# titulo titulo NOUN NOUN ROOT xxxx
# universitaria universitario ADJ ADJ amod xxxx
# uemc uemc NOUN NOUN ROOT xxxx
# ['recogido', 'titulo']
# []
# haber
#
#
# la interesada se queja por cómo se ha tratado el problema de un accidente de su hijo en el instituto
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# por por ADP ADP case xxx
# cómo cómo PRON PRON obl xxxx
# se él PRON PRON expl:pass xx
# ha haber AUX AUX aux xx
# tratado tratar VERB VERB advcl xxxx
# el el DET DET det xx
# problema problema NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# un uno DET DET det xx
# accidente accidente NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# su su DET DET det xx
# hijo hijo NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# instituto instituto NOUN NOUN obl xxxx
# ['problema', 'tratar']
# [(11840699188806025751, 3, 4), (11840699188806025751, 7, 8), (11840699188806025751, 8, 9)]
# queja
# tratado
# tratar
#
#
# no esta de acuerdo con la contestación
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# esta este PRON PRON ROOT xxxx
# ent1 que o perro >>  este
# de de ADP ADP advmod xx
# ent1 que o perro >>  de
# acuerdo acuerdo NOUN NOUN fixed xxxx
# ent1 que o perro >>  acuerdo
# con con ADP ADP fixed xxx
# la el DET DET det xx
# contestación contestación NOUN NOUN nmod xxxx
# ['acuerdo', 'contestación']
# []
# haber
#
#
# mala educación en el transporte escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mala malo ADJ ADJ amod xxxx
# ent1 que o perro >>  malo
# educación educación NOUN NOUN ROOT xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# transporte transporte NOUN NOUN nmod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['malo', 'educación']
# []
# haber
#
#
# trato recibido en la dirección provincial de educación
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# recibido recibido ADJ ADJ amod xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# dirección dirección NOUN NOUN obl xxxx
# provincial provincial ADJ ADJ amod xxxx
# de de ADP ADP case xx
# educación educación NOUN NOUN nmod xxxx
# ['trato', 'recibido']
# []
# haber
#
#
# devolucion tasa matricula por discapacidad
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# devolucion devolucion ADJ ADJ nsubj xxxx
# tasa tasa NOUN NOUN flat xxxx
# matricula matricular VERB VERB ROOT xxxx
# por por ADP ADP case xxx
# discapacidad discapacidad NOUN NOUN obl xxxx
# ['devolucion', 'tasa']
# [(11840699188806025751, 2, 3)]
# matricula
# matricula
# matricular
#
#
# pcr en el ceip miguel delibes de nava del rey (va)
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# pcr pcr PROPN PROPN ROOT xxx
# ent1 que o perro >>  pcr
# en en ADP ADP case xx
# ent1 que o perro >>  en
# el el DET DET det xx
# ent1 que o perro >>  el
# ceip ceip NOUN NOUN ROOT xxxx
# ent1 que o perro >>  ceip
# miguel miguel PROPN PROPN appos xxxx
# delibes delib ADJ ADJ appos xxxx
# de de ADP ADP case xx
# nava nava NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# rey rey PROPN PROPN nmod xxx
# ( ( PUNCT PUNCT punct (
# va ir VERB VERB appos xx
# ) ) PUNCT PUNCT punct )
# ['ceip', 'delib']
# [(11840699188806025751, 11, 12)]
# va
# va
# ir
#
#
# santa maría la mayor. cierre escuela infantil
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# santa santa PROPN PROPN nsubj xxxx
# maría macer VERB VERB ROOT xxxx
# la el DET DET det xx
# mayor mayor ADJ ADJ obj xxxx
# . . PUNCT PUNCT punct .
# cierre cerrar VERB VERB ROOT xxxx
# escuela escuela NOUN NOUN nsubj xxxx
# infantil infantil ADJ ADJ amod xxxx
# ['escuela', 'mayor']
# [(11840699188806025751, 1, 2), (11840699188806025751, 5, 6)]
# maría
# cierre
# cerrar
#
#
# profesor oboe.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# profesor profesor NOUN NOUN ROOT xxxx
# ent1 que o perro >>  profesor
# oboe oboe ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['profesor', 'oboe']
# []
# haber
#
#
# problemas en  eltransporte scolar del ceip gran duque de alba
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# problemas problema NOUN NOUN ROOT xxxx
# ent1 que o perro >>  problema
# en en ADP ADP case xx
#     SPACE SPACE dep
# eltransporte eltransporte NOUN NOUN nmod xxxx
# scolar scolar PROPN PROPN appos xxxx
# del del ADP ADP case xxx
# ceip ceip NOUN NOUN nmod xxxx
# gran gran ADJ ADJ amod xxxx
# duque duque NOUN NOUN appos xxxx
# de de ADP ADP case xx
# alba alba NOUN NOUN nmod xxxx
# ['problema', 'eltransporte']
# []
# haber
#
#
# no atencion presencial
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# atencion atencion PROPN PROPN ROOT xxxx
# ent1 que o perro >>  atencion
# presencial presencial ADJ ADJ flat xxxx
# ent1 que o perro >>  presencial
# ['', 'presencial']
# []
# haber
#
#
# solicitud participación programa releo plus.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicitud solicitud NOUN NOUN ROOT xxxx
# ent1 que o perro >>  solicitud
# participación participación ADJ ADJ amod xxxx
# programa programa NOUN NOUN appos xxxx
# releo releo PROPN PROPN appos xxxx
# plus plus PROPN PROPN flat xxxx
# . . PUNCT PUNCT punct .
# ['solicitud', 'participación']
# []
# haber
#
#
# presentación solicitud de admisión de alumnado en centros.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# presentación presentación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  presentación
# solicitud solicitud NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# admisión admisión NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# alumnado alumnado NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# centros centro NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# ['presentación', 'solicitud']
# []
# haber
#
#
# santa maría la mayor. cierre escuela infantil.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# santa santa PROPN PROPN nsubj xxxx
# maría macer VERB VERB ROOT xxxx
# la el DET DET det xx
# mayor mayor ADJ ADJ obj xxxx
# . . PUNCT PUNCT punct .
# cierre cerrar VERB VERB ROOT xxxx
# escuela escuela NOUN NOUN nsubj xxxx
# infantil infantil ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['escuela', 'mayor']
# [(11840699188806025751, 1, 2), (11840699188806025751, 5, 6)]
# maría
# cierre
# cerrar
#
#
# santa maría la mayor. cierre escuela infantil
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# santa santa PROPN PROPN nsubj xxxx
# maría macer VERB VERB ROOT xxxx
# la el DET DET det xx
# mayor mayor ADJ ADJ obj xxxx
# . . PUNCT PUNCT punct .
# cierre cerrar VERB VERB ROOT xxxx
# escuela escuela NOUN NOUN nsubj xxxx
# infantil infantil ADJ ADJ amod xxxx
# ['escuela', 'mayor']
# [(11840699188806025751, 1, 2), (11840699188806025751, 5, 6)]
# maría
# cierre
# cerrar
#
#
# santa maría la mayor. cierre escuela infantil
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# santa santa PROPN PROPN nsubj xxxx
# maría macer VERB VERB ROOT xxxx
# la el DET DET det xx
# mayor mayor ADJ ADJ obj xxxx
# . . PUNCT PUNCT punct .
# cierre cerrar VERB VERB ROOT xxxx
# escuela escuela NOUN NOUN nsubj xxxx
# infantil infantil ADJ ADJ amod xxxx
# ['escuela', 'mayor']
# [(11840699188806025751, 1, 2), (11840699188806025751, 5, 6)]
# maría
# cierre
# cerrar
#
#
# tardanza en empezar clases ingles
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# tardanza tardanzar VERB VERB ROOT xxxx
# ent1 que o perro >>  tardanzar
# en en ADP ADP mark xx
# ent1 que o perro >>  en
# empezar empezar VERB VERB xcomp xxxx
# ent1 que o perro >>  empezar
# clases clase NOUN NOUN obj xxxx
# ingles ingl ADJ ADJ amod xxxx
# ent1 que o perro >>  ingl
# ['ingl', 'clase']
# [(11840699188806025751, 0, 1), (11840699188806025751, 2, 3)]
# tardanza
# empezar
# empezar
#
#
# no atención al problema de fonetica del niño.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# atención atención NOUN NOUN ROOT xxxx
# ent1 que o perro >>  atención
# al al ADP ADP case xx
# problema problema NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# fonetica fonetica NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# niño niño NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# ['atención', 'problema']
# []
# haber
#
#
# programa releo plus 21/22
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# programa programa NOUN NOUN ROOT xxxx
# ent1 que o perro >>  programa
# releo releo PROPN PROPN appos xxxx
# plus plus PROPN PROPN flat xxxx
# 21/22 21/22 NUM NUM appos dd/dd
# ['programa', '']
# []
# haber
#
#
# listas dinámicas
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# listas lista NOUN NOUN ROOT xxxx
# ent1 que o perro >>  lista
# dinámicas dinámico ADJ ADJ amod xxxx
# ['lista', 'dinámico']
# []
# haber
#
#
# enviar a alumnos a casa por obras en tejado
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# enviar enviar VERB VERB ROOT xxxx
# ent1 que o perro >>  enviar
# a a ADP ADP case x
# ent1 que o perro >>  a
# alumnos alumno NOUN NOUN obj xxxx
# a a ADP ADP case x
# casa casa NOUN NOUN obl xxxx
# ent1 que o perro >>  casa
# por por ADP ADP case xxx
# obras obra NOUN NOUN obl xxxx
# en en ADP ADP advmod xx
# tejado tejado ADJ ADJ fixed xxxx
# ['casa', 'alumno']
# [(11840699188806025751, 0, 1)]
# enviar
# enviar
# enviar
#
#
# reducción de horas lectivas a su hijo de 3º de infantil por organización de turnos para asistir a comedor
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# reducción reducción NOUN NOUN ROOT xxxx
# ent1 que o perro >>  reducción
# de de ADP ADP case xx
# horas hora NOUN NOUN nmod xxxx
# lectivas lectiva ADJ ADJ amod xxxx
# a a ADP ADP case x
# su su DET DET det xx
# hijo hijo NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# 3º 3º NUM NUM nummod dx
# de de ADP ADP case xx
# infantil infantil ADJ ADJ compound xxxx
# por por ADP ADP case xxx
# organización organización NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# turnos turno NOUN NOUN nmod xxxx
# para para ADP ADP mark xxxx
# asistir asistir VERB VERB acl xxxx
# a a ADP ADP advmod x
# comedor comedor NOUN NOUN fixed xxxx
# ['reducción', 'hora']
# [(11840699188806025751, 16, 17)]
# asistir
# asistir
# asistir
#
#
# queja sobre apuntar a los niños en colegios e instituto muy distantes.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja queja NOUN NOUN ROOT xxxx
# ent1 que o perro >>  queja
# sobre sobre ADP ADP mark xxxx
# apuntar apuntar VERB VERB acl xxxx
# a a ADP ADP case x
# los el DET DET det xxx
# niños niño NOUN NOUN obj xxxx
# en en ADP ADP case xx
# colegios colegio NOUN NOUN obl xxxx
# e e CCONJ CCONJ cc x
# instituto instituto NOUN NOUN conj xxxx
# muy mucho ADV ADV advmod xxx
# distantes distante ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['queja', 'niño']
# [(11840699188806025751, 2, 3)]
# apuntar
# apuntar
# apuntar
#
#
# ayudas contratatación predoctoral personal investigador.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# ayudas ayuda NOUN NOUN ROOT xxxx
# ent1 que o perro >>  ayuda
# contratatación contratatación PROPN PROPN flat xxxx
# predoctoral predoctoral PROPN PROPN amod xxxx
# personal personal ADJ ADJ amod xxxx
# investigador investigador ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# ['ayuda', 'personal']
# []
# haber
#
#
# retraso autobus escolar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# retraso retraso NOUN NOUN ROOT xxxx
# ent1 que o perro >>  retraso
# autobus autobus PROPN PROPN amod xxxx
# escolar escolar ADJ ADJ amod xxxx
# ['retraso', 'escolar']
# []
# haber
#
#
# modelo solicitud programa releo +.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# modelo modelo NOUN NOUN ROOT xxxx
# ent1 que o perro >>  modelo
# solicitud solicitud ADJ ADJ amod xxxx
# programa programa NOUN NOUN appos xxxx
# releo releo PROPN PROPN appos xxxx
# + + PROPN PROPN flat +
# . . PUNCT PUNCT punct .
# ['modelo', 'solicitud']
# []
# haber
#
#
# no sabemos qué procedimiento tenemos que seguir.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# sabemos saber VERB VERB ROOT xxxx
# ent1 que o perro >>  saber
# qué qué DET DET det xxx
# ent1 que o perro >>  qué
# procedimiento procedimiento NOUN NOUN obj xxxx
# tenemos tener VERB VERB ccomp xxxx
# ent1 que o perro >>  tener
# que que SCONJ SCONJ cc xxx
# ent1 que o perro >>  que
# seguir seguir VERB VERB conj xxxx
# ent1 que o perro >>  seguir
# . . PUNCT PUNCT punct .
# ['', 'procedimiento']
# [(11840699188806025751, 1, 2), (11840699188806025751, 4, 5), (11840699188806025751, 6, 7)]
# sabemos
# seguir
# seguir
#
#
# en ninguno de los documentos figura que tuviese que ir acompañada por padre, madre o tutor.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# en en ADP ADP case xx
# ent1 que o perro >>  en
# ninguno ninguno PRON PRON obl xxxx
# ent1 que o perro >>  ninguno
# de de ADP ADP case xx
# ent1 que o perro >>  de
# los el DET DET det xxx
# ent1 que o perro >>  el
# documentos documento NOUN NOUN nmod xxxx
# ent1 que o perro >>  documento
# figura figurar VERB VERB ROOT xxxx
# que que PRON PRON mark xxx
# tuviese tener VERB VERB ccomp xxxx
# que que SCONJ SCONJ cc xxx
# ir ir AUX AUX conj xx
# acompañada acompañado ADJ ADJ obj xxxx
# por por ADP ADP case xxx
# padre padre NOUN NOUN obj xxxx
# , , PUNCT PUNCT punct ,
# madre madre NOUN NOUN appos xxxx
# o o CCONJ CCONJ cc x
# tutor tutor NOUN NOUN conj xxxx
# . . PUNCT PUNCT punct .
# ['documento', 'padre']
# [(11840699188806025751, 5, 6), (11840699188806025751, 7, 8), (11840699188806025751, 9, 10)]
# figura
# ir
# ir
#
#
# incidencia aplicación comedores escolares
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# incidencia incidencia NOUN NOUN amod xxxx
# ent1 que o perro >>  incidencia
# aplicación aplicación NOUN NOUN nmod xxxx
# comedores comedor NOUN NOUN ROOT xxxx
# escolares escolar ADJ ADJ amod xxxx
# ['incidencia', 'aplicación']
# []
# haber
#
#
# queja sobre nula información a maestra interina
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja queja NOUN NOUN ROOT xxxx
# ent1 que o perro >>  queja
# sobre sobre ADP ADP case xxxx
# nula nulo ADJ ADJ amod xxxx
# información información NOUN NOUN nmod xxxx
# a a ADP ADP case x
# maestra maestra NOUN NOUN nmod xxxx
# interina interino ADJ ADJ amod xxxx
# ['queja', 'nulo']
# []
# haber
#
#
# atencion deficiente.
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# atencion atencion PROPN PROPN ROOT xxxx
# ent1 que o perro >>  atencion
# deficiente deficiente ADJ ADJ amod xxxx
# ent1 que o perro >>  deficiente
# . . PUNCT PUNCT punct .
# ['deficiente', '']
# []
# haber

# %%
entity_pairs = []

for i in phrases:
    entity_pairs.append(getEntities(i))

relations = [getRelation(i) for i in phrases]
# Out:
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# respuesta respuesta NOUN NOUN nmod xxxx
# a a ADP ADP case x
# solicitud solicitud NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# notificaciones notificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  notificación
# sin sin ADP ADP case xxx
# indicación indicación NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# titular titular NOUN NOUN nmod xxxx
# al al ADP ADP case xx
# que que PRON PRON obl xxx
# van ir VERB VERB acl xxx
# dirigidas dirigido ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicita solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# revisión revisión NOUN NOUN obj xxxx
# de de ADP ADP case xx
# ent1 que o perro >>  de
# altura altura NOUN NOUN nmod xxxx
# ent1 que o perro >>  altura
# máxima máximo ADJ ADJ amod xxxx
# de de ADP ADP case xx
# edificación edificación NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# cisterniga cisterniga NOUN NOUN nmod xxxx
# ( ( PUNCT PUNCT punct (
# vallladolid vallladolid NOUN NOUN appos xxxx
# ) ) PUNCT PUNCT punct )
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# normas norma NOUN NOUN ROOT xxxx
# ent1 que o perro >>  norma
# subsidiarias subsidiario ADJ ADJ amod xxxx
# municikpales municikpal ADJ ADJ amod xxxx
# consistente consistente ADJ ADJ obj xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# modificacion modificacion NOUN NOUN nmod xxxx
# el el DET DET det xx
# ambito ambito NOUN NOUN obj xxxx
# desarrolo desarrolo ADJ ADJ amod xxxx
# del del ADP ADP case xxx
# area area NOUN NOUN nmod xxxx
# especial especial ADJ ADJ amod xxxx
# ae.ps-4 ae.ps-4 ADJ ADJ appos xx.xx-d
# y y CCONJ CCONJ cc x
# re¡mision re¡mision PROPN PROPN conj xx¡xxxx
# a a ADP ADP case x
# la el DET DET det xx
# comision comision NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# urbanismo urbanismo NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# buzón buzón PROPN PROPN ROOT xxxx
# ent1 que o perro >>  buzón
# notificaciones notificaciones PROPN PROPN flat xxxx
# ent1 que o perro >>  notificaciones
# electrónicas electrónicas PROPN PROPN flat xxxx
# ent1 que o perro >>  electrónicas
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# funciona funcionar VERB VERB ROOT xxxx
# ent1 que o perro >>  funcionar
# la el DET DET det xx
# ent1 que o perro >>  el
# máquina máquina NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# bonos bono NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# transporte transporte NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# estación estación NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# autobuses autobús NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cita citar VERB VERB ROOT xxxx
# ent1 que o perro >>  citar
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# incidencias incidencia NOUN NOUN ROOT xxxx
# ent1 que o perro >>  incidencia
# en en ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# za-504 za-504 PROPN PROPN appos xx-ddd
# , , PUNCT PUNCT punct ,
# que que PRON PRON nsubj xxx
# ha haber AUX AUX aux xx
# sido ser AUX AUX aux xxxx
# recientemente recientemente ADV ADV advmod xxxx
# rehabilitada rehabilitado ADJ ADJ acl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# exigencia exigencia NOUN NOUN ROOT xxxx
# ent1 que o perro >>  exigencia
# de de ADP ADP case xx
# uso uso NOUN NOUN nmod xxx
# de de ADP ADP case xx
# navegador navegador NOUN NOUN nmod xxxx
# internet internet PROPN PROPN amod xxxx
# explorer explorer VERB VERB amod xxxx
# para para ADP ADP case xxxx
# trámites trámite NOUN NOUN obl xxxx
# electrónicos electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# transporte transporte NOUN NOUN ROOT xxxx
# ent1 que o perro >>  transporte
# a a ADP ADP case x
# la el DET DET det xx
# demanda demanda NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# merindades merindad NOUN NOUN ROOT xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# usar usar VERB VERB ROOT xxxx
# ent1 que o perro >>  usar
# las el DET DET det xxx
# ent1 que o perro >>  el
# mascarillas mascarilla NOUN NOUN obj xxxx
# en en ADP ADP case xx
# ent1 que o perro >>  en
# el el DET DET det xx
# ent1 que o perro >>  el
# lugar lugar NOUN NOUN obl xxxx
# ent1 que o perro >>  lugar
# de de ADP ADP case xx
# trabajo trabajo NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# señalización señalización NOUN NOUN ROOT xxxx
# ent1 que o perro >>  señalización
# en en ADP ADP case xx
# entrada entrada NOUN NOUN nmod xxxx
# carretera carretero ADJ ADJ amod xxxx
# a a ADP ADP case x
# peñaranda peñaranda NOUN NOUN fixed xxxx
# de de ADP ADP fixed xx
# bracamonte bracamonte PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# darse dar él VERB VERB ROOT xxxx
# ent1 que o perro >>  dar él
# de de ADP ADP advmod xx
# ent1 que o perro >>  de
# alta alta NOUN NOUN fixed xxxx
# ent1 que o perro >>  alta
# en en ADP ADP case xx
# bec bec PROPN PROPN obl xxx
# mediante mediante ADP ADP case xxxx
# sistema sistema NOUN NOUN obl xxxx
# cl@ve cl@ve ADJ ADJ amod xx@xx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# notificaciones notificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  notificación
# electrónicas electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# que que SCONJ SCONJ mark xxx
# ent1 que o perro >>  que
# en en ADP ADP advmod xx
# ent1 que o perro >>  en
# medio medio NOUN NOUN fixed xxxx
# ent1 que o perro >>  medio
# ambiente ambiente NOUN NOUN compound xxxx
# no no ADV ADV advmod xx
# ha haber AUX AUX aux xx
# sido ser AUX AUX aux xxxx
# atendida atender VERB VERB ROOT xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja queja NOUN NOUN ROOT xxxx
# ent1 que o perro >>  queja
# relacionada relacionado ADJ ADJ amod xxxx
# con con ADP ADP case xxx
# la el DET DET det xx
# presentada presentado ADJ ADJ amod xxxx
# el el DET DET det xx
# día día NOUN NOUN obl xxx
# 8 8 NUM NUM compound d
# noviembre noviembre NOUN NOUN compound xxxx
# 2021 2021 NUM NUM compound dddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# aviso aviso NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# notificaciones notificación NOUN NOUN nmod xxxx
# electrónicas electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# paso paso NOUN NOUN ROOT xxxx
# ent1 que o perro >>  paso
# peatonal peatonal ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicita solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# mejora mejora NOUN NOUN obj xxxx
# señalizacion señalizacion PROPN PROPN nmod xxxx
# ent1 que o perro >>  señalizacion
# horizontal horizontal ADJ ADJ amod xxxx
# ent1 que o perro >>  horizontal
# cl cl NOUN NOUN nsubj xx
# 517 517 NUM NUM compound ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesa interesa NOUN NOUN nsubj xxxx
# sugiere sugerir VERB VERB ROOT xxxx
# abaratar abaratar VERB VERB xcomp xxxx
# precios precio NOUN NOUN obj xxxx
# del del ADP ADP case xxx
# transporte transporte NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# tren tren NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# cercanías cercanía NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# segovia-madrid segovia-madrid NOUN NOUN ROOT xxxx-xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# reacondicionamiento reacondicionamiento ADJ ADJ amod xxxx
# ent1 que o perro >>  reacondicionamiento
# camino camino NOUN NOUN case xxxx
# navarredondilla navarredondillar VERB VERB ROOT xxxx
# a a ADP ADP case x
# navatalgordo navatalgordo PROPN PROPN obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# satisfecho satisfecho ADJ ADJ ROOT xxxx
# ent1 que o perro >>  satisfecho
# con con ADP ADP case xxx
# ent1 que o perro >>  con
# contestación contestación NOUN NOUN obl xxxx
# ent1 que o perro >>  contestación
# envíada envíado ADJ ADJ amod xxxx
# a a ADP ADP case x
# queja queja NOUN NOUN obl xxxx
# anterior anterior ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# modificación modificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  modificación
# de de ADP ADP case xx
# normativa normativa NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# pesca pesca NOUN NOUN nmod xxxx
# para para ADP ADP case xxxx
# el el DET DET det xx
# año año NOUN NOUN nmod xxx
# 2022 2022 NUM NUM compound dddd
# para para ADP ADP case xxxx
# los el DET DET det xxx
# embalses embalse NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# pontón pontón NOUN NOUN nmod xxxx
# alto alto ADJ ADJ amod xxxx
# y y CCONJ CCONJ cc x
# puente puente PROPN PROPN conj xxxx
# alta alta PROPN PROPN flat xxxx
# ( ( PUNCT PUNCT punct (
# sg sg PROPN PROPN flat xx
# ) ) PUNCT PUNCT punct )
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# alegaciones alegación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  alegación
# a a ADP ADP case x
# la el DET DET det xx
# plantilla plantilla NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# respuestas respuesta NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# primer primero ADJ ADJ amod xxxx
# ejercicio ejercicio NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# oposición oposición NOUN NOUN nmod xxxx
# para para ADP ADP case xxxx
# acceso acceso NOUN NOUN nmod xxxx
# al al ADP ADP case xx
# cuerpo cuerpo NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# policía policía NOUN NOUN nmod xxxx
# local local ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# eliminación eliminación NOUN NOUN obj xxxx
# de de ADP ADP case xx
# líneas línea NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# trasporte trasporte NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# santa santa PROPN PROPN nmod xxxx
# mª mª PROPN PROPN flat xx
# la el DET DET det xx
# real real PROPN PROPN obj xxxx
# de de ADP ADP case xx
# nieva nieva PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# supresión supresión NOUN NOUN obj xxxx
# de de ADP ADP case xx
# líneas línea NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# transporte transporte NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# santa santa PROPN PROPN nmod xxxx
# mª mª PROPN PROPN flat xx
# la el DET DET det xx
# real real PROPN PROPN appos xxxx
# de de ADP ADP case xx
# nieva nieva PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# eliminación eliminación NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# líneas línea NOUN NOUN nmod xxxx
# regulares regular ADJ ADJ amod xxxx
# de de ADP ADP case xx
# transporte transporte NOUN NOUN nmod xxxx
# público público ADJ ADJ amod xxxx
# en en ADP ADP case xx
# santa santa PROPN PROPN nmod xxxx
# mª mª PROPN PROPN flat xx
# la el DET DET det xx
# real real PROPN PROPN obj xxxx
# de de ADP ADP case xx
# nieva nieva PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# desacuerdo desacuerdo NOUN NOUN ROOT xxxx
# ent1 que o perro >>  desacuerdo
# con con ADP ADP case xxx
# asignación asignación NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# cotos coto NOUN NOUN nmod xxxx
# sobrantes sobrante ADJ ADJ amod xxxx
# de de ADP ADP case xx
# pesca pesca NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# salamanca salamanca PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# rechazada rechazado ADJ ADJ ROOT xxxx
# ent1 que o perro >>  rechazado
# y y CCONJ CCONJ cc x
# ent1 que o perro >>  y
# derivada derivado ADJ ADJ conj xxxx
# ent1 que o perro >>  derivado
# a a ADP ADP case x
# servicios servicio NOUN NOUN obj xxxx
# centrales central ADJ ADJ amod xxxx
# ent1 que o perro >>  central
#     SPACE SPACE dep
# por por ADP ADP mark xxx
# ser ser AUX AUX cop xxx
# competencia competencia NOUN NOUN advcl xxxx
# del del ADP ADP case xxx
# 112 112 NUM NUM nmod ddd
# ( ( PUNCT PUNCT punct (
# fomento fomento NOUN NOUN appos xxxx
# y y CCONJ CCONJ cc x
# medio medio NOUN NOUN conj xxxx
# ambiente ambiente NOUN NOUN flat xxxx
# ) ) PUNCT PUNCT punct )
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# retrasos retraso NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# línea línea NOUN NOUN nmod xxxx
# arévalo-nava arévalo-navo ADJ ADJ amod xxxx-xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# asunción-segovia asunción-segovia PROPN PROPN nmod xxxx-xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mejora mejora NOUN NOUN ROOT xxxx
# ent1 que o perro >>  mejora
# carretera carretero ADJ ADJ amod xxxx
# cl-501 cl-501 DET DET amod xx-ddd
# entrada entrada NOUN NOUN obl xxxx
# pueblo pueblo NOUN NOUN appos xxxx
# la el DET DET det xx
# adrada adrada NOUN NOUN ROOT xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# los el DET DET det xxx
# ent1 que o perro >>  el
# pasales pasal NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# madera madera NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# puente puente NOUN NOUN nmod xxxx
# se él PRON PRON expl:pv xx
# encuentran encontrar VERB VERB ROOT xxxx
# en en ADP ADP case xx
# un uno DET DET det xx
# estado estado NOUN NOUN obl xxxx
# ruinoso ruinoso ADJ ADJ obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# teme temer VERB VERB ROOT xxxx
# riesgo riesgo NOUN NOUN obj xxxx
# de de ADP ADP case xx
# inundaciones inundación NOUN NOUN nmod xxxx
# por por ADP ADP case xxx
# estado estado NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# puentes puente NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# madrona madrona NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# obligacion obligacion NOUN NOUN nsubj xxxx
# relacionarse relacionar él VERB VERB ROOT xxxx
# electrónicamente electrónicamente ADV ADV advmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# se él PRON PRON expl:pass xx
# ent1 que o perro >>  él
# requiere requerir VERB VERB ROOT xxxx
# ent1 que o perro >>  requerir
# contestación contestación NOUN NOUN nsubj xxxx
# y y CCONJ CCONJ cc x
# aportación aportación NOUN NOUN conj xxxx
# documentos documento NOUN NOUN amod xxxx
# relacionados relacionado ADJ ADJ amod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# " " PUNCT PUNCT punct "
# solicita solicitar VERB VERB obj xxxx
# " " PUNCT PUNCT punct "
# del del ADP ADP case xxx
# escrito escrito NOUN NOUN obj xxxx
# de de ADP ADP case xx
# 22 22 NUM NUM nummod dd
# de de ADP ADP case xx
# noviembre noviembre NOUN NOUN compound xxxx
# de de ADP ADP case xx
# 2021 2021 NUM NUM compound dddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# incumplimiento incumplimiento NOUN NOUN ROOT xxxx
# ent1 que o perro >>  incumplimiento
# normativa normativo ADJ ADJ amod xxxx
# de de ADP ADP case xx
# acampada acampada PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado ADJ ADJ nsubj xxxx
# denuncia denuncia NOUN NOUN ROOT xxxx
# situcación situcación ADJ ADJ amod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# ocupación ocupación NOUN NOUN nmod xxxx
# por por ADP ADP case xxx
# roturación roturación NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# vias via NOUN NOUN nmod xxxx
# pecuarias pecuaria ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADJ ADJ amod xxx
# ent1 que o perro >>  mal
# funcionamiento funcionamiento NOUN NOUN ROOT xxxx
# nuevo nuevo ADJ ADJ amod xxxx
# sistema sistema NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# notificaciones notificación NOUN NOUN nmod xxxx
# electrónicas electrónico ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# deasignación deasignación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  deasignación
# permiso permiso NOUN NOUN obj xxxx
# arec arec ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mejorar mejorar VERB VERB ROOT xxxx
# ent1 que o perro >>  mejorar
# tramitación tramitación NOUN NOUN obj xxxx
# electrónica electrónico ADJ ADJ amod xxxx
# ent1 que o perro >>  electrónico
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADJ ADJ amod xxx
# ent1 que o perro >>  mal
# funcionamiento funcionamiento NOUN NOUN ROOT xxxx
# formulario formulario ADJ ADJ amod xxxx
# para para ADP ADP mark xxxx
# presentar presentar VERB VERB acl xxxx
# telematicamente telematicamente ADV ADV advmod xxxx
# para para ADP ADP case xxxx
# medioambiente medioambiente PROPN PROPN obl xxxx
# valladolid valladolid PROPN PROPN appos xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# petición petición NOUN NOUN nsubj xxxx
# mejora mejorar VERB VERB ROOT xxxx
# plataformas plataforma NOUN NOUN obj xxxx
# junta junto ADJ ADJ amod xxxx
# cyl cyl PROPN PROPN punct xxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# colocación colocación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  colocación
# badenes badén ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# incorporar incorporar VERB VERB ROOT xxxx
# ent1 que o perro >>  incorporar
# sistema sistema NOUN NOUN obj xxxx
# cl@ve cl@ve ADJ ADJ amod xx@xx
# ent1 que o perro >>  cl@ve
# para para ADP ADP case xxxx
# trámites trámite NOUN NOUN nmod xxxx
# administrativos administrativo ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# limpieza limpieza NOUN NOUN ROOT xxxx
# ent1 que o perro >>  limpieza
# cañada cañado ADJ ADJ amod xxxx
# de de ADP ADP case xx
# ganado ganado NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicitud solicitud NOUN NOUN ROOT xxxx
# ent1 que o perro >>  solicitud
# de de ADP ADP case xx
# servicio servicio NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# autobús autobús NOUN NOUN nmod xxxx
# a a ADP ADP case x
# escuela escuela NOUN NOUN fixed xxxx
# capacitación capacitación NOUN NOUN nmod xxxx
# agraria agrario ADJ ADJ amod xxxx
# segovis segovis NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cierre cerrar VERB VERB amod xxxx
# ent1 que o perro >>  cerrar
# camino camino NOUN NOUN ROOT xxxx
# ent1 que o perro >>  camino
# vecinal vecinal ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# información información NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# notificaciones notificación NOUN NOUN nmod xxxx
# electrónicas electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# notificación notificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  notificación
# electrónica electrónico ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# enlace enlace NOUN NOUN ROOT xxxx
# al al ADP ADP case xx
# nuevo nuevo ADJ ADJ amod xxxx
# sistema sistema NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# notificaciones notificación NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# retraso retraso NOUN NOUN ROOT xxxx
# ent1 que o perro >>  retraso
# autobus autobus ADJ ADJ amod xxxx
# de de ADP ADP case xx
# santervas santerva NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# campos campo NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# unificación unificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  unificación
# criterios criterio ADJ ADJ amod xxxx
# en en ADP ADP case xx
# sede sede NOUN NOUN nmod xxxx
# electrónica electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# contaminación contaminación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  contaminación
# por por ADP ADP case xxx
# actividades actividad NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# combustión combustión NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# pellets pellets PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cierre cerrar VERB VERB ROOT xxxx
# ent1 que o perro >>  cerrar
# alerta alerta NOUN NOUN obj xxxx
# 112 112 NUM NUM obj ddd
# sin sin ADP ADP mark xxx
# ent1 que o perro >>  sin
# contactar contactar VERB VERB acl xxxx
# ent1 que o perro >>  contactar
# con con ADP ADP case xxx
# ent1 que o perro >>  con
# menor menor ADJ ADJ advmod xxxx
# ent1 que o perro >>  menor
# que que PRON PRON nsubj xxx
# ent1 que o perro >>  que
# llamó llamar VERB VERB ccomp xxxx
# ent1 que o perro >>  llamar
# al al ADP ADP case xx
# ent1 que o perro >>  al
# 112 112 NUM NUM obj ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# vigilancia vigilancia NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# zona zona NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# barbacoas barbacoas NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# verano verano NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja quejar VERB VERB ROOT xxxx
# ent1 que o perro >>  quejar
# por por ADP ADP case xxx
# ent1 que o perro >>  por
# mal mal ADV ADV advmod xxx
# ent1 que o perro >>  mal
# estado estado PROPN PROPN obl xxxx
# ent1 que o perro >>  estado
# carretera carretero ADJ ADJ amod xxxx
# ent1 que o perro >>  carretero
# tordillos tordil él VERB VERB punct xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mejoras mejora NOUN NOUN ROOT xxxx
# ent1 que o perro >>  mejora
# tecnológicas tecnológico ADJ ADJ amod xxxx
# ámbito ámbito NOUN NOUN appos xxxx
# rural rural ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# imposibilidad imposibilidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  imposibilidad
# contacto contacto NOUN NOUN amod xxxx
# telefónico telefónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# señales señal NOUN NOUN ROOT xxxx
# ent1 que o perro >>  señal
# de de ADP ADP case xx
# carretera carretera NOUN NOUN nmod xxxx
# incorrectas incorrecto ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# iteresado iteresado NOUN NOUN nsubj xxxx
# sugiere sugerir VERB VERB ROOT xxxx
# que que SCONJ SCONJ mark xxx
# se él PRON PRON ccomp xx
# de de ADP ADP case xx
# una uno DET DET det xxx
# solución solución NOUN NOUN obl xxxx
# al al ADP ADP case xx
# estado estado NOUN NOUN nmod xxxx
# , , PUNCT PUNCT punct ,
# lamentable lamentable ADJ ADJ amod xxxx
# , , PUNCT PUNCT punct ,
# de de ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# sg-322 sg-322 ADJ ADJ amod xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# malestar malestar NOUN NOUN nsubj xxxx
# con con ADP ADP case xxx
# con con ADP ADP case xxx
# falta falta NOUN NOUN obl xxxx
# de de ADP ADP case xx
# resolución resolución NOUN NOUN nmod xxxx
# expresa expresar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# su su DET DET det xx
# solicitud solicitud NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADJ ADJ amod xxx
# ent1 que o perro >>  mal
# funcionamiento funcionamiento NOUN NOUN ROOT xxxx
# aplicacvión aplicacvión ADJ ADJ amod xxxx
# permisos permiso NOUN NOUN nmod xxxx
# pesca pesco ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# supervisión supervisión NOUN NOUN ROOT xxxx
# ent1 que o perro >>  supervisión
# e e CCONJ CCONJ cc x
# la el DET DET det xx
# calidad calidad NOUN NOUN conj xxxx
# de de ADP ADP case xx
# las el DET DET det xxx
# aguas agua NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# pantano pantano NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# cuerda cuerda NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# pozo pozo NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# críticas crítica NOUN NOUN nsubj xxxx
# a a ADP ADP case x
# la el DET DET det xx
# exigencia exigencia NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# internet internet PROPN PROPN nmod xxxx
# explorer explorer VERB VERB ROOT xxxx
# en en ADP ADP case xx
# trámites trámite NOUN NOUN obj xxxx
# administrativos administrativo ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# porque porque SCONJ SCONJ mark xxxx
# se él PRON PRON expl:pass xx
# ha haber AUX AUX aux xx
# asfaltado asfaltar VERB VERB advcl xxxx
# mal mal ADV ADV advmod xxx
# un uno DET DET det xx
# agujero agujero NOUN NOUN obj xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cierre cerrar VERB VERB amod xxxx
# ent1 que o perro >>  cerrar
# camino camino NOUN NOUN ROOT xxxx
# ent1 que o perro >>  camino
# público público ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# pide pedir VERB VERB ROOT xxxx
# ent1 que o perro >>  pedir
# que que SCONJ SCONJ mark xxx
# ent1 que o perro >>  que
# atiendan atender VERB VERB ccomp xxxx
# ent1 que o perro >>  atender
# de de ADP ADP case xx
# ent1 que o perro >>  de
# forma forma NOUN NOUN obl xxxx
# ent1 que o perro >>  forma
# presencial presencial ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# demora demorar VERB VERB ROOT xxxx
# ent1 que o perro >>  demorar
# en en ADP ADP mark xx
# ent1 que o perro >>  en
# otorgar otorgar VERB VERB acl xxxx
# ent1 que o perro >>  otorgar
# vivienda vivienda NOUN NOUN obj xxxx
# proteccion proteccion PROPN PROPN obj xxxx
# oficial oficial ADJ ADJ amod xxxx
# ent1 que o perro >>  oficial
# por por ADP ADP case xxx
# violencia violencia NOUN NOUN obj xxxx
# de de ADP ADP case xx
# género género NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# registro registro NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# medio medio NOUN NOUN nmod xxxx
# ambiente ambiente NOUN NOUN flat xxxx
# no no ADV ADV advmod xx
# está estar AUX AUX cop xxxx
# operativo operativo ADJ ADJ ROOT xxxx
# a a ADP ADP case x
# las el DET DET det xxx
# 13.50 13.50 NUM NUM nummod dd.dd
# horas hora NOUN NOUN obl xxxx
# y y CCONJ CCONJ cc x
# no no ADV ADV advmod xx
# abren abrir VERB VERB conj xxxx
# la el DET DET det xx
# puerta puerta NOUN NOUN obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# propone proponer VERB VERB ROOT xxxx
# nueva nuevo ADJ ADJ amod xxxx
# ubiación ubiación NOUN NOUN obj xxxx
# de de ADP ADP case xx
# los el DET DET det xxx
# autobuses autobús NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# atencion atencion PROPN PROPN ROOT xxxx
# ent1 que o perro >>  atencion
# deficiente deficiente ADJ ADJ amod xxxx
# ent1 que o perro >>  deficiente
# territorial territorial ADJ ADJ amod xxxx
# de de ADP ADP case xx
# medio medio NOUN NOUN nmod xxxx
# ambiente ambiente PROPN PROPN compound xxxx
# valladolid valladolid PROPN PROPN flat xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# reiteración reiteración NOUN NOUN ROOT xxxx
# ent1 que o perro >>  reiteración
# mal mal ADV ADV advmod xxx
# estado estado ADJ ADJ cop xxxx
# rejilla rejilla NOUN NOUN amod xxxx
# crta crta PROPN PROPN flat xxxx
# . . PUNCT PUNCT punct .
# va-223 va-223 PROPN PROPN ROOT xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# carteles cartel NOUN NOUN ROOT xxxx
# ent1 que o perro >>  cartel
# aparcamiento aparcamiento NOUN NOUN nmod xxxx
# carbanas carbanas VERB VERB amod xxxx
# playa playa NOUN NOUN obj xxxx
# pita pita PROPN PROPN amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# denuncia denuncia NOUN NOUN ROOT xxxx
# ent1 que o perro >>  denuncia
# desafectacion desafectacion PROPN PROPN amod xxxx
# parcelas parcela NOUN NOUN nsubj xxxx
# ganadero ganadero ADJ ADJ amod xxxx
#     SPACE SPACE dep
# a a ADP ADP advmod x
# medio medio NOUN NOUN fixed xxxx
# ambiente ambiente NOUN NOUN fixed xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# atención atención NOUN NOUN ROOT xxxx
# ent1 que o perro >>  atención
# telefónica telefónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADV ADV advmod xxx
# ent1 que o perro >>  mal
# estado estado NOUN NOUN ROOT xxxx
# ent1 que o perro >>  estado
# de de ADP ADP case xx
# la el DET DET det xx
# señalización señalización NOUN NOUN nmod xxxx
# vertical vertical ADJ ADJ amod xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# bu-532 bu-532 SPACE SPACE nmod xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# quiere querer VERB VERB ROOT xxxx
# que que SCONJ SCONJ mark xxx
# le él PRON PRON obj xx
# envien envien VERB VERB ccomp xxxx
# el el DET DET det xx
# certificado certificado NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# transporte transporte NOUN NOUN nmod xxxx
# por por ADP ADP case xxx
# carretera carretera NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# señal señal NOUN NOUN nsubj xxxx
# luminosa luminoso ADJ ADJ amod xxxx
# no no ADV ADV advmod xx
# funciona funcionar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# noche noche NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# paso paso NOUN NOUN ROOT xxxx
# ent1 que o perro >>  paso
# de de ADP ADP case xx
# camiones camión NOUN NOUN nmod xxxx
# por por ADP ADP case xxx
# carretera carretera NOUN NOUN nmod xxxx
# inapropiada inapropiado ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# limpieza limpieza NOUN NOUN ROOT xxxx
# ent1 que o perro >>  limpieza
# cunetas cuneta NOUN NOUN obj xxxx
# carretera carretera PROPN PROPN flat xxxx
# cl-602 cl-602 PROPN PROPN amod xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# instalacion instalacion PROPN PROPN nsubj xxxx
# terraza terrazar VERB VERB ROOT xxxx
# muy mucho ADV ADV advmod xxx
# cerca cerca ADV ADV advmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN obl xxxx
# za-925 za-925 PROPN PROPN ROOT xx-ddd
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# vehículo vehículo NOUN NOUN ROOT xxxx
# ent1 que o perro >>  vehículo
# del del ADP ADP case xxx
# servicio servicio NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# medio medio NOUN NOUN flat xxxx
# ambiente ambiente NOUN NOUN compound xxxx
# que que SCONJ SCONJ mark xxx
# aparca aparca NOUN NOUN nmod xxxx
# en en ADP ADP advmod xx
# vado vado NOUN NOUN amod xxxx
# vecinal vecinal ADJ ADJ amod xxxx
# obstruyendo obstruir VERB VERB advcl xxxx
# el el DET DET det xx
# paso paso NOUN NOUN obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADV ADV advmod xxx
# ent1 que o perro >>  mal
# estado estar AUX AUX cop xxxx
# ent1 que o perro >>  estar
# salida salido ADJ ADJ ROOT xxxx
# ent1 que o perro >>  salido
# 36 36 NUM NUM obl dd
# ent1 que o perro >>  36
# a a ADP ADP case x
# a-601 a-601 NOUN NOUN ROOT x-ddd
# ent1 que o perro >>  a-601
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# atención atención NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# sección sección NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# vivienda vivienda NOUN NOUN nmod xxxx
# pública público ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# problemas problema NOUN NOUN ROOT xxxx
# ent1 que o perro >>  problema
# de de ADP ADP case xx
# conexión conexión NOUN NOUN nmod xxxx
# a a ADP ADP case x
# internet internet NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# alta alto ADJ ADJ amod xxxx
# ent1 que o perro >>  alto
# velocidad velocidad NOUN NOUN ROOT xxxx
# al al ADP ADP case xx
# atravesar atravesar VERB VERB acl xxxx
# la el DET DET det xx
# localidad localidad NOUN NOUN obj xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# del del ADP ADP case xxx
# retraso retraso NOUN NOUN obj xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# linea linea NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# nava nava NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# asunción asunción NOUN NOUN nmod xxxx
# a a ADP ADP case x
# segovia segovia PROPN PROPN obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# errores error NOUN NOUN ROOT xxxx
# ent1 que o perro >>  error
# a a ADP ADP case x
# la el DET DET det xx
# hora hora NOUN NOUN nmod xxxx
# de de ADP ADP mark xx
# presentar presentar VERB VERB acl xxxx
# declaración declaración NOUN NOUN obj xxxx
# responsable responsable ADJ ADJ amod xxxx
# de de ADP ADP case xx
# celebración celebración NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# monterías montería NOUN NOUN nmod xxxx
# y y CCONJ CCONJ cc x
# / / NOUN NOUN conj /
# o o CCONJ CCONJ cc x
# ganchos gancho NOUN NOUN conj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# cuidado cuidado NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# puentes puente NOUN NOUN nmod xxxx
# sobre sobre ADP ADP case xxxx
# las el DET DET det xxx
# vías vía NOUN NOUN nmod xxxx
# za-925 za-925 VERB VERB amod xx-ddd
# y y CCONJ CCONJ cc x
# za-921 za-921 NOUN NOUN conj xx-ddd
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# luz luz NOUN NOUN nmod xxx
# en en ADP ADP case xx
# carretera carretera NOUN NOUN nmod xxxx
# autonomica autonomico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# imposiblidad imposiblidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  imposiblidad
# de de ADP ADP mark xx
# conectarse conectar él VERB VERB acl xxxx
# a a ADP ADP case x
# internet internet NOUN NOUN obl xxxx
# para para ADP ADP case xxxx
# renovación renovación NOUN NOUN obl xxxx
# licencia licencia NOUN NOUN obj xxxx
# de de ADP ADP case xx
# caza caza NOUN NOUN nmod xxxx
# e e CCONJ CCONJ cc x
# imposibilidad imposibilidad NOUN NOUN conj xxxx
# de de ADP ADP case xx
# tramitación tramitación NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# ventanilla ventanilla NOUN NOUN nmod xxxx
# ya ya ADV ADV mark xx
# que que SCONJ SCONJ fixed xxx
# está estar AUX AUX cop xxxx
# cerrada cerrado ADJ ADJ ROOT xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# notificaciones notificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  notificación
# electrónicas electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# desacuerdo desacuerdo NOUN NOUN ROOT xxxx
# ent1 que o perro >>  desacuerdo
# con con ADP ADP case xxx
# asignación asignación NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# permisos permiso NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# pesca pesca NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# ponferrada ponferrada NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mala malo ADJ ADJ amod xxxx
# ent1 que o perro >>  malo
# conservación conservación NOUN NOUN ROOT xxxx
# carretera carretero ADJ ADJ amod xxxx
# fompedraza fompedrazar VERB VERB appos xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# poder poder AUX AUX aux xxxx
# ent1 que o perro >>  poder
# hacer hacer VERB VERB ROOT xxxx
# ent1 que o perro >>  hacer
# tramitación tramitación NOUN NOUN obj xxxx
# electrónica electrónico ADJ ADJ amod xxxx
# ent1 que o perro >>  electrónico
# con con ADP ADP case xxx
# certificado certificado NOUN NOUN nmod xxxx
# digital digital ADJ ADJ amod xxxx
# bajo bajo ADP ADP case xxxx
# sistema sistema NOUN NOUN nmod xxxx
# operativo operativo ADJ ADJ amod xxxx
# debian debiar VERB VERB ROOT xxxx
# ( ( PUNCT PUNCT punct (
# gnu-linux gnu-linux PROPN PROPN obj xxx-xxxx
# ) ) PUNCT PUNCT punct )
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# reclamación reclamación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  reclamación
# por por ADP ADP case xxx
# la el DET DET det xx
# mala malo ADJ ADJ amod xxxx
# gestión gestión NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# administración administración NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# arreglo arreglo NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# zona zona NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# acceso acceso NOUN NOUN nmod xxxx
# a a ADP ADP case x
# explotación explotación NOUN NOUN nmod xxxx
# ganadera ganadero ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# limpieza limpieza NOUN NOUN ROOT xxxx
# ent1 que o perro >>  limpieza
# solar solar ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# notificaciones notificación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  notificación
# buzón buzón PROPN PROPN appos xxxx
# electrónico electrónico ADJ ADJ amod xxxx
# del del ADP ADP case xxx
# ciudadano ciudadano NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicita solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# que que SCONJ SCONJ mark xxx
# ent1 que o perro >>  que
# se él PRON PRON expl:pass xx
# ent1 que o perro >>  él
# habilite habilitar VERB VERB ccomp xxxx
# ent1 que o perro >>  habilitar
# la el DET DET det xx
# ent1 que o perro >>  el
# posibilidad posibilidad NOUN NOUN nsubj xxxx
# de de ADP ADP mark xx
# que que SCONJ SCONJ mark xxx
# un uno DET DET det xx
# tercero tercero ADJ ADJ nsubj xxxx
# pueda poder AUX AUX aux xxxx
# presentar presentar VERB VERB acl xxxx
# documentación documentación NOUN NOUN obj xxxx
# por por ADP ADP case xxx
# otro otro DET DET det xxxx
# solicitante solicitante NOUN NOUN obj xxxx
# en en ADP ADP case xx
# determinados determinado ADJ ADJ amod xxxx
# trámites trámite NOUN NOUN obl xxxx
# administrativos administrativo ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# sanción sanción NOUN NOUN ROOT xxxx
# ent1 que o perro >>  sanción
# de de ADP ADP case xx
# tráfico tráfico NOUN NOUN nmod xxxx
# por por ADP ADP case xxx
# práctica práctica NOUN NOUN nmod xxxx
# irregular irregular ADJ ADJ amod xxxx
# de de ADP ADP case xx
# castellana castellana NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# autopistas autopista NOUN NOUN nmod xxxx
# s.a s.a PROPN PROPN appos x.x
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# hay haber AUX AUX ROOT xxx
# ent1 que o perro >>  haber
# personal personal NOUN NOUN obj xxxx
# de de ADP ADP case xx
# ent1 que o perro >>  de
# medio medio NOUN NOUN nmod xxxx
# ent1 que o perro >>  medio
# ambiente ambiente PROPN PROPN compound xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# planta planta NOUN NOUN obl xxxx
# baja bajo ADJ ADJ amod xxxx
# y y CCONJ CCONJ cc x
# no no ADV ADV advmod xx
# está estar AUX AUX conj xxxx
# permitido permitido ADJ ADJ iobj xxxx
# subir subir VERB VERB advcl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# servicio servicio PROPN PROPN ROOT xxxx
# ent1 que o perro >>  servicio
# oficina oficina PROPN PROPN flat xxxx
# ent1 que o perro >>  oficina
# caza caza PROPN PROPN flat xxxx
# ent1 que o perro >>  caza
# y y CCONJ CCONJ cc x
# ent1 que o perro >>  y
# pesca pesca NOUN NOUN conj xxxx
# ent1 que o perro >>  pesca
# ( ( PUNCT PUNCT punct (
# planta planta NOUN NOUN flat xxxx
# baja bajo ADJ ADJ amod xxxx
# ) ) PUNCT PUNCT punct )
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# servicio servicio NOUN NOUN ROOT xxxx
# ent1 que o perro >>  servicio
# precario precario ADJ ADJ amod xxxx
# e e CCONJ CCONJ cc x
# insuficiente insuficiente ADJ ADJ amod xxxx
# transporte transporte NOUN NOUN conj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# atención atención NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# medios medio NOUN NOUN nmod xxxx
# telemáticos telemático ADJ ADJ amod xxxx
# para para ADP ADP mark xxxx
# realizar realizar VERB VERB acl xxxx
# junta junta NOUN NOUN obj xxxx
# arbitral arbitral ADJ ADJ amod xxxx
# de de ADP ADP case xx
# transportes transporte NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# aclaración aclaración NOUN NOUN ROOT xxxx
# ent1 que o perro >>  aclaración
# sobre sobre ADP ADP case xxxx
# legislación legislación NOUN NOUN nmod xxxx
# aplicable aplicable ADJ ADJ amod xxxx
# a a ADP ADP case x
# requisitos requisito NOUN NOUN nmod xxxx
# para para ADP ADP case xxxx
# alquiler alquiler NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# vivienda vivienda NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# sistema sistema NOUN NOUN nsubj xxxx
# informatico informatico ADJ ADJ amod xxxx
# no no ADV ADV advmod xx
# funciona funcionar VERB VERB ROOT xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja queja NOUN NOUN ROOT xxxx
# ent1 que o perro >>  queja
# sobre sobre ADP ADP case xxxx
# medio medio NOUN NOUN nmod xxxx
# ambiente ambiente NOUN NOUN compound xxxx
# y y CCONJ CCONJ cc x
# residuos residuo NOUN NOUN conj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# pinos pino NOUN NOUN ROOT xxxx
# ent1 que o perro >>  pino
# existentes existente ADJ ADJ amod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# monte monte NOUN NOUN nmod xxxx
# público público ADJ ADJ amod xxxx
# lindantes lindant ADJ ADJ amod xxxx
# con con ADP ADP case xxx
# urbanización urbanización NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# protección protección NOUN NOUN ROOT xxxx
# ent1 que o perro >>  protección
# contra contra ADP ADP case xxxx
# incendios incendio NOUN NOUN nmod xxxx
# forestales forestal ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# contestación contestación NOUN NOUN ROOT xxxx
# a a ADP ADP advmod x
# queja queja NOUN NOUN fixed xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# disconformidad disconformidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  disconformidad
# con con ADP ADP case xxx
# la el DET DET det xx
# contestación contestación NOUN NOUN nmod xxxx
# dada dado ADJ ADJ amod xxxx
# a a ADP ADP case x
# la el DET DET det xx
# q-14457 q-14457 NOUN NOUN nmod x-dddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta faltar VERB VERB ROOT xxxx
# ent1 que o perro >>  faltar
# cobertura cobertura NOUN NOUN nsubj xxxx
# internet internet NOUN NOUN nsubj xxxx
# y y CCONJ CCONJ cc x
# telefonía telefonía NOUN NOUN conj xxxx
# móvil móvil ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# incumplmiiento incumplmiiento DET DET det xxxx
# ent1 que o perro >>  incumplmiiento
# normativa normativa NOUN NOUN ROOT xxxx
# ent1 que o perro >>  normativa
# medioambiental medioambiental ADJ ADJ amod xxxx
# por por ADP ADP case xxx
# la el DET DET det xx
# empresa empresa NOUN NOUN nmod xxxx
# kronospan kronospan PROPN PROPN appos xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicitud solicitud NOUN NOUN ROOT xxxx
# ent1 que o perro >>  solicitud
# devolución devolución NOUN NOUN amod xxxx
# pagos pago NOUN NOUN appos xxxx
# cotos coto NOUN NOUN amod xxxx
# pesca pesca NOUN NOUN amod xxxx
# por por ADP ADP case xxx
# cierre cierre NOUN NOUN obj xxxx
# perimetral perimetral ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicita solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# cambio cambio NOUN NOUN obj xxxx
# localidad localidad NOUN NOUN nmod xxxx
# ent1 que o perro >>  localidad
# examen examen NOUN NOUN amod xxxx
# y y CCONJ CCONJ cc x
# otras otro DET DET det xxxx
# cuestiones cuestión NOUN NOUN conj xxxx
# por por ADP ADP advmod xxx
# puerperio puerperio NOUN NOUN fixed xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# inadecuado inadecuado ADJ ADJ amod xxxx
# por por ADP ADP case xxx
# personal personal NOUN NOUN advmod xxxx
# del del ADP ADP case xxx
# 112 112 NUM NUM ROOT ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# licencia licencia NOUN NOUN ROOT xxxx
# ent1 que o perro >>  licencia
# ambiental ambiental ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# construcción construcción NOUN NOUN ROOT xxxx
# ent1 que o perro >>  construcción
# velatorio velatorio ADJ ADJ amod xxxx
# en en ADP ADP case xx
# toral toral ADJ ADJ nmod xxxx
# de de ADP ADP case xx
# los el DET DET det xxx
# vados vado NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# sistema sistema NOUN NOUN ROOT xxxx
# ent1 que o perro >>  sistema
# operativo operativo ADJ ADJ amod xxxx
# móvil móvil ADJ ADJ amod xxxx
# ios ios PROPN PROPN ROOT xxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# pregunta preguntar VERB VERB ROOT xxxx
# por por ADP ADP case xxx
# las el DET DET det xxx
# obras obra NOUN NOUN obj xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# cl-601 cl-601 NOUN NOUN nmod xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# deficiencias deficiencia NOUN NOUN ROOT xxxx
# ent1 que o perro >>  deficiencia
# en en ADP ADP case xx
# carril carril NOUN NOUN nmod xxxx
# bici bici ADJ ADJ amod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# puente puente NOUN NOUN nmod xxxx
# ducero ducero ADJ ADJ appos xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# recibido recibido ADJ ADJ amod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# 112 112 NUM NUM obl ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# bu-562 bu-562 NOUN NOUN ROOT xx-ddd
# ent1 que o perro >>  bu-562
# . . PUNCT PUNCT punct .
# falta faltar VERB VERB ROOT xxxx
# barrera barrera NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# protección protección NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# aumentar aumentar VERB VERB ROOT xxxx
# ent1 que o perro >>  aumentar
# capacidad capacidad NOUN NOUN obj xxxx
# subir subir VERB VERB xcomp xxxx
# ent1 que o perro >>  subir
# documentos documento NOUN NOUN obj xxxx
# en en ADP ADP case xx
# teletramitación teletramitación NOUN NOUN obl xxxx
# ent1 que o perro >>  teletramitación
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# vertido vertido NOUN NOUN ROOT xxxx
# ent1 que o perro >>  vertido
# de de ADP ADP case xx
# san san PROPN PROPN obj xxx
# en en ADP ADP case xx
# la el DET DET det xx
# parcela parcela NOUN NOUN obl xxxx
# 79 79 NUM NUM appos dd
# pol pol PROPN PROPN flat xxx
# 23 23 NUM NUM nummod dd
# de de ADP ADP case xx
# almeida almeida NOUN NOUN nmod xxxx
# de de ADP ADP advmod xx
# sayago sayago PROPN PROPN obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADV ADV advmod xxx
# ent1 que o perro >>  mal
# estado estado NOUN NOUN ROOT xxxx
# ent1 que o perro >>  estado
# de de ADP ADP case xx
# carretera carretera NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# prtoblemas prtoblema NOUN NOUN ROOT xxxx
# ent1 que o perro >>  prtoblema
# con con ADP ADP case xxx
# mac mac NOUN NOUN nmod xxx
# en en ADP ADP case xx
# sede sede NOUN NOUN nmod xxxx
# electrónica electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# atención atención NOUN NOUN ROOT xxxx
# ent1 que o perro >>  atención
# inadecuada inadecuado ADJ ADJ amod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# servicio servicio NOUN NOUN obl xxxx
# de de ADP ADP case xx
# financiacion financiacion NOUN NOUN nmod xxxx
# y y CCONJ CCONJ cc x
# ayudas ayuda NOUN NOUN conj xxxx
# a a ADP ADP case x
# la el DET DET det xx
# vivienda vivienda NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADV ADV amod xxx
# ent1 que o perro >>  mal
# estado estado NOUN NOUN ROOT xxxx
# ent1 que o perro >>  estado
# de de ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# autónomica autónomico ADJ ADJ amod xxxx
# cl-612 cl-612 PROPN PROPN appos xx-ddd
# ( ( PUNCT PUNCT punct (
# carretera carretera NOUN NOUN appos xxxx
# zamora zamora PROPN PROPN flat xxxx
# villalpando villalpando PROPN PROPN flat xxxx
# ) ) PUNCT PUNCT punct )
# en en ADP ADP case xx
# el el DET DET det xx
# primer primero ADJ ADJ amod xxxx
# tramo tramo NOUN NOUN obl xxxx
# desde desde ADP ADP case xxxx
# la el DET DET det xx
# capital capital NOUN NOUN nmod xxxx
# hasta hasta ADP ADP case xxxx
# aspariegos aspariego ADJ ADJ ROOT xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta faltar VERB VERB ROOT xxxx
# ent1 que o perro >>  faltar
# contestación contestación NOUN NOUN nsubj xxxx
# escrito escrito ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# señalización señalización NOUN NOUN ROOT xxxx
# ent1 que o perro >>  señalización
# comienzo comienzo NOUN NOUN amod xxxx
# pueblo pueblo NOUN NOUN amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# se él PRON PRON expl:pv xx
# quja quja VERB VERB ROOT xxxx
# del del ADP ADP case xxx
# estado estado NOUN NOUN obj xxxx
# del del ADP ADP case xxx
# firme firme NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# sg-723 sg-723 VERB VERB punct xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# peligrosidad peligrosidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  peligrosidad
# en en ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# espinar espinar NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# certificadi certificadi NOUN NOUN ROOT xxxx
# ent1 que o perro >>  certificadi
# competencias competencia ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# del del ADP ADP case xxx
# estado estado NOUN NOUN obj xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# carretera carretera NOUN NOUN nmod xxxx
# cl-607 cl-607 PROPN PROPN punct xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# trato trato NOUN NOUN ROOT xxxx
# ent1 que o perro >>  trato
# inadecuado inadecuado ADJ ADJ amod xxxx
# agente agente NOUN NOUN nsubj xxxx
# medioambiental medioambiental ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# lal lal VERB VERB nsubj xxx
# interesada interesado ADJ ADJ obj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# del del ADP ADP case xxx
# mal mal ADJ ADJ amod xxx
# estado estado NOUN NOUN obj xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# cl cl NOUN NOUN nmod xx
# 607 607 NUM NUM compound ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicita solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# poder poder AUX AUX aux xxxx
# ent1 que o perro >>  poder
# realizar realizar VERB VERB xcomp xxxx
# ...
# za-925 za-925 VERB VERB ROOT xx-ddd
# en en ADP ADP case xx
# periodo periodo NOUN NOUN obl xxxx
# invernal invernal ADJ ADJ amod xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# retrasos retraso NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# transporte transporte NOUN NOUN nmod xxxx
# escolar escolar ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# diversas diverso DET DET det xxxx
# ent1 que o perro >>  diverso
# cuestioones cuestioón NOUN NOUN ROOT xxxx
# ent1 que o perro >>  cuestioón
# relativas relativo ADJ ADJ amod xxxx
# a a ADP ADP case x
# un uno DET DET det xx
# proyecto proyecto NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# reparcelación reparcelación NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# terraza terrazar VERB VERB ROOT xxxx
# ent1 que o perro >>  terrazar
# con con ADP ADP case xxx
# ent1 que o perro >>  con
# una uno DET DET det xxx
# ent1 que o perro >>  uno
# verja verja NOUN NOUN nmod xxxx
# ent1 que o perro >>  verja
# perimetral perimetral ADJ ADJ amod xxxx
# atornillada atornillado ADJ ADJ amod xxxx
# a a ADP ADP case x
# la el DET DET det xx
# carretera carretera NOUN NOUN obj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# requisito requisito NOUN NOUN ROOT xxxx
# ent1 que o perro >>  requisito
# ite ite ADJ ADJ amod xxx
# para para ADP ADP case xxxx
# ayudas ayuda NOUN NOUN nmod xxxx
# rehabilitación rehabilitación NOUN NOUN amod xxxx
# de de ADP ADP case xx
# vivienda vivienda NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADV ADV advmod xxx
# ent1 que o perro >>  mal
# estado estado NOUN NOUN cop xxxx
# ent1 que o perro >>  estado
# márgenes márgén ADJ ADJ amod xxxx
# río río PROPN PROPN ROOT xxx
# tormes tormes PROPN PROPN ROOT xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# sugiere sugerir VERB VERB ROOT xxxx
# ent1 que o perro >>  sugerir
# que que SCONJ SCONJ mark xxx
# ent1 que o perro >>  que
# se él PRON PRON expl:pass xx
# ent1 que o perro >>  él
# reanude reanudar VERB VERB ccomp xxxx
# ent1 que o perro >>  reanudar
# la el DET DET det xx
# ent1 que o perro >>  el
# atención atención NOUN NOUN nsubj xxxx
# en en ADP ADP case xx
# la el DET DET det xx
# mesa mesa NOUN NOUN obl xxxx
# habilitada habilitado ADJ ADJ amod xxxx
# al al ADP ADP case xx
# efecto efecto NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# información información NOUN NOUN ROOT xxxx
# ent1 que o perro >>  información
# insuficiente insuficiente ADJ ADJ amod xxxx
# para para ADP ADP case xxxx
# anulación anulación NOUN NOUN nmod xxxx
# permisos permiso NOUN NOUN nmod xxxx
# pesca pesco ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# devolución devolución NOUN NOUN ROOT xxxx
# ent1 que o perro >>  devolución
# importe importe ADJ ADJ amod xxxx
# licencia licencia NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# caza caza NOUN NOUN nmod xxxx
# temporada temporado ADJ ADJ nmod xxxx
# 2020/2021 2020/2021 NUM NUM nummod dddd/dddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# aglomeraciones aglomeración NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# el el DET DET det xx
# autobús autobús NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# imposibilidad imposibilidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  imposibilidad
# de de ADP ADP mark xx
# hacer hacer VERB VERB acl xxxx
# el el DET DET det xx
# trámite trámite NOUN NOUN obj xxxx
# electrónicamente electrónicamente ADV ADV advmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# sugiere sugerir VERB VERB ROOT xxxx
# catalogar catalogar VERB VERB xcomp xxxx
# la el DET DET det xx
# zona zona NOUN NOUN obj xxxx
# de de ADP ADP case xx
# cosntanzana cosntanzana NOUN NOUN nmod xxxx
# y y CCONJ CCONJ cc x
# protegerla proteger él VERB VERB conj xxxx
# y y CCONJ CCONJ cc x
# evitar evitar VERB VERB conj xxxx
# prácticas práctica NOUN NOUN obj xxxx
# agrícolas agrícola ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# contestación contestación NOUN NOUN nmod xxxx
# y y CCONJ CCONJ cc x
# actuación actuación NOUN NOUN conj xxxx
# en en ADP ADP case xx
# queja queja NOUN NOUN nmod xxxx
# sobre sobre ADP ADP case xxxx
# reparación reparación NOUN NOUN nmod xxxx
# alcantarilla alcantarillo ADJ ADJ amod xxxx
# en en ADP ADP case xx
# ctra ctra NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# va-223 va-223 NOUN NOUN ROOT xx-ddd
# en en ADP ADP case xx
# fompedraza fompedraza NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# horario horario NOUN NOUN ROOT xxxx
# ent1 que o perro >>  horario
# de de ADP ADP case xx
# clases clase NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# curso curso NOUN NOUN nmod xxxx
# del del ADP ADP case xxx
# cap cap NOUN NOUN nmod xxx
# en en ADP ADP case xx
# miranda miranda NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# ebro ebro NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja quejar VERB VERB ROOT xxxx
# ent1 que o perro >>  quejar
# actuaciones actuación NOUN NOUN obj xxxx
# cámara cámaro ADJ ADJ amod xxxx
# ent1 que o perro >>  cámaro
# propiedad propiedad NOUN NOUN nmod xxxx
# urbana urbano ADJ ADJ amod xxxx
# fianza fianza NOUN NOUN nsubj xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# falta falta NOUN NOUN ROOT xxxx
# ent1 que o perro >>  falta
# de de ADP ADP case xx
# señalización señalización NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# escalón escalón NOUN NOUN nmod xxxx
# en en ADP ADP case xx
# aparcamietno aparcamietno PROPN PROPN nmod xxxx
# del del ADP ADP case xxx
# parque parque NOUN NOUN nmod xxxx
# natural natural ADJ ADJ amod xxxx
# laguna laguna NOUN NOUN appos xxxx
# negra negro ADJ ADJ amod xxxx
# y y CCONJ CCONJ cc x
# circos circo NOUN NOUN conj xxxx
# glaciares glaciar ADJ ADJ amod xxxx
# de de ADP ADP case xx
# urbión urbión PROPN PROPN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# ha haber AUX AUX aux xx
# ent1 que o perro >>  haber
# sido ser AUX AUX aux xxxx
# ent1 que o perro >>  ser
# atendido atender VERB VERB ROOT xxxx
# ent1 que o perro >>  atender
# presencialmente presencialmente ADV ADV advmod xxxx
# ent1 que o perro >>  presencialmente
# en en ADP ADP case xx
# fomento fomento NOUN NOUN obl xxxx
# ent1 que o perro >>  fomento
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# dificultad dificultad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  dificultad
# en en ADP ADP case xx
# tramitación tramitación NOUN NOUN nmod xxxx
# electrónica electrónico ADJ ADJ amod xxxx
# para para ADP ADP mark xxxx
# solicitar solicitar VERB VERB acl xxxx
# tarjeta tarjeta NOUN NOUN obj xxxx
# club club NOUN NOUN flat xxxx
# de de ADP ADP case xx
# los el DET DET det xxx
# 60 60 NUM NUM obl dd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# derecho derecho NOUN NOUN ROOT xxxx
# ent1 que o perro >>  derecho
# a a ADP ADP case x
# trámites trámite NOUN NOUN nmod xxxx
# electrónicos electrónico ADJ ADJ amod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# queja queja NOUN NOUN ROOT xxxx
# ent1 que o perro >>  queja
# sobre sobre ADP ADP case xxxx
# nuevo nuevo ADJ ADJ amod xxxx
# sistema sistema NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# elección elección NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# cotos coto NOUN NOUN nmod xxxx
# . . PUNCT PUNCT punct .
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# cebos cebo NOUN NOUN ROOT xxxx
# ent1 que o perro >>  cebo
# utilizados utilizado ADJ ADJ amod xxxx
# para para ADP ADP case xxxx
# pesca pesca NOUN NOUN obl xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# mal mal ADJ ADJ amod xxx
# ent1 que o perro >>  mal
# funcionamiento funcionamiento NOUN NOUN ROOT xxxx
# de de ADP ADP case xx
# aplicación aplicación NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# subvención subvención NOUN NOUN nmod xxxx
# iapa iapo ADJ ADJ amod xxxx
# 3065 3065 NUM NUM punct dddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# reserva reserva NOUN NOUN ROOT xxxx
# ent1 que o perro >>  reserva
# de de ADP ADP case xx
# fecha fecha NOUN NOUN nmod xxxx
# para para ADP ADP case xxxx
# cotos coto NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# pesca pesca NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# villafeliz villafeliz NOUN NOUN nmod xxxx
# ( ( PUNCT PUNCT punct (
# león león PROPN PROPN flat xxxx
# ) ) PUNCT PUNCT punct )
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# solicita solicitar VERB VERB ROOT xxxx
# ent1 que o perro >>  solicitar
# devolución devolución NOUN NOUN obj xxxx
# del del ADP ADP case xxx
# ent1 que o perro >>  del
# importe importe NOUN NOUN nmod xxxx
# ent1 que o perro >>  importe
# de de ADP ADP case xx
# permisos permiso NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# cotos coto NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# la el DET DET det xx
# ent1 que o perro >>  el
# interesada interesado ADJ ADJ nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# prestación prestación NOUN NOUN obj xxxx
# del del ADP ADP case xxx
# servicio servicio NOUN NOUN nmod xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# ruta ruta NOUN NOUN nmod xxxx
# escolar escolar ADJ ADJ amod xxxx
# de de ADP ADP case xx
# su su DET DET det xx
# hijo hijo NOUN NOUN nmod xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# el el DET DET det xx
# ent1 que o perro >>  el
# interesado interesado NOUN NOUN nsubj xxxx
# se él PRON PRON expl:pv xx
# queja quejar VERB VERB ROOT xxxx
# porque porque SCONJ SCONJ mark xxxx
# el el DET DET det xx
# autobús autobús NOUN NOUN nsubj xxxx
# de de ADP ADP case xx
# la el DET DET det xx
# línea línea NOUN NOUN nmod xxxx
# 5 5 NUM NUM appos d
# del del ADP ADP case xxx
# servicio servicio NOUN NOUN nmod xxxx
# metropolitano metropolitano ADJ ADJ amod xxxx
# no no ADV ADV advmod xx
# llegó llegar VERB VERB advcl xxxx
# los el DET DET det xxx
# días día NOUN NOUN obl xxxx
# 2 2 NUM NUM appos d
# y y CCONJ CCONJ cc x
# 4 4 NUM NUM conj d
# de de ADP ADP case xx
# enero enero NOUN NOUN compound xxxx
# e e CCONJ CCONJ punct x
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# no no ADV ADV advmod xx
# ent1 que o perro >>  no
# limpieza limpieza NOUN NOUN ROOT xxxx
# ent1 que o perro >>  limpieza
# de de ADP ADP case xx
# carretera carretera NOUN NOUN nmod xxxx
# bu-945 bu-945 PROPN PROPN flat xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# normalidad normalidad NOUN NOUN ROOT xxxx
# ent1 que o perro >>  normalidad
# post-covid post-covid NUM NUM appos xxxx-xxxx
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# diámetro diámetro NOUN NOUN ROOT xxxx
# ent1 que o perro >>  diámetro
# escaso escaso ADJ ADJ amod xxxx
# tuberías tubería NOUN NOUN nmod xxxx
# agua aguo ADJ ADJ amod xxxx
# za-925 za-925 VERB VERB ROOT xx-ddd
# TEXTO  LEMMA  POS  TAG  DEP  SHAPE
# contestación contestación NOUN NOUN ROOT xxxx
# ent1 que o perro >>  contestación
# urgente urgente ADJ ADJ amod xxxx
# a a ADP ADP case x
# solicitud solicitud NOUN NOUN nmod xxxx
# formulada formulado ADJ ADJ amod xxxx
# por por ADP ADP case xxx
# correo correo NOUN NOUN obj xxxx
# electrónico electrónico ADJ ADJ amod xxxx
# el el DET DET det xx
# día día NOUN NOUN obl xxx
# 21 21 NUM NUM compound dd
# de de ADP ADP case xx
# enero enero NOUN NOUN compound xxxx
# de de ADP ADP case xx
# 2021 2021 NUM NUM compound dddd
# []
# [(11840699188806025751, 7, 8)]
# van
# van
# [(11840699188806025751, 0, 1)]
# solicita
# solicita
# []
# []
# [(11840699188806025751, 1, 2)]
# funciona
# funciona
# [(11840699188806025751, 0, 1)]
# cita
# cita
# [(11840699188806025751, 7, 8), (11840699188806025751, 8, 9)]
# ha
# sido
# [(11840699188806025751, 6, 7)]
# explorer
# explorer
# []
# [(11840699188806025751, 1, 2)]
# usar
# usar
# []
# [(11840699188806025751, 0, 1)]
# darse
# darse
# []
# [(11840699188806025751, 5, 6), (11840699188806025751, 6, 7), (11840699188806025751, 7, 8)]
# ha
# atendida
# []
# []
# []
# [(11840699188806025751, 0, 1)]
# solicita
# solicita
# [(11840699188806025751, 2, 3), (11840699188806025751, 3, 4)]
# sugiere
# abaratar
# [(11840699188806025751, 2, 3)]
# navarredondilla
# navarredondilla
# []
# []
# []
# [(11840699188806025751, 3, 4)]
# queja
# queja
# [(11840699188806025751, 3, 4)]
# queja
# queja
# [(11840699188806025751, 3, 4)]
# queja
# queja
# []
# [(11840699188806025751, 8, 9)]
# ser
# ser
# [(11840699188806025751, 3, 4)]
# queja
# queja
# []
# [(11840699188806025751, 7, 8)]
# encuentran
# encuentran
# [(11840699188806025751, 2, 3)]
# teme
# teme
# [(11840699188806025751, 1, 2)]
# relacionarse
# relacionarse
# [(11840699188806025751, 1, 2), (11840699188806025751, 10, 11)]
# requiere
# solicita
# []
# []
# []
# []
# [(11840699188806025751, 0, 1)]
# mejorar
# mejorar
# [(11840699188806025751, 4, 5)]
# presentar
# presentar
# [(11840699188806025751, 1, 2)]
# mejora
# mejora
# []
# [(11840699188806025751, 0, 1)]
# incorporar
# incorporar
# []
# []
# [(11840699188806025751, 0, 1)]
# cierre
# cierre
# []
# []
# []
# []
# []
# [(11840699188806025751, 0, 1), (11840699188806025751, 4, 5), (11840699188806025751, 8, 9)]
# cierre
# llamó
# []
# [(11840699188806025751, 0, 1), (11840699188806025751, 5, 6)]
# queja
# tordillos
# []
# []
# []
# [(11840699188806025751, 2, 3)]
# sugiere
# sugiere
# [(11840699188806025751, 6, 7)]
# expresa
# expresa
# []
# []
# [(11840699188806025751, 6, 7)]
# explorer
# explorer
# [(11840699188806025751, 3, 4), (11840699188806025751, 6, 7), (11840699188806025751, 7, 8)]
# queja
# asfaltado
# [(11840699188806025751, 0, 1)]
# cierre
# cierre
# [(11840699188806025751, 0, 1), (11840699188806025751, 2, 3)]
# pide
# atiendan
# [(11840699188806025751, 0, 1), (11840699188806025751, 2, 3)]
# demora
# otorgar
# [(11840699188806025751, 5, 6), (11840699188806025751, 13, 14)]
# está
# abren
# [(11840699188806025751, 2, 3)]
# propone
# propone
# []
# []
# [(11840699188806025751, 2, 3)]
# carbanas
# carbanas
# []
# []
# []
# [(11840699188806025751, 2, 3), (11840699188806025751, 5, 6)]
# quiere
# envien
# [(11840699188806025751, 3, 4)]
# funciona
# funciona
# []
# []
# [(11840699188806025751, 1, 2)]
# terraza
# terraza
# [(11840699188806025751, 11, 12)]
# obstruyendo
# obstruyendo
# [(11840699188806025751, 1, 2)]
# estado
# estado
# []
# []
# [(11840699188806025751, 3, 4)]
# atravesar
# atravesar
# [(11840699188806025751, 3, 4)]
# queja
# queja
# [(11840699188806025751, 5, 6)]
# presentar
# presentar
# [(11840699188806025751, 8, 9)]
# za-925
# za-925
# []
# [(11840699188806025751, 2, 3), (11840699188806025751, 18, 19)]
# conectarse
# está
# []
# []
# [(11840699188806025751, 3, 4)]
# fompedraza
# fompedraza
# [(11840699188806025751, 0, 1), (11840699188806025751, 1, 2), (11840699188806025751, 10, 11)]
# poder
# debian
# []
# []
# []
# [(11840699188806025751, 0, 1), (11840699188806025751, 3, 4), (11840699188806025751, 10, 11), (11840699188806025751, 11, 12)]
# solicita
# presentar
# []
# [(11840699188806025751, 1, 2), (11840699188806025751, 12, 13), (11840699188806025751, 14, 15)]
# hay
# subir
# []
# []
# []
# [(11840699188806025751, 5, 6)]
# realizar
# realizar
# []
# [(11840699188806025751, 4, 5)]
# funciona
# funciona
# []
# []
# []
# []
# [(11840699188806025751, 0, 1)]
# falta
# falta
# []
# []
# [(11840699188806025751, 0, 1)]
# solicita
# solicita
# []
# []
# []
# []
# [(11840699188806025751, 2, 3)]
# pregunta
# pregunta
# []
# []
# [(11840699188806025751, 2, 3)]
# falta
# falta
# [(11840699188806025751, 0, 1), (11840699188806025751, 2, 3)]
# aumentar
# subir
# []
# []
# []
# []
# []
# [(11840699188806025751, 0, 1)]
# falta
# falta
# []
# [(11840699188806025751, 3, 4), (11840699188806025751, 11, 12)]
# quja
# sg-723
# []
# []
# [(11840699188806025751, 3, 4)]
# queja
# queja
# []
# [(11840699188806025751, 0, 1), (11840699188806025751, 3, 4)]
# lal
# queja
# [(11840699188806025751, 0, 1), (11840699188806025751, 0, 2), (11840699188806025751, 1, 2), (11840699188806025751, 2, 3)]
# solicita
# realizar
# [(11840699188806025751, 10, 11)]
# za-925
# za-925
# [(11840699188806025751, 3, 4)]
# queja
# queja
# []
# [(11840699188806025751, 0, 1)]
# terraza
# terraza
# []
# []
# [(11840699188806025751, 0, 1), (11840699188806025751, 3, 4)]
# sugiere
# reanude
# []
# []
# [(11840699188806025751, 3, 4)]
# queja
# queja
# [(11840699188806025751, 2, 3)]
# hacer
# hacer
# [(11840699188806025751, 2, 3), (11840699188806025751, 3, 4), (11840699188806025751, 9, 10), (11840699188806025751, 11, 12)]
# sugiere
# evitar
# []
# []
# [(11840699188806025751, 0, 1)]
# queja
# queja
# []
# [(11840699188806025751, 1, 2), (11840699188806025751, 2, 3), (11840699188806025751, 3, 4)]
# ha
# atendido
# [(11840699188806025751, 5, 6)]
# solicitar
# solicitar
# []
# []
# []
# []
# []
# [(11840699188806025751, 0, 1)]
# solicita
# solicita
# [(11840699188806025751, 3, 4)]
# queja
# queja
# [(11840699188806025751, 3, 4), (11840699188806025751, 15, 16)]
# queja
# llegó
# []
# []
# [(11840699188806025751, 4, 5)]
# za-925
# za-925
# []

# %%
source = [i[0] for i in entity_pairs]
# extract object
target = [i[1] for i in entity_pairs]

# %%
from collections import Counter

# %%
all_words = source + target #+ relations
words = getWordCount(all_words)
k = Counter(words)

# %%
k.most_common(5)
# Out:
# [('interesado', 16), ('falta', 12), ('', 8), ('estado', 8), ('carretera', 8)]

# %%
from collections.abc import Iterable
from highcharts import Highchart
from IPython.core.display import HTML

# %%
# %%javascript
# require.config({
#     packages: [{
#         name: 'highcharts',
#         main: 'highcharts'
#     }],
#     paths: {
#         'highcharts': 'https://code.highcharts.com',
#         'networkgraph': 'https://code.highcharts.com/modules/networkgraph.js'
#     }
# });

# %%
import json
from IPython.display import Javascript

chart_data = []

for index in range(0, len(source) - 1):
    if source[index] != "" and target[index] != "":
        chart_data.append([source[index], target[index]])
        
"""for index in range(0, len(source) - 1):
    if (source[index] != ""):
        chart_data.append([source[index], relations[index]])
    if (target[index] != ""):
        chart_data.append([target[index], relations[index]])
    if (source[index] != "" and target[index] != ""):
        chart_data.append([source[index], target[index]])"""

Javascript("window.chartData={};".format(json.dumps(chart_data)))

# %%
# %%javascript
# // Since I append the div later, sometimes there are multiple divs.
# $("#container").remove();
#
# // Make the cdiv to contain the chart.
# element.append('<div id="container" style="min-width: 310px; min-height: 600px; margin: 0 auto"></div>');
#
# console.log("init");
# console.log(window.chartData);
#
# // Require highcarts and make the chart.
# require([
#     'highcharts',
#     'highcharts/modules/exporting',
#     'highcharts/modules/accessibility',
#     'highcharts/modules/networkgraph'
# ], function (Highcharts) {
#
#
#     console.log("WORKING");
#     $('#container').highcharts({
#         chart: {
#         type: 'networkgraph',
#         height: '100%'
#       },
#       title: {
#         text: 'The Indo-European Language Tree'
#       },
#       subtitle: {
#         text: 'A Force-Directed Network Graph in Highcharts'
#       },
#       plotOptions: {
#         networkgraph: {
#           keys: ['from', 'to'],
#           layoutAlgorithm: {
#             enableSimulation: true,
#             friction: -0.9
#           }
#         }
#       },
#     legend: {
#         layout: 'vertical',
#         align: 'right',
#         verticalAlign: 'middle'
#     },
#       series: [{
#         accessibility: {
#           enabled: false
#         },
#         dataLabels: {
#           enabled: true,
#           linkFormat: ''
#         },
#         id: 'lang-tree',
#         // This is where I used the chart_data from Python
#         data: window.chartData
#       }]
#     });
# });

# %%
source = [i[0] for i in entity_pairs]
# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})
kg_df[0:30]
# Out:
#                  source        target              edge
# 0                 falta     respuesta             haber
# 1          notificación    indicación                ir
# 2                altura      revisión         solicitar
# 3                 norma        ambito             haber
# 4                                                 haber
# 5           no  máquina          bono         funcionar
# 6                                                 citar
# 7            incidencia     carretera               ser
# 8             exigencia           uso          explorer
# 9            transporte       demanda             haber
# 10                lugar    mascarilla              usar
# 11         señalización       entrada             haber
# 12                 alta       sistema            dar él
# 13         notificación   electrónico             haber
# 14                medio      ambiente           atender
# 15                queja   relacionado             haber
# 16                falta         aviso             haber
# 17                 paso      peatonal             haber
# 18       horizontal  cl        mejora         solicitar
# 19             interesa        precio          abaratar
# 20  reacondicionamiento  navatalgordo  navarredondillar
# 21         contestación    satisfecho             haber
# 22         modificación     normativa             haber
# 23            alegación     plantilla             haber
# 24           interesado          real            quejar
# 25           interesado     supresión            quejar
# 26           interesado          real            quejar
# 27           desacuerdo    asignación             haber
# 28              central      servicio               ser
# 29           interesado       retraso            quejar

# %%
G = nx.from_pandas_edgelist(kg_df, "source", "target", edge_attr=True, create_using=nx.MultiDiGraph())
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='teal', edge_cmap=plt.cm.Blues, pos = pos, font_size=10, node_size=500)
plt.show()

# %%
G = nx.from_pandas_edgelist(kg_df, "source", "target", edge_attr=True, create_using=nx.MultiGraph())
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='teal', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 G = nx.from_pandas_edgelist(kg_df, "source", "target", edge_attr=True, create_using=nx.MultiGraph())
#       2 plt.figure(figsize=(12,12))
#       4 pos = nx.spring_layout(G)
#
# NameError: name 'kg_df' is not defined

# %%
entities = []
actions = []

for index in range(0, len(source) - 1):
    if (source[index] != ""):
        actions.append(relations[index])
        entities.append(source[index])
    if (target[index] != ""):
        actions.append(relations[index])
        entities.append(target[index])

entities_actions_df = pd.DataFrame({'entities':entities, 'actions':actions, 'edge':actions})

# %%
entities_actions_df
# Out:
#        entities actions    edge
# 0         ayuda   haber   haber
# 1          beca   haber   haber
# 2      cuestión     ser     ser
# 3     rechazado     ser     ser
# 4       acuerdo  cantar  cantar
# ..          ...     ...     ...
# 166       padre      ir      ir
# 167  incidencia   haber   haber
# 168  aplicación   haber   haber
# 169       queja   haber   haber
# 170        nulo   haber   haber
#
# [171 rows x 3 columns]

# %%
G = nx.from_pandas_edgelist(entities_actions_df, "entities", "actions", edge_attr=True, create_using=nx.MultiGraph())
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='teal', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
entities = []
actions = []

for index in range(0, len(source) - 1):
    if (source[index] != ""):
        actions.append(relations[index])
        entities.append(source[index])
    if (target[index] != ""):
        actions.append(target[index])
        entities.append(relations[index])

entities_actions_df = pd.DataFrame({'entities':entities, 'actions':actions, 'edge':actions})

G = nx.from_pandas_edgelist(entities_actions_df, "entities", "actions", edge_attr=True, create_using=nx.MultiDiGraph())
plt.figure(figsize=(12,12))

#pos = nx.spring_layout(G)
#pos = nx.circular_layout(G)
pos = nx.kamada_kawai_layout(G)
#pos = nx.spiral_layout(G)

nx.draw(G, with_labels=True, node_color='teal', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
import igraph as ig

import chart_studio.plotly as plotly
from plotly.offline import iplot
import plotly.graph_objs as go

# %%
entities = []
actions = []

for index in range(0, len(source) - 1):
    if (source[index] != ""):
        actions.append(relations[index])
        entities.append(source[index])
    if (target[index] != ""):
        actions.append(target[index])
        entities.append(relations[index])

entities_actions_df = pd.DataFrame({'entities':entities, 'actions':actions, 'edge':actions})

# %%
dictWords = {}
counter = 0

for word in entities:
    if word not in dictWords.keys():
        dictWords[word] = counter
        counter +=1

for word in actions:
    if word not in dictWords.keys():
        dictWords[word] = counter
        counter += 1

# %%
L = len(entities_actions_df["entities"])
L
# Out:
# 171

# %%
Edges = [(dictWords[entities_actions_df["entities"][k]], dictWords[entities_actions_df["actions"][k]]) for k in range(L)]

# %%
G = ig.Graph(Edges, directed=False)

# %%
""" labels=[]
group=[]
for node in data['nodes']:
    labels.append(node['name'])
    group.append(node['group']) """
labels = entities_actions_df["entities"].values
group = []

# %%
layt = G.layout('kk', dim=3)

# %%
len(layt)
# Out:
# 154

# %%
N = 154

# %%
Xn=[layt[k][0] for k in range(N)]# x-coordinates of nodes
Yn=[layt[k][1] for k in range(N)]# y-coordinates
Zn=[layt[k][2] for k in range(N)]# z-coordinates
Xe=[]
Ye=[]
Ze=[]
for e in Edges:
    Xe += [layt[e[0]][0],layt[e[1]][0], None]# x-coordinates of edge ends
    Ye += [layt[e[0]][1],layt[e[1]][1], None]
    Ze += [layt[e[0]][2],layt[e[1]][2], None]

# %%
trace1=go.Scatter3d(x=Xe,
            y=Ye,
            z=Ze,
            mode='lines',
            line=dict(color='rgb(125,125,125)', width=1),
            hoverinfo='none'
            )

trace2=go.Scatter3d(x=Xn,
            y=Yn,
            z=Zn,
            mode='markers',
            name='actors',
            marker=dict(symbol='circle',
                            size=6,
                            color=group,
                            colorscale='Viridis',
                            line=dict(color='rgb(50,50,50)', width=0.5)
                            ),
            text=labels,
            hoverinfo='text'
            )

axis=dict(showbackground=False,
        showline=False,
        zeroline=False,
        showgrid=False,
        showticklabels=False,
        title=''
        )

layout = go.Layout(
        title="",
        width=1000,
        height=1000,
        showlegend=False,
        scene=dict(
            xaxis=dict(axis),
            yaxis=dict(axis),
            zaxis=dict(axis),
        ),
        margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
        dict(
        showarrow=False,
        text="",
        xref='paper',
        yref='paper',
        x=0,
        y=0.1,
        xanchor='left',
        yanchor='bottom',
        font=dict(
        size=14
        )
        )
    ],    )

# %%
import chart_studio

# %%
data = [trace1, trace2]
fig = go.Figure(data=data, layout=layout)

plotly.iplot(fig, filename='Les-Miserables')
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="https://plotly.com/~darkmyes/1.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
entities = []
actions = []

for index in range(0, len(source) - 1):
    if (source[index] != ""):
        actions.append(relations[index])
        entities.append(source[index])
    if (target[index] != ""):
        actions.append(target[index])
        entities.append(relations[index])
    if (source[index] != "" and target[index] != ""):
        actions.append(source[index])
        entities.append(target[index])

entities_actions_df = pd.DataFrame({'entities':entities, 'actions':actions, 'edge':actions})

G = nx.from_pandas_edgelist(entities_actions_df, "entities", "actions", edge_attr=True, create_using=nx.MultiGraph())
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='teal', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
entities = []
actions = []

for index in range(0, len(source) - 1):
    if (source[index] != ""):
        actions.append(relations[index])
        entities.append(source[index])
    if (target[index] != ""):
        actions.append(target[index])
        entities.append(relations[index])
    if (source[index] != "" and target[index] != ""):
        actions.append(source[index])
        entities.append(target[index])

entities_actions_df = pd.DataFrame({'entities':entities, 'actions':actions, 'edge':actions})

# %%
G = nx.MultiDiGraph()
for index in range(0, len(source) - 1):
    if (source[index] != ""):
        G.add_edge(source[index],relations[index])
    if (target[index] != ""):
        G.add_edge(target[index],relations[index])
    if (source[index] != "" and target[index] != ""):
        G.add_edge(source[index],target[index])

H = nx.Graph(G)
# edge width is proportional number of games played
#edgewidth = [len(G.get_edge_data(u, v)) for u, v in H.edges()]

pos = nx.kamada_kawai_layout(H)

fig, ax = plt.subplots(figsize=(12, 12))
# Visualize graph components
#nx.draw_networkx_edges(H, pos, alpha=0.3, width=edgewidth, edge_color="m")
nx.draw_networkx_edges(H, pos, alpha=0.3, width=2, edge_color="m")

#nx.draw_networkx_nodes(H, pos, node_size=nodesize, node_color="#210070", alpha=0.9)
nx.draw_networkx_nodes(H, pos, node_size=500, node_color="#210070", alpha=0.9)
label_options = {"ec": "k", "fc": "white", "alpha": 0.7}
nx.draw_networkx_labels(H, pos, font_size=14, bbox=label_options)

fig.tight_layout()
plt.axis("off")
plt.show()
